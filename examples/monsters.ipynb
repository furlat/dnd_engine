# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

import time

start_time = time.time()
source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior(name="Mona")

# %%
warrior.source_entity_uuid
# Out:
# UUID('ab2b9121-e849-463c-9d41-cc35738901d8')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('721c1e40-cb50-4401-b8ab-7cd5b9958184')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('721c1e40-cb50-4401-b8ab-7cd5b9958184'): AbilityScores(name='ability_scores', description=None, uuid=UUID('721c1e40-cb50-4401-b8ab-7cd5b9958184'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('b7af7f50-fd52-4089-81a5-e0fe1503b282'): Ability(name='strength', description=None, uuid=UUID('b7af7f50-fd52-4089-81a5-e0fe1503b282'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('19c859c7-3d49-4e09-93db-578b41721c8a'): ModifiableValue(name='strength Ability Score', uuid=UUID('19c859c7-3d49-4e09-93db-578b41721c8a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9e9b4fd2-2319-41aa-9206-601056ace7be'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6a3be04-0564-4172-8f08-98281573a160'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6a3be04-0564-4172-8f08-98281573a160'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'): NumericalModifier(name='level 4 talent', uuid=UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Damag ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('19c859c7-3d49-4e09-93db-578b41721c8a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9e9b4fd2-2319-41aa-9206-601056ace7be'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6a3be04-0564-4172-8f08-98281573a160'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6a3be04-0564-4172-8f08-98281573a160'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'): NumericalModifier(name='level 4 talent', uuid=UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b402833f-c481-42fa-8dfa-04ec8595ffb0'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 23

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 18

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.0005033016204833984

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('19c859c7-3d49-4e09-93db-578b41721c8a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9e9b4fd2-2319-41aa-9206-601056ace7be'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6a3be04-0564-4172-8f08-98281573a160'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6a3be04-0564-4172-8f08-98281573a160'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'): NumericalModifier(name='level 4 talent', uuid=UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b402833f-c481-42fa-8dfa-04ec8595ffb0'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.002016305923461914

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 15, Roll total: 20 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0004975795745849609

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 50
# 0.0005006790161132812

# %%
damages
# Out:
# [Damage(name='Damage', uuid=UUID('964ce0be-4fc3-4eaa-b1d6-d800bc97f72f'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('0a602c15-28fc-44e0-b802-1616cf1972ea'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4EB60>, generated_from=[UUID('fe28189c-39cd-4171-9174-814b3eb16dc4'), UUID('44afc976-19a7-4d47-9e3c-9e1da2675252'), UUID('c6661f95-e971-4f85-8ec7-7e11dc5364e3'), UUID('7fe6355f-3d5f-463c-a63e-24250f115d12')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('3fda2bae-6f7e-4c3b-af2d-cb9581a3346d'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4EB60>, generated_from=[UUID('9a4e908a-4acc-4a8e-bb0b-214dc008d655'), UUID('96224fdf-4af0-449d-bef4-d12f3b6b2b3e'), UUID('b29c73fc-9e3a-43e1-a749-5c033686a970'), UUID('04eb2f14-7e8d-4630-910d-6c22954b4da5')], global_normalizer=False, value_modifiers={UUID('c00c3b73-aaeb-42de-833e-e4b5e6549660'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('c00c3b73-aaeb-42de-833e-e4b5e6549660'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4EB60>, normalized_value=1), UUID('47d56bf8-9168-43c0-a103-0b7921ce5c5a'): NumericalModifier(name='a past in the circus', uuid=UUID('47d56bf8-9168-43c0-a103-0b7921ce5c5a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('fc9f280e-1e3e-41c1-9bae-1772fc3a543f'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('fc9f280e-1e3e-41c1-9bae-1772fc3a543f'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4E2A0>, normalized_value=0), UUID('3ed84fa4-ab86-4ba5-9ec5-f22fd730c4a2'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('3ed84fa4-ab86-4ba5-9ec5-f22fd730c4a2'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4E7A0>, normalized_value=0), UUID('a6a3be04-0564-4172-8f08-98281573a160'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6a3be04-0564-4172-8f08-98281573a160'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'): NumericalModifier(name='level 4 talent', uuid=UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, targ ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0035233497619628906

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0019998550415039062

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0019981861114501953

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('19c859c7-3d49-4e09-93db-578b41721c8a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9e9b4fd2-2319-41aa-9206-601056ace7be'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6a3be04-0564-4172-8f08-98281573a160'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6a3be04-0564-4172-8f08-98281573a160'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'): NumericalModifier(name='level 4 talent', uuid=UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b402833f-c481-42fa-8dfa-04ec8595ffb0'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 1, Roll total: 6 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.010016679763793945

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request
# Out:
# SkillCheckEvent(name='Skill Check', uuid=UUID('c69e63f9-3d2c-4f6b-ad35-c1582123d990'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, lineage_uuid=UUID('c6ed355c-c4ac-4b51-838a-db631c2ddfd4'), timestamp=datetime.datetime(2025, 5, 2, 2, 48, 27, 156256), event_type=<EventType.SKILL_CHECK: 'skill_check'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], dc=12, bonus=0, dice=None, dice_roll=None, result=None, skill_name='acrobatics')

# %%
strength_saving_throw_request
# Out:
# SavingThrowEvent(name='Saving Throw', uuid=UUID('1a18a529-ae47-4447-a3a4-bdeb6520cef7'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, lineage_uuid=UUID('5c14e72f-2629-4d98-b0e2-0ce9c420ed3c'), timestamp=datetime.datetime(2025, 5, 2, 2, 48, 27, 166276), event_type=<EventType.SAVING_THROW: 'saving_throw'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], dc=12, bonus=0, dice=None, dice_roll=None, result=None, ability_name='strength')

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")
# Out:
# ModifiableValue(name='Value_acrobatics Skill Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('423fc4b5-fdaa-491a-8269-c5f75c682cc4'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020503F232E0>, generated_from=[UUID('5decbb93-956c-46cb-996d-7ddb8d959e82'), UUID('3391ec27-a8c4-490a-8f01-d3c43d246b6a'), UUID('b6398b7a-9a35-45aa-b50e-fefb2f288e4b'), UUID('e8ac2b45-bce1-473f-8d28-d7d2634724c3')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('9e0fadb2-20f8-40c8-bb79-74299fc89143'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020503F232E0>, generated_from=[UUID('56072026-88c0-4f5c-8227-4428ffdc5ac9'), UUID('17b3d573-c86d-41f6-bc2d-6d7d6a7d10b6'), UUID('e59e1a29-4a90-447d-97ad-ab026a0b72ab'), UUID('4d304eff-4954-42ba-bd40-1415be93800a')], global_normalizer=False, value_modifiers={UUID('73352fe3-660f-4d97-999f-40d5077bb157'): NumericalModifier(name='Value_base_value', uuid=UUID('73352fe3-660f-4d97-999f-40d5077bb157'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=0, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020503F232E0>, normalized_value=0), UUID('651d95b8-148c-44c6-8352-e052431e6d17'): NumericalModifier(name='a past in the circus', uuid=UUID('651d95b8-148c-44c6-8352-e052431e6d17'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020503F232E0>, normalized_value=-2), UUID('96d0de12-8e2c-410f-82db-8fb9b0c6d58e'): NumericalModifier(name='acrobatics Skill Bonus_base_value', uuid=UUID('96d0de12-8e2c-410f-82db-8fb9b0c6d58e'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020503E30400>, normalized_value=0), UUID('289f2f26-993b-4f02-8edd-f13280e9efb6'): NumericalModifier(name='a past in the circus', uuid=UUID('289f2f26-993b-4f02-8edd-f13280e9efb6'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=7, score_normalizer=None, normalized_value=7), UUID('2fc6ed16-11e4-4d3d-be4c-fc399134e6f4'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('2fc6ed16-11e4-4d3d-be4c-fc399134e6f4'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=12, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=1), UUID('17fc5e23-02c3-4c3d-8fc4-038ce64ca972'): NumericalModifier(name='strength Modifier Bonus_base_value', uuid=UUID('17fc5e23-02c3-4c3d-8fc4-038ce64ca972'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4F740>, normalized_value=0)}, min_constraints={}, max_co ...

# %%
warrior2.skill_check(acrobatics_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 6
# Roll result: 18, Roll total: 24 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('66b214b2-a0a8-40cd-921a-8ad76c40ca20'), dice_uuid=UUID('79446074-d5d3-4dd9-bcf3-db28ec9add48'), roll_type=<RollType.ATTACK: 'Attack'>, results=18, total=24, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  True)

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 13, Roll total: 13 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('df21a4d2-7932-4b5a-bea3-f3c04f3877f6'), dice_uuid=UUID('203d7387-d4d6-4858-a925-ce850b66413f'), roll_type=<RollType.ATTACK: 'Attack'>, results=13, total=13, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  True)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")
# Out:
# ModifiableValue(name='Value_strength_saving_throw Saving Throw Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('613147f7-ae39-421d-a760-ed1532fd294e'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020503F200E0>, generated_from=[UUID('5decbb93-956c-46cb-996d-7ddb8d959e82'), UUID('727e5ca2-d2d5-4f65-a53b-35ae3af7f7d0'), UUID('4bb10d71-7d61-4ca6-b642-c0b18f4d8df2'), UUID('d527bb99-e455-425c-bf34-034657d7e012')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('4633ded0-8d8b-42d0-94cf-40053bc98236'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020503F200E0>, generated_from=[UUID('56072026-88c0-4f5c-8227-4428ffdc5ac9'), UUID('a5cff34a-01a0-44d2-9445-c20b64a49937'), UUID('0cc18472-704c-4e43-8811-2ce9dd1d17be'), UUID('fe713bf7-b391-4c2a-9b0e-958178abcba4')], global_normalizer=False, value_modifiers={UUID('73352fe3-660f-4d97-999f-40d5077bb157'): NumericalModifier(name='Value_base_value', uuid=UUID('73352fe3-660f-4d97-999f-40d5077bb157'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=0, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020503F200E0>, normalized_value=0), UUID('651d95b8-148c-44c6-8352-e052431e6d17'): NumericalModifier(name='a past in the circus', uuid=UUID('651d95b8-148c-44c6-8352-e052431e6d17'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020503F200E0>, normalized_value=-1), UUID('11f50354-3c6a-4664-8f47-4392c762dcff'): NumericalModifier(name='strength_saving_throw Saving Throw Bonus_base_value', uuid=UUID('11f50354-3c6a-4664-8f47-4392c762dcff'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020503E325C0>, normalized_value=0), UUID('50739a9f-e672-4232-bc2e-f61032c8a4b6'): NumericalModifier(name='a past in the circus', uuid=UUID('50739a9f-e672-4232-bc2e-f61032c8a4b6'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'): NumericalModifier(name='level 4 talent', uuid=UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('3f50cdc4-8424-422d-923a-f8eed9a20683'): NumericalModifier(name='strength Modifier  ...

# %%
warrior2.saving_throw(strength_saving_throw_request)
# Out:
# Target AC: 12
# Attack bonus: 4
# Roll result: 15, Roll total: 19 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('dbcc57cf-0c51-4fdd-bae6-658f7200cfb4'), dice_uuid=UUID('142921e7-ae8d-4c22-8c5d-fa51a882e33d'), roll_type=<RollType.ATTACK: 'Attack'>, results=15, total=19, bonus=4, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  True)

# %%
from dnd.conditions import Blinded
from dnd.core.events import EventQueue


blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# ConditionApplicationEvent(name='Condition Application', uuid=UUID('f4c4c221-eae9-4af2-a17f-72d3c7c90a3a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, lineage_uuid=UUID('a2144be8-bb32-4ed0-8e48-54f8b9f10a6c'), timestamp=datetime.datetime(2025, 5, 2, 2, 48, 27, 470883), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], condition=Blinded(name='Blinded', uuid=UUID('de5962f4-cf6f-463d-9ad2-c135f449b46f'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('25ddb701-e5a8-4128-b9f1-84ce10c414a3'), source_entity_uuid=UUID('7a3c9003-5dca-43b2-8b09-e1a99620ef35'), source_entity_name=None, target_entity_uuid=UUID('c92ab417-b353-458e-a7a0-edf3a1215c9a'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('de5962f4-cf6f-463d-9ad2-c135f449b46f'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('e0f38632-eeba-4c7d-98fc-238e5fe07f01'): [UUID('a2d38b02-f5a5-4db7-936f-8397208e8912')], UUID('253a0773-2c27-4a44-87af-eeb742b4cfe0'): [UUID('b813d20c-baa9-4dfa-bb25-494507ab378d')], UUID('14724d35-39e3-4410-88ba-8b11d271527e'): [UUID('f08dbc1b-b1bd-4c49-a903-f7df91137c6a')], UUID('4825901c-cd7a-4c9e-bef7-0a972b66eeab'): [UUID('48a15abe-6bde-4ecd-8827-cc1fbf6bcaff')], UUID('7ab59a5a-ea5c-4172-9090-c00baf976f06'): [UUID('024762b5-b5d0-4eee-bd3e-68d2c3d711e0')], UUID('12b6d21d-67d4-47a9-a685-8751bbf3487e'): [UUID('4aa4cf8e-0abb-4a69-bd6e-b3989b2cdf87')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description="A blinded creature can't see and automatically fails any ability check that requires sight. Attack rolls against the creature have advantage, and the creature's attack rolls have disadvantage."))

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('4bb10d71-7d61-4ca6-b642-c0b18f4d8df2'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('0cc18472-704c-4e43-8811-2ce9dd1d17be'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'): NumericalModifier(name='level 4 talent', uuid=UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('53847059-efd7-43a0-a9a5-5850312fbc06'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 4, Roll total: 7 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('6d14fedd-0e58-4e7d-bbcb-a1ea41126525'), dice_uuid=UUID('abd8edf9-8811-43c7-8813-de782d292982'), roll_type=<RollType.ATTACK: 'Attack'>, results=4, total=7, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  [])

# %%
warrior.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior.attack(warrior2.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('19c859c7-3d49-4e09-93db-578b41721c8a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9e9b4fd2-2319-41aa-9206-601056ace7be'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6a3be04-0564-4172-8f08-98281573a160'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6a3be04-0564-4172-8f08-98281573a160'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'): NumericalModifier(name='level 4 talent', uuid=UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b402833f-c481-42fa-8dfa-04ec8595ffb0'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 16, Roll total: 21 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# Total Health before taking damage: 50
# Damage Roll result: [4], Roll total: 10
# Total Health after taking damage: 41
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('ba164f59-f776-4951-90d1-49b66406478c'), dice_uuid=UUID('66a3ea82-270e-4e1e-b8d3-00b6062c0ed2'), roll_type=<RollType.ATTACK: 'Attack'>, results=16, total=21, bonus=5, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), attack_outcome=None),
#  [(Damage(name='Damage', uuid=UUID('746e9dfc-84a5-4ee2-8176-8dd91a485a03'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('01ceca20-9912-4994-aa34-6d511dfdb5c5'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4EB60>, generated_from=[UUID('fe28189c-39cd-4171-9174-814b3eb16dc4'), UUID('44afc976-19a7-4d47-9e3c-9e1da2675252'), UUID('c6661f95-e971-4f85-8ec7-7e11dc5364e3'), UUID('fa895dfb-3325-485e-81f7-4213176311b2')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('32ff0df0-166a-4e90-b4a0-1233b2bae04d'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4EB60>, generated_from=[UUID('9a4e908a-4acc-4a8e-bb0b-214dc008d655'), UUID('96224fdf-4af0-449d-bef4-d12f3b6b2b3e'), UUID('b29c73fc-9e3a-43e1-a749-5c033686a970'), UUID('2a109242-bb0f-4c74-bf3d-2b744213539d')], global_normalizer=False, value_modifiers={UUID('c00c3b73-aaeb-42de-833e-e4b5e6549660'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('c00c3b73-aaeb-42de-833e-e4b5e6549660'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4EB60>, normalized_value=1), UUID('47d56bf8-9168-43c0-a103-0b7921ce5c5a'): NumericalModifier(name='a past in the circus', uuid=UUID('47d56bf8-9168-43c0-a103-0b7921ce5c5a'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('fc9f280e-1e3e-41c1-9bae-1772fc3a543f'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('fc9f280e-1e3e-41c1-9bae-1772fc3a543f'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4E2A0>, normalized_value=0), UUID('3ed84fa4-ab86-4ba5-9ec5-f22fd730c4a2'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('3ed84fa4-ab86-4ba5-9ec5-f22fd730c4a2'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020502D4E7A0>, normalized_value=0), UUID('a6a3be04-0564-4172-8f08-98281573a160'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6a3be04-0564-4172-8f08-98281573a160'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619'): NumericalModifier(name='level 4 talent', uuid=UUID('ddee7a36-ffcc-43a2-8c80-98fe3c91e619' ...
#    DiceRoll(roll_uuid=UUID('529c49f7-4e7a-4bf2-b7ad-0be9bda6d711'), dice_uuid=UUID('4913f59e-cf7a-4f3b-8bea-c98ef4f51be3'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[4], total=10, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
blinded.modifers_uuids
# Out:
# {UUID('e0f38632-eeba-4c7d-98fc-238e5fe07f01'): [UUID('a2d38b02-f5a5-4db7-936f-8397208e8912')],
#  UUID('253a0773-2c27-4a44-87af-eeb742b4cfe0'): [UUID('b813d20c-baa9-4dfa-bb25-494507ab378d')],
#  UUID('14724d35-39e3-4410-88ba-8b11d271527e'): [UUID('f08dbc1b-b1bd-4c49-a903-f7df91137c6a')],
#  UUID('4825901c-cd7a-4c9e-bef7-0a972b66eeab'): [UUID('48a15abe-6bde-4ecd-8827-cc1fbf6bcaff')],
#  UUID('7ab59a5a-ea5c-4172-9090-c00baf976f06'): [UUID('024762b5-b5d0-4eee-bd3e-68d2c3d711e0')],
#  UUID('12b6d21d-67d4-47a9-a685-8751bbf3487e'): [UUID('4aa4cf8e-0abb-4a69-bd6e-b3989b2cdf87')]}

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 16, Roll total: 16 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('98ad7416-b1ad-4f45-939d-7c3ae6b86a30'), dice_uuid=UUID('bea86540-2630-4257-9d0d-2c2878a0c548'), roll_type=<RollType.ATTACK: 'Attack'>, results=16, total=16, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  False)

# %%
blinded.remove()
# Out:
# False

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 19, Roll total: 19 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('95514a04-3c00-4fc4-adc1-eebc17e1694d'), dice_uuid=UUID('f6fd5792-da43-4354-99ee-3f76a51213e9'), roll_type=<RollType.ATTACK: 'Attack'>, results=19, total=19, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  False)

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('4bb10d71-7d61-4ca6-b642-c0b18f4d8df2'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('0cc18472-704c-4e43-8811-2ce9dd1d17be'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'): NumericalModifier(name='level 4 talent', uuid=UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('53847059-efd7-43a0-a9a5-5850312fbc06'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 5, Roll total: 8 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('3db0883a-4cec-40b4-87ca-e6a77908a271'), dice_uuid=UUID('c9f50d81-6dfe-4a7c-941d-df7bdc6fbc45'), roll_type=<RollType.ATTACK: 'Attack'>, results=5, total=8, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  [])

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()
# Out:
# ConditionApplicationEvent(name='Condition Application', uuid=UUID('c12dbfcd-bc54-4aa3-9660-cf15b85695b7'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, lineage_uuid=UUID('b7d770b4-be80-43d5-8176-7baae8b8dd41'), timestamp=datetime.datetime(2025, 5, 2, 2, 48, 27, 617995), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], condition=Charmed(name='Charmed', uuid=UUID('fddfbac6-61cf-4d92-ae40-d6bcf9e29b1d'), source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('b7bd3e47-ff79-4e0b-b60b-87a6f96c60a2'), source_entity_uuid=UUID('078b8217-1e15-4506-a6ce-030079d5e981'), source_entity_name=None, target_entity_uuid=UUID('ea41358a-524e-47d0-8d67-b2c7dac0cf0e'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('fddfbac6-61cf-4d92-ae40-d6bcf9e29b1d'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('e0f38632-eeba-4c7d-98fc-238e5fe07f01'): [UUID('a844f61e-3567-49ba-b6e9-8b28b1825a25')], UUID('6183766e-4783-4b87-ba0e-732ca701a82d'): [UUID('67ca9c61-9f7a-4e24-97e4-536f4190e975')], UUID('cc305a6e-0a8f-4398-aa16-cda4f24272cd'): [UUID('a83d9ee6-589c-4ab5-8f23-9f38737448f0')], UUID('4a89a09e-2636-4f7a-b1bf-5bfcd4c7fb8a'): [UUID('2bc8f6ef-b843-4943-a028-a887031f8022')], UUID('676541a9-7823-4902-8ce8-bf7fefed02e2'): [UUID('90713d09-3354-4713-8fe8-fdc5555601f8')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description="A charmed creature can't attack the charmer or target the charmer with harmful abilities or magical effects."))

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('4bb10d71-7d61-4ca6-b642-c0b18f4d8df2'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('0cc18472-704c-4e43-8811-2ce9dd1d17be'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('511eae66-7773-4ef1-aef3-edce45d18c1b'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, normalized_value=2), UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'): NumericalModifier(name='level 4 talent', uuid=UUID('b774c9b9-dccc-409d-bd24-098112c3a30c'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('53847059-efd7-43a0-a9a5-5850312fbc06'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002050121D080>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# charmer_id: ab2b9121-e849-463c-9d41-cc35738901d8, source_entity_uuid: 4afd89dc-685e-45b7-9746-80c5c6d769c9, target_entity_uuid: ab2b9121-e849-463c-9d41-cc35738901d8
# Target AC: 12
# Attack bonus: 3
# Roll result: 17, Roll total: 20 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('30dc059b-54e6-4551-8106-1fc8848ecef2'), dice_uuid=UUID('e4d336c3-4a6c-4a19-8957-e88055942187'), roll_type=<RollType.ATTACK: 'Attack'>, results=17, total=20, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), attack_outcome=None),
#  [])

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)
# Out:
# charmer_id: ab2b9121-e849-463c-9d41-cc35738901d8,charmed_id: 4afd89dc-685e-45b7-9746-80c5c6d769c9, source_entity_uuid: 4afd89dc-685e-45b7-9746-80c5c6d769c9, target_entity_uuid: ab2b9121-e849-463c-9d41-cc35738901d8
# charmer_id: ab2b9121-e849-463c-9d41-cc35738901d8,charmed_id: 4afd89dc-685e-45b7-9746-80c5c6d769c9, source_entity_uuid: 4afd89dc-685e-45b7-9746-80c5c6d769c9, target_entity_uuid: ab2b9121-e849-463c-9d41-cc35738901d8
# Target AC: 15
# Attack bonus: 0
# Roll result: 3, Roll total: 3 vs target ac: 15 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# charmer_id: ab2b9121-e849-463c-9d41-cc35738901d8,charmed_id: 4afd89dc-685e-45b7-9746-80c5c6d769c9, source_entity_uuid: 4afd89dc-685e-45b7-9746-80c5c6d769c9, target_entity_uuid: ab2b9121-e849-463c-9d41-cc35738901d8
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('861ab213-2f60-43b2-a7d3-cd87163af82c'), dice_uuid=UUID('7a60d62c-4d9c-464d-a1de-420950027270'), roll_type=<RollType.ATTACK: 'Attack'>, results=3, total=3, bonus=0, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), attack_outcome=None),
#  False)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)
# Out:
# UUID('a915deda-58d2-44cc-bfd6-9f2141322c22')

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score
# Out:
# 5

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score
# Out:
# 0

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()
# Out:
# ConditionApplicationEvent(name='Condition Application', uuid=UUID('37f4328a-3ae3-48aa-b9f5-0b00af2bdcda'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, lineage_uuid=UUID('eb335854-4e6b-47b7-a244-f78243ab6e80'), timestamp=datetime.datetime(2025, 5, 2, 2, 48, 27, 701722), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], condition=Frightened(name='Frightened', uuid=UUID('5352491b-71ca-4e1a-936b-479353a00cf4'), source_entity_uuid=UUID('4afd89dc-685e-45b7-9746-80c5c6d769c9'), source_entity_name=None, target_entity_uuid=UUID('ab2b9121-e849-463c-9d41-cc35738901d8'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('2582212a-1e8f-4c2b-9dc3-c237e5a29fb9'), source_entity_uuid=UUID('f1b4442d-7065-4e4a-b2d4-f8a31bda0bdc'), source_entity_name=None, target_entity_uuid=UUID('2a8b7729-c9ea-46af-9a6b-917d81258b38'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('5352491b-71ca-4e1a-936b-479353a00cf4'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('87024b84-5b9c-4640-ab18-9e731a2d7e46'): [UUID('a445fc1c-db6c-48b4-90db-a7c0256a8460')], UUID('ca44f8ec-2e51-4aa9-9ac8-034ec20659f7'): [UUID('5b333253-dbd9-4eae-818c-56838043bafc')], UUID('892f693e-1fe8-48ce-b9a4-18742d548387'): [UUID('962d20b3-bfbf-4bd7-95b1-83de6c5d2c3a')], UUID('92b57827-7508-4b05-817b-ca14ed7f5da9'): [UUID('41e3dee9-9b46-43e4-8fa8-d2ccda92a55c')], UUID('0151545b-1e78-4077-ad32-0b2d5458e47e'): [UUID('14824cea-d6a7-45bf-82c1-380f1fef47a4')], UUID('04be4331-a8c2-4768-ae7c-8a0adec3987f'): [UUID('68d9427f-c812-4942-832f-9c4dbc0cd155')], UUID('ca37ee8a-8288-4dbc-a7a3-56a3f676a63b'): [UUID('93d49591-9251-4ca4-a48a-6df7b1d71943')], UUID('879f4e98-999b-4421-8d34-2c9d0ba03ac1'): [UUID('c0436d8a-322d-43cb-b18f-33309d7accc6')], UUID('c46d26c2-eab2-49c4-815b-8333ffb0db85'): [UUID('3d1959a8-ef57-431c-81a3-a0965f6590e6')], UUID('aed21424-4dfb-4cf3-bbb4-a33725f216a0'): [UUID('97604b80-777e-4c0f-88f5-12296d8438c9')], UUID('71719bed-9743-4f69-8425-357b3659dbe1'): [UUID('58c8a998-ea8b-44a7-ab2c-353df6ae261d')], UUID('09a0893f-79c1-4f38-96f2-2c48a02ccd20'): [UUID('bee69292-3d58-4095-8759-3546406eb0e8')], UUID('5a9fe0da-ebb2-4457-bd70-9817f7fccdd5'): [UUID('771f2e6d-8001-4ae6-a52b-de58ab8fb67d')], UUID('59ed5ae8-2468-4a6f-aaea-2bcf356db820'): [UUID('1ce86fcf-c3dc-4dbf-aa32-a7e0b0598837')], UUID('6326e14d-d113-468d-ad01-ffe5d0b9cda2'): [UUID('ea078cf9-4f44-48d5-968c-32d47b3bfabd')], UUID('16bc324d-28c3-4054-ac1b-accd7ee8afe4'): [UUID('3a7b4e2c-c71b-410b-9381-384e3d42c715')], UUID('8d31fa78-33b7-4552-bb1f-beecbe31aef8'): [UUID('5799c449-be8a-492c-af5a-41158407be79')], UUID('d078f66f-a88d-49ce-835d-a8e26e864408'): [UUID('fe60c9bb-39ba-494f-a650-a3e915dd0ddc')], UUID('a470d169-a998-425d-9569-006ac20aa325'): [UUID('bd70bac1-2ccc-4b90-bda4-2bce498b1b02')], UUID('2e4231f6-5026-415b-87d2-0a8382f7bfcb'): [UUID('2e4231f6-5026-415b-87d2-0a8382f7bfcb')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='A frightened creature has disadvantage on attack rolls and ability checks and can not move while the frightener is in sight'))

# %%
warrior.action_economy.movement.normalized_score
# Out:
# 0

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score
# Out:
# 30

# %%
print(f"total_time: {time.time()-start_time}")
# Out:
# total_time: 0.5960943698883057
