# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4
from dnd.core.events import EventQueue

import time

# %%
start_time = time.time()
source_id = uuid4()
proficiency_bonus = 2

# %%
q = EventQueue()

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior(name="Mona")

# %%
warrior.source_entity_uuid
# Out:
# UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('a0cad6e1-c99f-421b-b548-b136178e959e')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('a0cad6e1-c99f-421b-b548-b136178e959e'): AbilityScores(name='ability_scores', description=None, uuid=UUID('a0cad6e1-c99f-421b-b548-b136178e959e'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('32ad455d-582c-4eed-8f6a-5b0f4e2515a3'): Ability(name='strength', description=None, uuid=UUID('32ad455d-582c-4eed-8f6a-5b0f4e2515a3'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('098c8949-9bbd-46fb-bfd3-3ca9a97afe3a'): ModifiableValue(name='strength Ability Score', uuid=UUID('098c8949-9bbd-46fb-bfd3-3ca9a97afe3a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e6e2a8e2-ac64-4862-885f-1a606f282131'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'): NumericalModifier(name='level 4 talent', uuid=UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Damag ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('098c8949-9bbd-46fb-bfd3-3ca9a97afe3a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e6e2a8e2-ac64-4862-885f-1a606f282131'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'): NumericalModifier(name='level 4 talent', uuid=UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('3d380691-78fd-4244-880b-9f90fc855f18'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 6

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 1

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.0009987354278564453

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('098c8949-9bbd-46fb-bfd3-3ca9a97afe3a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e6e2a8e2-ac64-4862-885f-1a606f282131'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'): NumericalModifier(name='level 4 talent', uuid=UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('3d380691-78fd-4244-880b-9f90fc855f18'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.000997304916381836

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0005004405975341797

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 2, Roll total: 7 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0005004405975341797

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Damage Roll result: [1], Roll total: 7
# Total Health after taking damage: 52
# 0.0004985332489013672

# %%
damages
# Out:
# [Damage(name='Damage', uuid=UUID('7ca49292-dc24-4f0a-a932-64a4c7b4a096'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('44cda971-469d-4b96-beb4-800d049909f1'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F1300>, generated_from=[UUID('266439fb-82dc-4277-b452-1447e30fc8cd'), UUID('acb542af-2f3d-4c2c-922b-eb051139d53b'), UUID('1eee4a50-6d60-4463-851d-20340c48abbc'), UUID('524dd2de-4d2c-4ad6-98dc-c6147697bee5')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('9dac432a-66a9-4299-8b88-13f27155044a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F1300>, generated_from=[UUID('e7c82340-500a-4eaa-a991-f87be199381e'), UUID('5620ca5f-3154-441e-8637-83abee887c71'), UUID('3d735b97-1f85-4f71-99f0-7d24cf2518a0'), UUID('096e0b18-5e94-4aba-89b4-6fe947faf605')], global_normalizer=False, value_modifiers={UUID('49c4d39e-22e4-4996-9e39-d38ff6592f8c'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('49c4d39e-22e4-4996-9e39-d38ff6592f8c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F1300>, normalized_value=1), UUID('30b30cae-4b90-44d3-a859-815c95fb2941'): NumericalModifier(name='a past in the circus', uuid=UUID('30b30cae-4b90-44d3-a859-815c95fb2941'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('8a566dc1-7d00-475e-a73c-1aad55674d3a'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('8a566dc1-7d00-475e-a73c-1aad55674d3a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F0A40>, normalized_value=0), UUID('ac4f1adf-5e90-40f2-8d0b-1020b9cfc8a2'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('ac4f1adf-5e90-40f2-8d0b-1020b9cfc8a2'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F0F40>, normalized_value=0), UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'): NumericalModifier(name='level 4 talent', uuid=UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, targ ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0014989376068115234

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.002496004104614258

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0019965171813964844

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('098c8949-9bbd-46fb-bfd3-3ca9a97afe3a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e6e2a8e2-ac64-4862-885f-1a606f282131'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'): NumericalModifier(name='level 4 talent', uuid=UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('3d380691-78fd-4244-880b-9f90fc855f18'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 5, Roll total: 10 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.010999917984008789

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request
# Out:
# SkillCheckEvent(name='Skill Check', uuid=UUID('8560f0bf-1932-4421-8db4-bdf6a2c73818'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, lineage_uuid=UUID('de4506ef-1068-4e3e-b031-046f32be90fc'), timestamp=datetime.datetime(2025, 5, 3, 15, 10, 28, 800700), event_type=<EventType.SKILL_CHECK: 'skill_check'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], dc=12, bonus=0, dice=None, dice_roll=None, result=None, skill_name='acrobatics')

# %%
strength_saving_throw_request
# Out:
# SavingThrowEvent(name='Saving Throw', uuid=UUID('580e3434-b304-4fc4-8d47-ff41865ad9f4'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, lineage_uuid=UUID('d2014f48-d52b-4663-8766-ee203c840666'), timestamp=datetime.datetime(2025, 5, 3, 15, 10, 28, 807199), event_type=<EventType.SAVING_THROW: 'saving_throw'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], dc=12, bonus=0, dice=None, dice_roll=None, result=None, ability_name='strength')

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")
# Out:
# ModifiableValue(name='Value_acrobatics Skill Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('17e70566-bbb0-4065-a756-30d1bf5b799c'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000002C814B3DA80>, generated_from=[UUID('dc995656-12a0-4345-a959-a6c9142848dd'), UUID('866896e9-546d-4b53-b2f3-e3485c2b20e8'), UUID('47d8cad0-d966-4a00-b35e-8f33165d81a6'), UUID('164de9bd-7768-4924-ac37-1a7ae8cba590')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('6d80d189-d3c3-49cc-b75f-87e29e2ffb78'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000002C814B3DA80>, generated_from=[UUID('b865cd97-003b-49d3-9b3f-9d01b134c2b0'), UUID('754b74ec-9729-4cee-9379-757629d4bf05'), UUID('e3b0f9db-ccd5-46b2-8904-f3aa148b4b2e'), UUID('20d6b6ed-8bf2-42d5-9ca2-b62ce0d28437')], global_normalizer=False, value_modifiers={UUID('4fad4725-b603-48e2-a728-0b2df75f18bd'): NumericalModifier(name='Value_base_value', uuid=UUID('4fad4725-b603-48e2-a728-0b2df75f18bd'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000002C814B3DA80>, normalized_value=0), UUID('6c341c17-1226-4b6a-841b-e759cb79921d'): NumericalModifier(name='a past in the circus', uuid=UUID('6c341c17-1226-4b6a-841b-e759cb79921d'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000002C814B3DA80>, normalized_value=-2), UUID('cbc87dba-9c33-4ded-a643-f4725019a43c'): NumericalModifier(name='acrobatics Skill Bonus_base_value', uuid=UUID('cbc87dba-9c33-4ded-a643-f4725019a43c'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F2B60>, normalized_value=0), UUID('b3240205-5eef-4f28-9317-ed21b3d90844'): NumericalModifier(name='a past in the circus', uuid=UUID('b3240205-5eef-4f28-9317-ed21b3d90844'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=7, score_normalizer=None, normalized_value=7), UUID('7e48b19d-3a54-4360-aa0e-4b1ee07d2055'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('7e48b19d-3a54-4360-aa0e-4b1ee07d2055'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=12, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=1), UUID('9571857c-4856-44e4-81eb-587288238cf9'): NumericalModifier(name='strength Modifier Bonus_base_value', uuid=UUID('9571857c-4856-44e4-81eb-587288238cf9'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F1EE0>, normalized_value=0)}, min_constraints={}, max_co ...

# %%
warrior2.skill_check(acrobatics_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 6
# Roll result: 15, Roll total: 21 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('577006f7-db40-40e1-a45f-b34e2d01473e'), dice_uuid=UUID('37a71bb9-34f7-483c-9d87-4f1c342df571'), roll_type=<RollType.ATTACK: 'Attack'>, results=15, total=21, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  True)

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 20, Roll total: 20 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.CRIT: 'Crit'>,
#  DiceRoll(roll_uuid=UUID('a8cb8f5d-665e-4f90-a049-a50e9304980c'), dice_uuid=UUID('946a29bb-31aa-45bd-a3a7-9f8eaf80f4d0'), roll_type=<RollType.ATTACK: 'Attack'>, results=20, total=20, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  True)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")
# Out:
# ModifiableValue(name='Value_strength_saving_throw Saving Throw Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('dd288655-ea45-4034-9d64-2b96f426a243'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000002C814B3DB20>, generated_from=[UUID('dc995656-12a0-4345-a959-a6c9142848dd'), UUID('bc8de3a7-1f2f-4812-bfa1-daaf57d86f0f'), UUID('89106ec1-c11e-4304-8ee1-9cd60ac78f95'), UUID('ef059b8d-7132-4d7c-955e-b48eed40d042')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('232f0037-9660-4d2e-958a-6492a750022b'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000002C814B3DB20>, generated_from=[UUID('b865cd97-003b-49d3-9b3f-9d01b134c2b0'), UUID('60c2f6fa-d657-43b6-97ae-a22f23fd212c'), UUID('cc789d79-e5e0-48d9-98d5-81b426b72c7a'), UUID('b0461c9b-c162-4ebd-afa5-e4ddc0688c94')], global_normalizer=False, value_modifiers={UUID('4fad4725-b603-48e2-a728-0b2df75f18bd'): NumericalModifier(name='Value_base_value', uuid=UUID('4fad4725-b603-48e2-a728-0b2df75f18bd'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000002C814B3DB20>, normalized_value=0), UUID('6c341c17-1226-4b6a-841b-e759cb79921d'): NumericalModifier(name='a past in the circus', uuid=UUID('6c341c17-1226-4b6a-841b-e759cb79921d'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000002C814B3DB20>, normalized_value=-1), UUID('bd30bcd7-88b6-4d3b-beb5-dec250fc427e'): NumericalModifier(name='strength_saving_throw Saving Throw Bonus_base_value', uuid=UUID('bd30bcd7-88b6-4d3b-beb5-dec250fc427e'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2CD60>, normalized_value=0), UUID('974cbce9-b63b-43d8-8ac1-2a4aad64e91e'): NumericalModifier(name='a past in the circus', uuid=UUID('974cbce9-b63b-43d8-8ac1-2a4aad64e91e'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'): NumericalModifier(name='level 4 talent', uuid=UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('e99460a7-6409-4788-b899-5f5875b8f413'): NumericalModifier(name='strength Modifier  ...

# %%
warrior2.saving_throw(strength_saving_throw_request)
# Out:
# Target AC: 12
# Attack bonus: 4
# Roll result: 18, Roll total: 22 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('2f688fcb-6f59-41b9-a3fc-b676dc118107'), dice_uuid=UUID('28f99dca-d272-4e6a-b391-02e96558d86a'), roll_type=<RollType.ATTACK: 'Attack'>, results=18, total=22, bonus=4, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  True)

# %%
from dnd.conditions import Blinded
from dnd.core.events import EventQueue


blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# ConditionApplicationEvent(name='Condition Application', uuid=UUID('625d7c94-e30e-4905-89a5-0db276525e4f'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, lineage_uuid=UUID('0bf1171c-69d3-41a4-aa6d-4b053051d1c8'), timestamp=datetime.datetime(2025, 5, 3, 15, 10, 29, 114487), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], condition=Blinded(name='Blinded', uuid=UUID('abd4e7aa-8719-4110-9549-b9afa8a975fa'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('99927b32-c148-4313-981e-6833056f4fc8'), source_entity_uuid=UUID('9f640c9c-20ba-4c6d-ac06-a99e593fca3e'), source_entity_name=None, target_entity_uuid=UUID('ee3a9002-2fac-47ac-a01e-b1fca4765fe2'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('abd4e7aa-8719-4110-9549-b9afa8a975fa'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('755e0188-11fe-4385-95e5-05a613743795'): [UUID('9ad2b924-8317-4fab-83f9-a2edf8903326')], UUID('698362a8-20e1-4c0a-8f2e-d105c4ab3d9d'): [UUID('3493a394-f6e0-45f3-9521-c69ff51ccb37')], UUID('b305a894-5d2c-4724-bd58-787e01d2287f'): [UUID('b005befd-136e-4b25-ba51-81c3632e9244')], UUID('bbf91af8-785b-487e-9b52-63edf67bcac9'): [UUID('769f9b1d-c6b9-4c5b-97f6-5b186b5d1b8b')], UUID('ab839eb8-219b-43bd-8e20-ba95e2b4ff6c'): [UUID('b3928ce0-8bd8-4d85-bf68-0c0f7c268908')], UUID('992a5a3c-c39d-4fa6-bf7d-b48f8bce9255'): [UUID('30dfc006-3288-43e2-9c92-e98d42fbcaf8')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description="A blinded creature can't see and automatically fails any ability check that requires sight. Attack rolls against the creature have advantage, and the creature's attack rolls have disadvantage."))

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('89106ec1-c11e-4304-8ee1-9cd60ac78f95'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('cc789d79-e5e0-48d9-98d5-81b426b72c7a'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'): NumericalModifier(name='level 4 talent', uuid=UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('dc4137ef-3822-4c8e-8cf4-0ebff0be2351'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 20, Roll total: 23 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# Total Health before taking damage: 58
# Damage Roll result: [1, 2], Roll total: 9
# Total Health after taking damage: 50
# (<AttackOutcome.CRIT: 'Crit'>,
#  DiceRoll(roll_uuid=UUID('1e6b009f-9f7d-40d2-b365-ef510ed67656'), dice_uuid=UUID('529a769e-bfdb-4a1f-8012-288350e613e4'), roll_type=<RollType.ATTACK: 'Attack'>, results=20, total=23, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  [(Damage(name='Damage', uuid=UUID('dd73edc2-89da-451c-b358-9d853a13a6cb'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('d51a400d-1827-4de2-8748-639131716028'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EE80>, generated_from=[UUID('d3279f1f-f66f-45fc-b086-eb60ca94eae5'), UUID('eb2d98a6-65d4-4fce-b44d-ee02631a6d52'), UUID('09b42e16-7683-4724-8a10-52c7aa47921b'), UUID('6b3c9d22-efe9-43ee-b91b-0ac44c180813')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('7c9e4f6f-4641-4c6a-b844-35e518973bac'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EE80>, generated_from=[UUID('ad100796-50e7-40ef-a18f-1743116698f6'), UUID('57c4427b-111f-40d3-992b-0d50ff98f4d1'), UUID('27ae1804-462c-4cc4-bd8f-d3c7bafc89ec'), UUID('1236d47a-2220-4867-adc2-77ba640c3ff9')], global_normalizer=False, value_modifiers={UUID('b7f8c45a-1a29-48c5-9418-ad2f4c06f56e'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('b7f8c45a-1a29-48c5-9418-ad2f4c06f56e'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EE80>, normalized_value=1), UUID('2c27fc59-884e-44a3-9335-38ecb76bf475'): NumericalModifier(name='a past in the circus', uuid=UUID('2c27fc59-884e-44a3-9335-38ecb76bf475'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('3ce3e77f-b78d-452b-84eb-22d5c53a0180'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('3ce3e77f-b78d-452b-84eb-22d5c53a0180'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2E5C0>, normalized_value=0), UUID('a39f1079-5c8c-40d4-9191-e575fddb1c88'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('a39f1079-5c8c-40d4-9191-e575fddb1c88'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EAC0>, normalized_value=0), UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'): NumericalModifier(name='level 4 talent', uuid=UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597' ...
#    DiceRoll(roll_uuid=UUID('5472f128-10d7-4b8a-8946-b869be1addac'), dice_uuid=UUID('50c8fb17-8048-4629-8ae0-eb6f77d68cb0'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[1, 2], total=9, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=<AttackOutcome.CRIT: 'Crit'>))])

# %%
warrior.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior.attack(warrior2.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('098c8949-9bbd-46fb-bfd3-3ca9a97afe3a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e6e2a8e2-ac64-4862-885f-1a606f282131'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'): NumericalModifier(name='level 4 talent', uuid=UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('3d380691-78fd-4244-880b-9f90fc855f18'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 11, Roll total: 16 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# Total Health before taking damage: 52
# Damage Roll result: [4], Roll total: 10
# Total Health after taking damage: 43
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('0370446a-e3c2-4c64-9f88-d06afd0d12df'), dice_uuid=UUID('1c4bc559-086e-48b8-b6d1-02fa16d1d878'), roll_type=<RollType.ATTACK: 'Attack'>, results=11, total=16, bonus=5, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), attack_outcome=None),
#  [(Damage(name='Damage', uuid=UUID('0c96c93b-5d2e-4b3c-b758-c7cdf4784f7c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('b992c01e-3398-4aef-a16c-e149b1444454'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F1300>, generated_from=[UUID('266439fb-82dc-4277-b452-1447e30fc8cd'), UUID('acb542af-2f3d-4c2c-922b-eb051139d53b'), UUID('1eee4a50-6d60-4463-851d-20340c48abbc'), UUID('22ee0e59-f1e8-49a3-893e-36a0df6c43c0')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('c5e5dc26-61c7-43f5-bfd8-ac00a1e2cee5'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F1300>, generated_from=[UUID('e7c82340-500a-4eaa-a991-f87be199381e'), UUID('5620ca5f-3154-441e-8637-83abee887c71'), UUID('3d735b97-1f85-4f71-99f0-7d24cf2518a0'), UUID('019d126d-8b49-4d2c-910d-57e8508d1c75')], global_normalizer=False, value_modifiers={UUID('49c4d39e-22e4-4996-9e39-d38ff6592f8c'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('49c4d39e-22e4-4996-9e39-d38ff6592f8c'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F1300>, normalized_value=1), UUID('30b30cae-4b90-44d3-a859-815c95fb2941'): NumericalModifier(name='a past in the circus', uuid=UUID('30b30cae-4b90-44d3-a859-815c95fb2941'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('8a566dc1-7d00-475e-a73c-1aad55674d3a'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('8a566dc1-7d00-475e-a73c-1aad55674d3a'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F0A40>, normalized_value=0), UUID('ac4f1adf-5e90-40f2-8d0b-1020b9cfc8a2'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('ac4f1adf-5e90-40f2-8d0b-1020b9cfc8a2'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C8148F0F40>, normalized_value=0), UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('3bfa8370-3c96-48d5-9435-fd2fc4eb14c7'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c'): NumericalModifier(name='level 4 talent', uuid=UUID('72bcf8f9-2327-4200-a017-51f1f2cdef6c' ...
#    DiceRoll(roll_uuid=UUID('b6a82ea4-21c9-44b2-9486-0d1f8c45b24e'), dice_uuid=UUID('fb6030ea-350f-450c-9e7a-57a4c7f8d160'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[4], total=10, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
blinded.modifers_uuids
# Out:
# {UUID('755e0188-11fe-4385-95e5-05a613743795'): [UUID('9ad2b924-8317-4fab-83f9-a2edf8903326')],
#  UUID('698362a8-20e1-4c0a-8f2e-d105c4ab3d9d'): [UUID('3493a394-f6e0-45f3-9521-c69ff51ccb37')],
#  UUID('b305a894-5d2c-4724-bd58-787e01d2287f'): [UUID('b005befd-136e-4b25-ba51-81c3632e9244')],
#  UUID('bbf91af8-785b-487e-9b52-63edf67bcac9'): [UUID('769f9b1d-c6b9-4c5b-97f6-5b186b5d1b8b')],
#  UUID('ab839eb8-219b-43bd-8e20-ba95e2b4ff6c'): [UUID('b3928ce0-8bd8-4d85-bf68-0c0f7c268908')],
#  UUID('992a5a3c-c39d-4fa6-bf7d-b48f8bce9255'): [UUID('30dfc006-3288-43e2-9c92-e98d42fbcaf8')]}

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 6, Roll total: 6 vs target ac: 12 result: False auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('c1da1a15-a274-418d-ba88-0889b9bb8eec'), dice_uuid=UUID('f41f28d6-3b27-4cd2-b1a5-634f27910928'), roll_type=<RollType.ATTACK: 'Attack'>, results=6, total=6, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  False)

# %%
blinded.remove()
# Out:
# True

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 4, Roll total: 4 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('e34622a7-4374-40e6-a667-ddb63bcd632d'), dice_uuid=UUID('f23a771d-292f-486f-af52-e65727696611'), roll_type=<RollType.ATTACK: 'Attack'>, results=4, total=4, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  False)

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('89106ec1-c11e-4304-8ee1-9cd60ac78f95'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('cc789d79-e5e0-48d9-98d5-81b426b72c7a'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'): NumericalModifier(name='level 4 talent', uuid=UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('dc4137ef-3822-4c8e-8cf4-0ebff0be2351'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 12, Roll total: 15 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 50
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 42
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('20340139-b76c-4866-b8ce-08fb02338cc4'), dice_uuid=UUID('a21a1324-e241-4568-81e5-b408ccc75899'), roll_type=<RollType.ATTACK: 'Attack'>, results=12, total=15, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  [(Damage(name='Damage', uuid=UUID('eb28b510-a411-4d63-85b9-94277f2c3923'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('06e0d683-6f51-462c-8055-9d52e0593cdd'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EE80>, generated_from=[UUID('d3279f1f-f66f-45fc-b086-eb60ca94eae5'), UUID('eb2d98a6-65d4-4fce-b44d-ee02631a6d52'), UUID('09b42e16-7683-4724-8a10-52c7aa47921b'), UUID('8f785fff-ec6e-4af4-91a6-7b73687920cb')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('96f53e54-a17b-4268-97c5-d8ee46ae2730'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EE80>, generated_from=[UUID('ad100796-50e7-40ef-a18f-1743116698f6'), UUID('57c4427b-111f-40d3-992b-0d50ff98f4d1'), UUID('27ae1804-462c-4cc4-bd8f-d3c7bafc89ec'), UUID('31a422fe-18bf-4ec6-8a8d-4cae08b5634d')], global_normalizer=False, value_modifiers={UUID('b7f8c45a-1a29-48c5-9418-ad2f4c06f56e'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('b7f8c45a-1a29-48c5-9418-ad2f4c06f56e'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EE80>, normalized_value=1), UUID('2c27fc59-884e-44a3-9335-38ecb76bf475'): NumericalModifier(name='a past in the circus', uuid=UUID('2c27fc59-884e-44a3-9335-38ecb76bf475'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('3ce3e77f-b78d-452b-84eb-22d5c53a0180'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('3ce3e77f-b78d-452b-84eb-22d5c53a0180'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2E5C0>, normalized_value=0), UUID('a39f1079-5c8c-40d4-9191-e575fddb1c88'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('a39f1079-5c8c-40d4-9191-e575fddb1c88'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002C814A2EAC0>, normalized_value=0), UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'): NumericalModifier(name='level 4 talent', uuid=UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597' ...
#    DiceRoll(roll_uuid=UUID('9a4634aa-f246-43dd-b912-c5bc014d728c'), dice_uuid=UUID('ce862bad-8067-4725-a996-612ead3b238e'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[3], total=9, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()
# Out:
# ConditionApplicationEvent(name='Condition Application', uuid=UUID('7c7100d5-e0a6-4274-a6dc-635cf24924fc'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, lineage_uuid=UUID('366661a7-fb8e-4be0-8681-ede5c6ebf5de'), timestamp=datetime.datetime(2025, 5, 3, 15, 10, 29, 275994), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], condition=Charmed(name='Charmed', uuid=UUID('855ee092-cf52-458e-a246-862e22bf9141'), source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('bffbf07c-ac86-4c7d-9473-2e59c8535ad0'), source_entity_uuid=UUID('2a34a3d8-e866-48b4-a9d2-bdd34e5a7ce6'), source_entity_name=None, target_entity_uuid=UUID('3223f9a8-cf63-404b-8f14-640f9d1b46f2'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('855ee092-cf52-458e-a246-862e22bf9141'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('755e0188-11fe-4385-95e5-05a613743795'): [UUID('de291f90-9abf-4238-9814-5f3f0b13d34d')], UUID('5530e70d-8594-46d6-b215-696384b47ea5'): [UUID('44a581d6-15e2-43f5-ac6c-e16517ca71db')], UUID('7cb55da6-652f-4fd7-9e22-bb4e3d5bc84e'): [UUID('1e8c556a-abcc-4431-9485-64bf1b8c0c1e')], UUID('1c5c1ff4-7d5b-4f73-b2ca-894f5e8628a5'): [UUID('7533b089-98d6-4633-b978-dadca4ea8b96')], UUID('a4a53b3f-6956-4737-9e0a-b730bad0c00a'): [UUID('edb3be57-f70e-41a4-8e30-4dac6e091b16')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description="A charmed creature can't attack the charmer or target the charmer with harmful abilities or magical effects."))

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('89106ec1-c11e-4304-8ee1-9cd60ac78f95'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('cc789d79-e5e0-48d9-98d5-81b426b72c7a'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('0980c3ab-55a7-4600-8a80-1289acc1112f'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, normalized_value=2), UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'): NumericalModifier(name='level 4 talent', uuid=UUID('c25887d5-2c2a-4a06-b8bf-17f181c68597'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('dc4137ef-3822-4c8e-8cf4-0ebff0be2351'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000002C8119B7600>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# charmer_id: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050, source_entity_uuid: ef8843e1-24dc-4cf4-acdc-c1c37ecf666f, target_entity_uuid: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050
# Target AC: 12
# Attack bonus: 3
# Roll result: 2, Roll total: 5 vs target ac: 12 result: False auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('9bafc7b0-1119-4411-b751-d14c3cc9165d'), dice_uuid=UUID('98d288e0-d133-46c7-b6fb-15b43ddf4e59'), roll_type=<RollType.ATTACK: 'Attack'>, results=2, total=5, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), attack_outcome=None),
#  [])

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)
# Out:
# charmer_id: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050,charmed_id: ef8843e1-24dc-4cf4-acdc-c1c37ecf666f, source_entity_uuid: ef8843e1-24dc-4cf4-acdc-c1c37ecf666f, target_entity_uuid: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050
# charmer_id: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050,charmed_id: ef8843e1-24dc-4cf4-acdc-c1c37ecf666f, source_entity_uuid: ef8843e1-24dc-4cf4-acdc-c1c37ecf666f, target_entity_uuid: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050
# Target AC: 15
# Attack bonus: 0
# Roll result: 6, Roll total: 6 vs target ac: 15 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# charmer_id: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050,charmed_id: ef8843e1-24dc-4cf4-acdc-c1c37ecf666f, source_entity_uuid: ef8843e1-24dc-4cf4-acdc-c1c37ecf666f, target_entity_uuid: 9ddd8bbe-9cc7-461f-8fce-eee017f8e050
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('78bd84d8-df62-4b9d-b452-eceb694d873f'), dice_uuid=UUID('088c61bd-52a0-4fd8-9dd1-de9e8e6b2ae0'), roll_type=<RollType.ATTACK: 'Attack'>, results=6, total=6, bonus=0, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), attack_outcome=None),
#  False)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)
# Out:
# UUID('17d2d088-2c9f-44af-83a5-36bdda43c681')

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score
# Out:
# 5

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score
# Out:
# 0

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()
# Out:
# ConditionApplicationEvent(name='Condition Application', uuid=UUID('7d05cfa3-e99d-49d1-b2c5-e33a575b5755'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, lineage_uuid=UUID('9ea7d49f-e6fa-408e-997d-c758d5129d90'), timestamp=datetime.datetime(2025, 5, 3, 15, 10, 29, 375888), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, child_events=[], children_events=[], condition=Frightened(name='Frightened', uuid=UUID('62ead27d-c699-44c7-8e8b-039055a492c7'), source_entity_uuid=UUID('ef8843e1-24dc-4cf4-acdc-c1c37ecf666f'), source_entity_name=None, target_entity_uuid=UUID('9ddd8bbe-9cc7-461f-8fce-eee017f8e050'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('6f8b100d-2861-479d-9ad9-9eb23837e2ee'), source_entity_uuid=UUID('455af2f7-0a7a-4e6b-9d66-805c18033bc6'), source_entity_name=None, target_entity_uuid=UUID('4ca2bfb8-4232-4d52-8f16-a62f7a988254'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('62ead27d-c699-44c7-8e8b-039055a492c7'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('2cfce9f6-0605-45c0-b6cb-7fbd3fdf4c3d'): [UUID('841bf062-9ddf-46f6-94fa-9581251893ea')], UUID('fc3cc328-6111-433d-b32b-343e592e24f0'): [UUID('e19b43e0-0219-4801-831a-bea8b6ed2eee')], UUID('91f469f8-67a4-4f1e-b39e-b9f4b3de850a'): [UUID('1d717fc2-2082-4159-a723-bca78b82f2f4')], UUID('f6d49bd3-0c3d-4b13-90c6-ce21122a161a'): [UUID('b0bd0f45-7d4a-406e-ad95-e29ec041f39e')], UUID('c2972066-5f7c-4bd4-bc4d-2980dd5425e6'): [UUID('30cb3b48-4343-4b9f-910c-4a086ee8cb78')], UUID('6510652a-2748-473a-a420-f8e50abb8a4e'): [UUID('fa8c89e8-9e5e-4801-bd4b-d80405ecfb72')], UUID('dd0ce44d-2f95-40b3-ba8c-f600c5432342'): [UUID('17cc2473-1d54-4151-bd9e-b3ee0cfa93d8')], UUID('db4d4c82-7ddc-472d-99ad-e2721abf5624'): [UUID('c801e5bf-49db-4dae-a3e9-5f785d1d634f')], UUID('0fb6c1cc-e529-4e5f-952d-e281d501b2f2'): [UUID('a09d3c08-6710-4cb7-818f-33c7b79cf31f')], UUID('bac5db4c-02e1-4e61-a65b-cc690cbe0f79'): [UUID('b116d19d-6421-4afc-9b1c-c7ec76177a18')], UUID('ebfc5d92-eee6-4a28-bc00-3b7e4c73f8c3'): [UUID('a4333121-1a11-4d60-a000-87d7217f5bfe')], UUID('20771478-a5ee-462e-8d95-96f704addd5a'): [UUID('2fc785b6-fb0b-4118-937d-81b305ed8ae0')], UUID('beda77a3-2127-4365-8e0e-41ee9f214f58'): [UUID('648e951d-8fe6-4a2e-8f28-cd2072146079')], UUID('7859159f-d453-4304-a52c-3f3b457564f5'): [UUID('aec46290-cfe1-4bed-9cd5-624dff376103')], UUID('5cb4679c-839a-4361-a194-f490d27d0cbb'): [UUID('d5582538-8953-4f84-a069-8a34476f8d85')], UUID('fa248575-1192-4c3b-aead-52da13a63818'): [UUID('824858a6-8929-458a-8d18-f800d02cc801')], UUID('7c25fbe3-df35-40e3-a455-84e2f531f5c6'): [UUID('75a917a6-6cca-444a-9498-30fdc730bfbc')], UUID('1d1cc348-4169-4db5-9ced-d77ab080972f'): [UUID('a94b92b8-f3ec-4f4a-8246-4e5466f6f3b7')], UUID('d44e0548-9072-43fd-898b-7d9a0f2ca537'): [UUID('0e0f24f3-2878-404d-abb9-c1370e5f424c')], UUID('37af7272-9f7d-4d17-95dd-23561f149396'): [UUID('37af7272-9f7d-4d17-95dd-23561f149396')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='A frightened creature has disadvantage on attack rolls and ability checks and can not move while the frightener is in sight'))

# %%
warrior.action_economy.movement.normalized_score
# Out:
# 0

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score
# Out:
# 30

# %%
print(f"total_time: {time.time()-start_time}")
# Out:
# total_time: 0.6284728050231934
