# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior()

# %%
warrior.source_entity_uuid
# Out:
# UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('ab714718-47e0-4809-b4f1-e0e09043c35e')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Gang Member', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, ability_scores=AbilityScores(name='ability_scores', description=None, uuid=UUID('ab714718-47e0-4809-b4f1-e0e09043c35e'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, strength=Ability(name='strength', description=None, uuid=UUID('b13c7509-de1b-4a21-953c-4a58bdc0331d'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, ability_score=ModifiableValue(name='strength Ability Score', uuid=UUID('b0e3d52d-742c-45ce-99f6-96f2f2209c8e'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8d4f7f39-de83-4dc0-9848-1dd8e814985b'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, normalized_value=2), UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'): NumericalModifier(name='level 4 talent', uuid=UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <Dam ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('b0e3d52d-742c-45ce-99f6-96f2f2209c8e'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('bbd4ef45-6c96-4bf5-b4c6-33575af76f38'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8d4f7f39-de83-4dc0-9848-1dd8e814985b'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('bbd4ef45-6c96-4bf5-b4c6-33575af76f38'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, normalized_value=2), UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'): NumericalModifier(name='level 4 talent', uuid=UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('d2437328-0d04-495a-b43a-4237c9b10813'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('bbd4ef45-6c96-4bf5-b4c6-33575af76f38'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 17

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 12

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.0010075569152832031

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('b0e3d52d-742c-45ce-99f6-96f2f2209c8e'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8d4f7f39-de83-4dc0-9848-1dd8e814985b'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, normalized_value=2), UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'): NumericalModifier(name='level 4 talent', uuid=UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('d2437328-0d04-495a-b43a-4237c9b10813'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.0009999275207519531

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 17, Roll total: 22 vs target ac: 12 result: True
# 0.0

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Roll result: [4], Roll total: 10
# Total Health after taking damage: 49
# 0.001001119613647461

# %%
damages
# Out:
# [Damage(name='Damage', description=None, uuid=UUID('fb73f7bb-d037-43a9-8763-ea56de549e1d'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('a2de4be3-b608-4543-9aee-9dfee06fff71'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001475D606480>, generated_from=[UUID('00fb1e4c-3d14-429c-94a3-b3c46462e941'), UUID('c0962785-dce7-4e4b-ade7-5248c9cf6af2'), UUID('f2ab3d4c-7523-4e37-803a-ad024320d787'), UUID('1dc0ae1b-69b6-4fdf-ab45-9d7e3d608238')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('61d785de-1c70-43e1-bc0c-1bfb3c6076f2'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001475D606480>, generated_from=[UUID('d672242d-4479-483b-85a6-7361a63f5b3e'), UUID('04439c2d-1238-4e6c-8b53-e89bf1ea8034'), UUID('95e1f1bf-3a5d-4021-8833-3af29f33e496'), UUID('f66f3440-88a0-4ce4-9763-ded0d7e95f32')], global_normalizer=False, value_modifiers={UUID('ec5feee5-cb3a-44ef-93ef-e788402126b5'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('ec5feee5-cb3a-44ef-93ef-e788402126b5'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001475D606480>, normalized_value=1), UUID('a3502e98-d54d-4d01-8ff3-6820a9c923d8'): NumericalModifier(name='a past in the circus', uuid=UUID('a3502e98-d54d-4d01-8ff3-6820a9c923d8'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('f6f7638e-9771-4031-8a8f-b3664cf92510'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('f6f7638e-9771-4031-8a8f-b3664cf92510'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001475D605BC0>, normalized_value=0), UUID('aef798ae-23f4-4fb0-903c-6a0394d324a3'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('aef798ae-23f4-4fb0-903c-6a0394d324a3'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001475D6060C0>, normalized_value=0), UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, normalized_value=2), UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'): NumericalModifier(name='level 4 talent', uuid=UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_enti ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0014972686767578125

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0025110244750976562

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0030126571655273438

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('b0e3d52d-742c-45ce-99f6-96f2f2209c8e'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('bbd4ef45-6c96-4bf5-b4c6-33575af76f38'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8d4f7f39-de83-4dc0-9848-1dd8e814985b'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('bbd4ef45-6c96-4bf5-b4c6-33575af76f38'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('744cf540-dd83-42fb-83f8-a8be8c132f3c'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, normalized_value=2), UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'): NumericalModifier(name='level 4 talent', uuid=UUID('bd7e6c7c-d608-410d-b474-0877a21e8878'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('d2437328-0d04-495a-b43a-4237c9b10813'), source_entity_uuid=UUID('664123cb-50a4-4d70-8ca4-3d38b525ab6f'), source_entity_name=None, target_entity_uuid=UUID('bbd4ef45-6c96-4bf5-b4c6-33575af76f38'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001475BD25800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 17, Roll total: 22 vs target ac: 12 result: True
# Total Health before taking damage: 49
# Roll result: [4], Roll total: 10
# Total Health after taking damage: 40
# 0.003506183624267578
