# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior()

# %%
warrior.source_entity_uuid
# Out:
# UUID('d66f58aa-6198-47ad-becb-458234909225')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('f13a0565-2bc4-42d1-910c-715008374abb')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Gang Member', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, ability_scores=AbilityScores(name='ability_scores', description=None, uuid=UUID('f13a0565-2bc4-42d1-910c-715008374abb'), source_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, strength=Ability(name='strength', description=None, uuid=UUID('288150ca-2e94-4535-bc43-e2c95cbc8513'), source_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, ability_score=ModifiableValue(name='strength Ability Score', uuid=UUID('955781c7-2d45-4c6f-9710-342e1f41f08d'), source_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000014F4EB43920>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('91565063-f8fa-4f46-af83-f9dad01b6a9b'), source_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000014F4EB43920>, generated_from=[], global_normalizer=True, value_modifiers={UUID('8b7b2940-43f0-48e7-8a02-c5e8a7caea4c'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('8b7b2940-43f0-48e7-8a02-c5e8a7caea4c'), source_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_name=None, target_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000014F4EB43920>, normalized_value=2), UUID('ba2fd8d8-a99e-4356-a056-170174487fac'): NumericalModifier(name='level 4 talent', uuid=UUID('ba2fd8d8-a99e-4356-a056-170174487fac'), source_entity_uuid=UUID('d66f58aa-6198-47ad-becb-458234909225'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <Dam ...
