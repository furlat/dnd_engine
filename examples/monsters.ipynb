# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior()

# %%
warrior.source_entity_uuid
# Out:
# UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('087b7c58-5b7a-449e-a96b-c907bd19dc89')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Gang Member', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('087b7c58-5b7a-449e-a96b-c907bd19dc89'): AbilityScores(name='ability_scores', description=None, uuid=UUID('087b7c58-5b7a-449e-a96b-c907bd19dc89'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('099d539d-a60e-4209-a892-d985aff9c33a'): Ability(name='strength', description=None, uuid=UUID('099d539d-a60e-4209-a892-d985aff9c33a'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('1062bce5-df11-40ca-9f7f-01dc7a58efa9'): ModifiableValue(name='strength Ability Score', uuid=UUID('1062bce5-df11-40ca-9f7f-01dc7a58efa9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('3ec1a9b2-8196-4fc2-ae72-41d45f365be1'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('44e6d354-a120-4687-bd4e-5deebd92791e'): NumericalModifier(name='level 4 talent', uuid=UUID('44e6d354-a120-4687-bd4e-5deebd92791e'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, < ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('1062bce5-df11-40ca-9f7f-01dc7a58efa9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('3ec1a9b2-8196-4fc2-ae72-41d45f365be1'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('44e6d354-a120-4687-bd4e-5deebd92791e'): NumericalModifier(name='level 4 talent', uuid=UUID('44e6d354-a120-4687-bd4e-5deebd92791e'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('6303d814-e2c5-4208-b985-ff30bdfa4fbc'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 11

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 6

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.0004987716674804688

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('1062bce5-df11-40ca-9f7f-01dc7a58efa9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('3ec1a9b2-8196-4fc2-ae72-41d45f365be1'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('44e6d354-a120-4687-bd4e-5deebd92791e'): NumericalModifier(name='level 4 talent', uuid=UUID('44e6d354-a120-4687-bd4e-5deebd92791e'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('6303d814-e2c5-4208-b985-ff30bdfa4fbc'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.0015020370483398438

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0004985332489013672

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 13, Roll total: 18 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0010013580322265625

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Damage Roll result: [2], Roll total: 8
# Total Health after taking damage: 51
# 0.0010042190551757812

# %%
damages
# Out:
# [Damage(name='Damage', description=None, uuid=UUID('df9b7fc6-993b-4c83-87d2-136a757ff768'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('ea62f7fb-8ab9-4747-a682-2c4145b099fd'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('ea62f7fb-8ab9-4747-a682-2c4145b099fd'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F3C4F880>, generated_from=[UUID('9d602b72-184a-40c2-b984-5703cc518a10'), UUID('b84e4f15-9791-4b8c-937c-3bec82990deb'), UUID('65df7070-aa54-459c-9fe2-992d1f5eaafb'), UUID('bb56db29-9c18-434e-8599-f5772b1db125')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('24126f3f-d30c-4b2c-aa7f-8c03c6a954e6'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F3C4F880>, generated_from=[UUID('dbba2508-d092-4992-91ad-a3f8dbbf6137'), UUID('e87b2356-4c60-460f-a298-aa0a3abe8eb8'), UUID('7160c91f-a8ac-4257-830b-76aede830e66'), UUID('f5dce7e5-c9d2-4789-ad69-056d614013c4')], global_normalizer=False, value_modifiers={UUID('2ed868b2-8c75-45a5-b603-63515196f829'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('2ed868b2-8c75-45a5-b603-63515196f829'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F3C4F880>, normalized_value=1), UUID('c4e02f45-a05a-4bf5-ad94-84ccdccaef38'): NumericalModifier(name='a past in the circus', uuid=UUID('c4e02f45-a05a-4bf5-ad94-84ccdccaef38'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('041da0c9-b43e-4735-8116-321a54c0e91c'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('041da0c9-b43e-4735-8116-321a54c0e91c'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F3C4EFC0>, normalized_value=0), UUID('c8d19c89-de16-4d02-b11a-41665a5c3f26'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('c8d19c89-de16-4d02-b11a-41665a5c3f26'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F3C4F4C0>, normalized_value=0), UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('44e6d354-a120-4687-bd4e-5deebd92791e'): NumericalModifier(name='level 4 talent', uuid=UUID('44e6d354-a120-4687-bd4e-5deebd92791e'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_n ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0014963150024414062

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.001994609832763672

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0014963150024414062

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('1062bce5-df11-40ca-9f7f-01dc7a58efa9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('3ec1a9b2-8196-4fc2-ae72-41d45f365be1'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('44e6d354-a120-4687-bd4e-5deebd92791e'): NumericalModifier(name='level 4 talent', uuid=UUID('44e6d354-a120-4687-bd4e-5deebd92791e'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('6303d814-e2c5-4208-b985-ff30bdfa4fbc'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 13, Roll total: 18 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 51
# Damage Roll result: [4], Roll total: 10
# Total Health after taking damage: 42
# 0.008009195327758789

# %%
from dnd.core.requests import SkillCheckRequest, SavingThrowRequest, SkillName

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request
# Out:
# SkillCheckRequest(dc=12, source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), context=None, skill_name='acrobatics')

# %%
strength_saving_throw_request
# Out:
# SavingThrowRequest(dc=12, source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), context=None, ability_name='strength')

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")
# Out:
# ModifiableValue(name='Value_acrobatics Skill Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('38fc4f77-feab-4357-8bce-09dc9c452430'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x00000286F554BEC0>, generated_from=[UUID('ad020146-f542-4300-82f7-bb90774d7791'), UUID('df5f8a61-993e-48b8-be32-154efa06e3d5'), UUID('9376649b-72c4-4d4c-848b-b1a62c099697'), UUID('e10bf997-c668-4f70-9dac-60156ae01910')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('0e225ee9-108d-4d3f-a222-6df2bb60e7fc'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x00000286F554BEC0>, generated_from=[UUID('6d0043ec-6319-4b77-91ce-f8af0ef54e50'), UUID('9d4efadc-0a9c-48e1-99a8-a19f75be3f40'), UUID('83488d3e-be0a-43ce-aa9b-8ccdf88923bd'), UUID('4cdfb760-5ef0-442a-9b49-864f52d4c3a7')], global_normalizer=False, value_modifiers={UUID('512082e0-f64e-4b38-893b-ae8de1a31d88'): NumericalModifier(name='Value_base_value', uuid=UUID('512082e0-f64e-4b38-893b-ae8de1a31d88'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x00000286F554BEC0>, normalized_value=0), UUID('67e944d3-6717-4f3c-afcd-58bfd86eaefc'): NumericalModifier(name='a past in the circus', uuid=UUID('67e944d3-6717-4f3c-afcd-58bfd86eaefc'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x00000286F554BEC0>, normalized_value=-2), UUID('cb9a4b62-a8fd-4406-b582-743f4fab8812'): NumericalModifier(name='acrobatics Skill Bonus_base_value', uuid=UUID('cb9a4b62-a8fd-4406-b582-743f4fab8812'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F5485120>, normalized_value=0), UUID('aca095b6-307f-4c27-bd27-9e3acce3514f'): NumericalModifier(name='a past in the circus', uuid=UUID('aca095b6-307f-4c27-bd27-9e3acce3514f'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=7, score_normalizer=None, normalized_value=7), UUID('8fca909f-d89d-47d4-ac33-f4f3606167df'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('8fca909f-d89d-47d4-ac33-f4f3606167df'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=12, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=1), UUID('86452978-0734-4455-915d-b42819338d93'): NumericalModifier(name='strength Modifier Bonus_base_value', uuid=UUID('86452978-0734-4455-915d-b42819338d93'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54844A0>, normalized_value=0)}, min_constraints={}, max_co ...

# %%
warrior2.skill_check(acrobatics_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 6
# Roll result: 2, Roll total: 8 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('bde6a921-94cb-47b8-b848-f24e7a1f716f'), dice_uuid=UUID('2deba726-e954-446c-9451-53e6aadd648e'), roll_type=<RollType.ATTACK: 'Attack'>, results=2, total=8, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=None),
#  False)

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 3, Roll total: 3 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('415e1e8b-cd2d-427c-a4e2-f156ccc2736a'), dice_uuid=UUID('e6bf8b14-9a39-44b7-af92-ea722181d586'), roll_type=<RollType.ATTACK: 'Attack'>, results=3, total=3, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=None),
#  False)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")
# Out:
# ModifiableValue(name='Value_strength_saving_throw Saving Throw Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('c24a1bc2-86fb-49d8-b316-27455ddd2038'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x00000286F5548540>, generated_from=[UUID('ad020146-f542-4300-82f7-bb90774d7791'), UUID('04b2f42a-16f1-440b-b67f-ac0ae36dd29f'), UUID('cce51406-cf39-483e-bcc7-f62ce1d67371'), UUID('71f58526-7826-426b-8ee4-f91279a3ab04')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('b1a27ba6-ae5e-459b-9f36-8dcede57216b'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x00000286F5548540>, generated_from=[UUID('6d0043ec-6319-4b77-91ce-f8af0ef54e50'), UUID('fdeb70a8-ec9b-4033-800f-3e6129ac640a'), UUID('74fb8504-a6dd-4762-a988-49e95f1616a6'), UUID('416d5a6b-e11c-483c-93d4-ca07f6421b39')], global_normalizer=False, value_modifiers={UUID('512082e0-f64e-4b38-893b-ae8de1a31d88'): NumericalModifier(name='Value_base_value', uuid=UUID('512082e0-f64e-4b38-893b-ae8de1a31d88'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x00000286F5548540>, normalized_value=0), UUID('67e944d3-6717-4f3c-afcd-58bfd86eaefc'): NumericalModifier(name='a past in the circus', uuid=UUID('67e944d3-6717-4f3c-afcd-58bfd86eaefc'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x00000286F5548540>, normalized_value=-1), UUID('b6e13908-89d8-494f-9a60-554df67361a0'): NumericalModifier(name='strength_saving_throw Saving Throw Bonus_base_value', uuid=UUID('b6e13908-89d8-494f-9a60-554df67361a0'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54872E0>, normalized_value=0), UUID('41f37628-c45b-40b0-b7fd-eead43d87cfe'): NumericalModifier(name='a past in the circus', uuid=UUID('41f37628-c45b-40b0-b7fd-eead43d87cfe'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'): NumericalModifier(name='level 4 talent', uuid=UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('bfb07dad-39bd-4975-8749-4feb3ff6485f'): NumericalModifier(name='strength Modifier  ...

# %%
warrior2.saving_throw(strength_saving_throw_request)
# Out:
# Target AC: 12
# Attack bonus: 4
# Roll result: 5, Roll total: 9 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('a4f98b9b-3f89-4219-80ef-9ab6980a58b8'), dice_uuid=UUID('86e7d627-9db8-48f8-bcca-61d45562825b'), roll_type=<RollType.ATTACK: 'Attack'>, results=5, total=9, bonus=4, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=None),
#  False)

# %%
from dnd.conditions import Blinded

blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# True

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('cce51406-cf39-483e-bcc7-f62ce1d67371'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('74fb8504-a6dd-4762-a988-49e95f1616a6'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'): NumericalModifier(name='level 4 talent', uuid=UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('220cac37-b824-42f8-ac19-1afeed0ff4c3'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 12, Roll total: 15 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# Total Health before taking damage: 58
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 50
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('ed1739db-7cde-43b4-b3bd-dfe930050f6f'), dice_uuid=UUID('09804da7-608e-442d-9d7d-0516a43e86d9'), roll_type=<RollType.ATTACK: 'Attack'>, results=12, total=15, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('7da1b3f1-af3f-4961-b01a-634057d31095'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, blocks={}, values={UUID('09d1f5cb-d421-463a-97bc-a32ee4c4c156'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('09d1f5cb-d421-463a-97bc-a32ee4c4c156'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5440>, generated_from=[UUID('3a1be28b-c7c7-417d-8a32-f9aa70e3bd05'), UUID('7fa5e18b-244f-411b-bc86-b65c812cc32c'), UUID('4b17c69a-e24c-49e2-97c9-6a1b612c40dd'), UUID('1d992be6-b5cf-4f23-8a34-6fc7a870ae38')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('b2d46c20-f017-45fa-b2bc-0978dc0c03f9'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5440>, generated_from=[UUID('83722edc-1679-420e-8619-221af61bf06f'), UUID('6ee4c469-9a68-4c2c-a251-7aa023f2978a'), UUID('acfde796-98e1-4a26-a257-ff300240938f'), UUID('a1dfcb7a-f6eb-4f91-bb3d-4745fcf2a85c')], global_normalizer=False, value_modifiers={UUID('5f58fa6f-8336-450e-9001-8a9dcf3be47d'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('5f58fa6f-8336-450e-9001-8a9dcf3be47d'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5440>, normalized_value=1), UUID('77cf9cc4-0596-41be-9c3c-8b3dd48f2b4b'): NumericalModifier(name='a past in the circus', uuid=UUID('77cf9cc4-0596-41be-9c3c-8b3dd48f2b4b'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('a68f8688-db2d-4449-8777-8ec5ec8b4094'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('a68f8688-db2d-4449-8777-8ec5ec8b4094'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D4B80>, normalized_value=0), UUID('6fe565fb-f303-4f0a-8066-f7722e1a957a'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('6fe565fb-f303-4f0a-8066-f7722e1a957a'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5080>, normalized_value=0), UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('586d6281-0dde-4522-b157-b1241e35d140'), dice_uuid=UUID('71ee1b27-1dd9-4477-b5e3-5bf0cdb3facc'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[3], total=9, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
warrior.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior.attack(warrior2.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('1062bce5-df11-40ca-9f7f-01dc7a58efa9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('3ec1a9b2-8196-4fc2-ae72-41d45f365be1'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d5120c6c-d50c-4430-941a-07cd776e3ec9'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('44e6d354-a120-4687-bd4e-5deebd92791e'): NumericalModifier(name='level 4 talent', uuid=UUID('44e6d354-a120-4687-bd4e-5deebd92791e'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('6303d814-e2c5-4208-b985-ff30bdfa4fbc'), source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 4, Roll total: 9 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('3942ce88-244b-4c7f-bda3-c075d0700ff8'), dice_uuid=UUID('7ef01dba-1a26-4180-a4d3-2a70733c6b6a'), roll_type=<RollType.ATTACK: 'Attack'>, results=4, total=9, bonus=5, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), attack_outcome=None),
#  [])

# %%
blinded.modifers_uuids
# Out:
# {UUID('fc5e9791-47ba-4c77-85c4-37bc8b4707da'): [UUID('a10aab4f-568f-4aa4-9622-786709f7eade')],
#  UUID('da6dd414-a772-4841-bd67-80f05a384025'): [UUID('f8ec0ba9-59ec-4e75-b2e4-a9e2cc246081')],
#  UUID('bf5248ab-a5a5-4726-a64a-5af6c6e281d5'): [UUID('fe8a97e7-d748-4b24-909a-3c381c1efa48')],
#  UUID('da90dade-a3b3-48ef-9d0f-f8552fa8b24a'): [UUID('6e4e079f-8fd1-498c-8bb5-36dabe3bc5b5')],
#  UUID('d9c676a5-d9c6-4fb5-b316-bc71d054dfa4'): [UUID('239be229-7c0c-44f2-961f-0791199347f1')],
#  UUID('de085b1a-061c-4cc9-8450-1ffed531a892'): [UUID('7cda0e36-5adf-47df-9ac3-355a807dfcc1')]}

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 4, Roll total: 4 vs target ac: 12 result: False auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('8090a12d-3cf8-41b6-8926-6f82bfe9805f'), dice_uuid=UUID('de4bb580-76fe-46f9-8b8b-7a4c228b65cf'), roll_type=<RollType.ATTACK: 'Attack'>, results=4, total=4, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=None),
#  False)

# %%
blinded.remove()
# Out:
# True

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 16, Roll total: 16 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('e40f4fc5-b81a-45fa-85a2-16a3d35a268f'), dice_uuid=UUID('0ea2dbf6-56ef-47a1-bf03-e1c2b41f0641'), roll_type=<RollType.ATTACK: 'Attack'>, results=16, total=16, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=None),
#  True)

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('cce51406-cf39-483e-bcc7-f62ce1d67371'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('74fb8504-a6dd-4762-a988-49e95f1616a6'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'): NumericalModifier(name='level 4 talent', uuid=UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('220cac37-b824-42f8-ac19-1afeed0ff4c3'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 19, Roll total: 22 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 50
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 42
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('6509b5fd-7d2b-4bee-a74b-c7473c71e0af'), dice_uuid=UUID('539e7b1b-c914-4a4f-8565-764aed5e9f3b'), roll_type=<RollType.ATTACK: 'Attack'>, results=19, total=22, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('1ab4a90b-4302-4f38-ae7c-0b22ad9bec6c'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, blocks={}, values={UUID('d98c276f-d97d-4810-9e98-806baf6d24e8'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('d98c276f-d97d-4810-9e98-806baf6d24e8'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5440>, generated_from=[UUID('3a1be28b-c7c7-417d-8a32-f9aa70e3bd05'), UUID('7fa5e18b-244f-411b-bc86-b65c812cc32c'), UUID('4b17c69a-e24c-49e2-97c9-6a1b612c40dd'), UUID('96988dca-bae6-4176-8167-f47e57e2b513')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('4868ba8b-fed1-4f25-b749-666aa625c3c9'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5440>, generated_from=[UUID('83722edc-1679-420e-8619-221af61bf06f'), UUID('6ee4c469-9a68-4c2c-a251-7aa023f2978a'), UUID('acfde796-98e1-4a26-a257-ff300240938f'), UUID('147a64fe-7b98-4d7f-8268-3d13d1a73df0')], global_normalizer=False, value_modifiers={UUID('5f58fa6f-8336-450e-9001-8a9dcf3be47d'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('5f58fa6f-8336-450e-9001-8a9dcf3be47d'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5440>, normalized_value=1), UUID('77cf9cc4-0596-41be-9c3c-8b3dd48f2b4b'): NumericalModifier(name='a past in the circus', uuid=UUID('77cf9cc4-0596-41be-9c3c-8b3dd48f2b4b'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('a68f8688-db2d-4449-8777-8ec5ec8b4094'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('a68f8688-db2d-4449-8777-8ec5ec8b4094'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D4B80>, normalized_value=0), UUID('6fe565fb-f303-4f0a-8066-f7722e1a957a'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('6fe565fb-f303-4f0a-8066-f7722e1a957a'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000286F54D5080>, normalized_value=0), UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('9677f34c-fbd8-4cdf-b3c1-510fc59a0797'), source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), source_entity_name=None, target_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000286F296DBC0>, normalized_value=2), UUID('97f1040f-c05b-4f76-8a8b-74df385c1025'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('09c5499d-afd1-4dff-80cd-65f6171c8356'), dice_uuid=UUID('99b5ada3-545e-4650-8c10-e0a6430ff4ad'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[3], total=9, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('643d9211-3f04-494e-b10a-94bf935de4ec'), target_entity_uuid=UUID('380378a5-8c1a-4f56-a62b-f2ead15b9f1c'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])
