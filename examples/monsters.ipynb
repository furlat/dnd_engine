# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior()

# %%
warrior.source_entity_uuid
# Out:
# UUID('1b40ce5b-2381-4622-a575-562ab77e6112')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('65d1898e-c9d1-4d0c-97ce-bb62428d5293')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Gang Member', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('65d1898e-c9d1-4d0c-97ce-bb62428d5293'): AbilityScores(name='ability_scores', description=None, uuid=UUID('65d1898e-c9d1-4d0c-97ce-bb62428d5293'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('79b96e6e-ac6c-49c2-b67d-635a40f49d2f'): Ability(name='strength', description=None, uuid=UUID('79b96e6e-ac6c-49c2-b67d-635a40f49d2f'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('49e89aee-a3d9-4956-91f2-3e8bba22d9c4'): ModifiableValue(name='strength Ability Score', uuid=UUID('49e89aee-a3d9-4956-91f2-3e8bba22d9c4'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('42a83b0a-1518-484e-b4a8-8d5bee545040'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6c53ca2-7475-47c9-965a-323a40a69140'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6c53ca2-7475-47c9-965a-323a40a69140'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'): NumericalModifier(name='level 4 talent', uuid=UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, < ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('49e89aee-a3d9-4956-91f2-3e8bba22d9c4'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('42a83b0a-1518-484e-b4a8-8d5bee545040'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6c53ca2-7475-47c9-965a-323a40a69140'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6c53ca2-7475-47c9-965a-323a40a69140'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'): NumericalModifier(name='level 4 talent', uuid=UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('12d79fcd-042b-4ea7-9f22-660e5f64095b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 23

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 18

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.0004961490631103516

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('49e89aee-a3d9-4956-91f2-3e8bba22d9c4'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('42a83b0a-1518-484e-b4a8-8d5bee545040'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6c53ca2-7475-47c9-965a-323a40a69140'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6c53ca2-7475-47c9-965a-323a40a69140'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'): NumericalModifier(name='level 4 talent', uuid=UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('12d79fcd-042b-4ea7-9f22-660e5f64095b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.002005338668823242

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 1, Roll total: 6 vs target ac: 12 result: False
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0004990100860595703

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Roll result: [2], Roll total: 8
# Total Health after taking damage: 51
# 0.0005013942718505859

# %%
damages
# Out:
# [Damage(name='Damage', description=None, uuid=UUID('42454282-fb2b-4ebe-88e6-996309cf1f81'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('9a5268e9-1439-49e4-9183-bbf0f0082aa8'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('9a5268e9-1439-49e4-9183-bbf0f0082aa8'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AB060>, generated_from=[UUID('f4cf41fd-4626-4677-bcbc-a4741f8ce5a4'), UUID('26fe51ba-a900-4687-b53f-ab2846bb2652'), UUID('8397edc6-aba7-4c9e-aa19-81feb628e393'), UUID('dcafdff0-9c26-419b-a920-58114f393008')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('db8baeac-eecb-415f-ad43-edee4ed31ff6'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AB060>, generated_from=[UUID('fb3fc0f5-9f85-44c0-a148-75704eff99f1'), UUID('595a3a34-c2f2-4140-b3e6-a9db585d1088'), UUID('04267245-6be4-4ba0-8d89-6b0caebca50d'), UUID('6d7ce879-ae3a-4034-a7c9-eec1fe094805')], global_normalizer=False, value_modifiers={UUID('574ff8d8-4085-4c9b-b14a-a6f804a8f50e'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('574ff8d8-4085-4c9b-b14a-a6f804a8f50e'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AB060>, normalized_value=1), UUID('7f4fcbeb-51cf-4935-b36b-aff7594c7006'): NumericalModifier(name='a past in the circus', uuid=UUID('7f4fcbeb-51cf-4935-b36b-aff7594c7006'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('afb6d3ca-e8c3-4625-a0c3-a75d45e752ca'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('afb6d3ca-e8c3-4625-a0c3-a75d45e752ca'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AA7A0>, normalized_value=0), UUID('9a4a4b50-ae0a-4d57-b245-c0753258e6e1'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('9a4a4b50-ae0a-4d57-b245-c0753258e6e1'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AACA0>, normalized_value=0), UUID('a6c53ca2-7475-47c9-965a-323a40a69140'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6c53ca2-7475-47c9-965a-323a40a69140'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'): NumericalModifier(name='level 4 talent', uuid=UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_n ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.002001523971557617

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0004999637603759766

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0009992122650146484

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.001495361328125

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('49e89aee-a3d9-4956-91f2-3e8bba22d9c4'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('42a83b0a-1518-484e-b4a8-8d5bee545040'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6c53ca2-7475-47c9-965a-323a40a69140'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6c53ca2-7475-47c9-965a-323a40a69140'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'): NumericalModifier(name='level 4 talent', uuid=UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('12d79fcd-042b-4ea7-9f22-660e5f64095b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 3, Roll total: 8 vs target ac: 12 result: False
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.007512331008911133

# %%
from dnd.conditions import Blinded

blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# True

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('bb5da7ba-6357-4a0a-a15f-481c82a7e5a9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('45399ab8-fdd5-45a6-bc4b-e93914d0ec27'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('050d2060-85d9-4ea6-bfad-38e4da78dbfe'): NumericalModifier(name='level 4 talent', uuid=UUID('050d2060-85d9-4ea6-bfad-38e4da78dbfe'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('98b57812-8d7e-405d-9a98-7b37e145d2c7'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 17, Roll total: 20 vs target ac: 12 result: True
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# Total Health before taking damage: 58
# Roll result: [1], Roll total: 7
# Total Health after taking damage: 52
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('a14bd7a7-7607-440b-9758-d56af89e139b'), dice_uuid=UUID('3275e510-f731-4118-a2a8-ae17fb0d05f7'), roll_type=<RollType.ATTACK: 'Attack'>, results=17, total=20, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('f7c64092-9e92-4b86-b46f-18a92c8ff80e'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, blocks={}, values={UUID('55b67cc4-2592-48fa-be2c-bb48cc5ad970'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('55b67cc4-2592-48fa-be2c-bb48cc5ad970'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58C20>, generated_from=[UUID('7f1df74e-c9cb-4887-a1d0-05dbd6dd0f9f'), UUID('988cf3f7-b3a8-431d-96e4-e6793e8e54d3'), UUID('7a9310a5-5971-4681-8c18-634ccb597f52'), UUID('87c6abb8-5380-4ad1-9b3a-616fe8b310c0')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('9302149d-9d2b-48de-91b6-980a4274d4e0'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58C20>, generated_from=[UUID('dd58e4b2-8c11-4809-a544-46d0c668c9f9'), UUID('4249915e-a2cf-4ff3-adf9-09ed9683183e'), UUID('a0749968-77e9-4ccf-af87-c911af792115'), UUID('ea38a74c-3cc3-4115-b64c-e6bc5575f1f7')], global_normalizer=False, value_modifiers={UUID('c36c4d68-7286-4be2-b54a-d0428bbb242c'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('c36c4d68-7286-4be2-b54a-d0428bbb242c'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58C20>, normalized_value=1), UUID('1f6f36ae-5bab-418b-b5d4-f18694cb16a9'): NumericalModifier(name='a past in the circus', uuid=UUID('1f6f36ae-5bab-418b-b5d4-f18694cb16a9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('2eeef394-792a-49fc-a423-a42b6af86758'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('2eeef394-792a-49fc-a423-a42b6af86758'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58360>, normalized_value=0), UUID('36e67500-b84c-47b9-b7b8-72c452a2879c'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('36e67500-b84c-47b9-b7b8-72c452a2879c'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58860>, normalized_value=0), UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('050d2060-85d9-4ea6-bfad-38e4da78dbfe'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('2b3b7eda-a8fd-4fc7-b1fd-ef448954b4b9'), dice_uuid=UUID('461582f5-73fc-4ec2-9721-fd5da9b22122'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[1], total=7, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
warrior.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior.attack(warrior2.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('49e89aee-a3d9-4956-91f2-3e8bba22d9c4'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('42a83b0a-1518-484e-b4a8-8d5bee545040'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a6c53ca2-7475-47c9-965a-323a40a69140'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6c53ca2-7475-47c9-965a-323a40a69140'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'): NumericalModifier(name='level 4 talent', uuid=UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('12d79fcd-042b-4ea7-9f22-660e5f64095b'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 9, Roll total: 14 vs target ac: 12 result: True
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# Total Health before taking damage: 51
# Roll result: [3], Roll total: 9
# Total Health after taking damage: 43
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('600b684d-ba2b-4895-bffe-649452aeeb24'), dice_uuid=UUID('2007a415-7acd-4d3f-9804-0df3db0b1084'), roll_type=<RollType.ATTACK: 'Attack'>, results=9, total=14, bonus=5, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('43f707ac-dfa8-4403-a366-6499e97fb9e9'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, blocks={}, values={UUID('77b38e5a-c4a7-431f-9b49-595b17c4462e'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('77b38e5a-c4a7-431f-9b49-595b17c4462e'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AB060>, generated_from=[UUID('f4cf41fd-4626-4677-bcbc-a4741f8ce5a4'), UUID('26fe51ba-a900-4687-b53f-ab2846bb2652'), UUID('8397edc6-aba7-4c9e-aa19-81feb628e393'), UUID('dc443e2a-00d8-4fb8-9586-5524cd902c5f')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('f8ee308f-d372-4afe-b78c-88bf7a45f893'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AB060>, generated_from=[UUID('fb3fc0f5-9f85-44c0-a148-75704eff99f1'), UUID('595a3a34-c2f2-4140-b3e6-a9db585d1088'), UUID('04267245-6be4-4ba0-8d89-6b0caebca50d'), UUID('c709e587-f294-4274-99f5-2eb51b3607ca')], global_normalizer=False, value_modifiers={UUID('574ff8d8-4085-4c9b-b14a-a6f804a8f50e'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('574ff8d8-4085-4c9b-b14a-a6f804a8f50e'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AB060>, normalized_value=1), UUID('7f4fcbeb-51cf-4935-b36b-aff7594c7006'): NumericalModifier(name='a past in the circus', uuid=UUID('7f4fcbeb-51cf-4935-b36b-aff7594c7006'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('afb6d3ca-e8c3-4625-a0c3-a75d45e752ca'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('afb6d3ca-e8c3-4625-a0c3-a75d45e752ca'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AA7A0>, normalized_value=0), UUID('9a4a4b50-ae0a-4d57-b245-c0753258e6e1'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('9a4a4b50-ae0a-4d57-b245-c0753258e6e1'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85B5AACA0>, normalized_value=0), UUID('a6c53ca2-7475-47c9-965a-323a40a69140'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('a6c53ca2-7475-47c9-965a-323a40a69140'), source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('e2fbd0ba-e3db-4b01-9ef2-2ba899e4402b'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('5c084d7c-6e68-4f34-b47a-7903fb4117ab'), dice_uuid=UUID('23d3230c-d9ca-4908-91a0-eee39f4483fa'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[3], total=9, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
blinded.modifers_uuids
# Out:
# {UUID('93330f1e-6cdb-4de9-b91d-25176e51099c'): [UUID('3d3f5d94-fde9-4bfc-b2ed-20516f1b1e86')],
#  UUID('666e8e44-12d2-4b16-9a10-26961fbcf712'): [UUID('abbe5b51-4bbb-4ca9-8ab3-fd4a71e47a69')],
#  UUID('58382484-30c6-4597-8d74-f6b59cf4e4f1'): [UUID('6a6c6604-76e9-4f37-b84e-b667e1e92411')],
#  UUID('9a7ef61d-1685-42b4-96a5-f1f7975878e8'): [UUID('b4c7efd4-db21-4b99-948d-4574e98e7cb5')],
#  UUID('add13a9c-e94e-4c3c-9074-4adac0d02797'): [UUID('1023f52d-f4f3-4741-b000-0252c856e13b')],
#  UUID('ae8846d9-b02a-47ec-9d01-30fa70f9a109'): [UUID('6de0cf92-e894-45c0-8e56-a1739caa8acd')]}

# %%
blinded.remove()
# Out:
# True

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('bb5da7ba-6357-4a0a-a15f-481c82a7e5a9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('45399ab8-fdd5-45a6-bc4b-e93914d0ec27'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('050d2060-85d9-4ea6-bfad-38e4da78dbfe'): NumericalModifier(name='level 4 talent', uuid=UUID('050d2060-85d9-4ea6-bfad-38e4da78dbfe'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('98b57812-8d7e-405d-9a98-7b37e145d2c7'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 17, Roll total: 20 vs target ac: 12 result: True
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 52
# Roll result: [4], Roll total: 10
# Total Health after taking damage: 43
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('dcc8d161-8ad8-48e7-bcd8-6b1571bb7691'), dice_uuid=UUID('a77ebad4-8d34-4c2a-911e-392c6bfcc8fa'), roll_type=<RollType.ATTACK: 'Attack'>, results=17, total=20, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('09075960-f28f-45f9-9d80-4442d1c60882'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, blocks={}, values={UUID('ab0ae768-3da9-442a-8bfa-dca3e759d3a4'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('ab0ae768-3da9-442a-8bfa-dca3e759d3a4'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58C20>, generated_from=[UUID('7f1df74e-c9cb-4887-a1d0-05dbd6dd0f9f'), UUID('988cf3f7-b3a8-431d-96e4-e6793e8e54d3'), UUID('7a9310a5-5971-4681-8c18-634ccb597f52'), UUID('fc7e709f-256d-41ab-a6b6-3308a00cef65')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('c2eab76f-35e9-4c25-be51-8114bb152ac5'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58C20>, generated_from=[UUID('dd58e4b2-8c11-4809-a544-46d0c668c9f9'), UUID('4249915e-a2cf-4ff3-adf9-09ed9683183e'), UUID('a0749968-77e9-4ccf-af87-c911af792115'), UUID('38ba888c-5e03-4419-bcda-aaadbd36551b')], global_normalizer=False, value_modifiers={UUID('c36c4d68-7286-4be2-b54a-d0428bbb242c'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('c36c4d68-7286-4be2-b54a-d0428bbb242c'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58C20>, normalized_value=1), UUID('1f6f36ae-5bab-418b-b5d4-f18694cb16a9'): NumericalModifier(name='a past in the circus', uuid=UUID('1f6f36ae-5bab-418b-b5d4-f18694cb16a9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('2eeef394-792a-49fc-a423-a42b6af86758'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('2eeef394-792a-49fc-a423-a42b6af86758'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58360>, normalized_value=0), UUID('36e67500-b84c-47b9-b7b8-72c452a2879c'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('36e67500-b84c-47b9-b7b8-72c452a2879c'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001D85BC58860>, normalized_value=0), UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c92a1d0a-cebe-4158-8a53-6491f581a4e9'), source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), source_entity_name=None, target_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001D85A1E5620>, normalized_value=2), UUID('050d2060-85d9-4ea6-bfad-38e4da78dbfe'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('db0f4f1e-0d65-4d9b-a6cc-696b99c7d40d'), dice_uuid=UUID('7afb4c48-1c68-4436-9b58-ec2186a0aaa8'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[4], total=10, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('48f08a6c-536a-4b8c-8b2a-888caa0e5f19'), target_entity_uuid=UUID('1b40ce5b-2381-4622-a575-562ab77e6112'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])
