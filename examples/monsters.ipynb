# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior()

# %%
warrior.source_entity_uuid
# Out:
# UUID('c1760451-d672-4909-a8b4-2c77ae96c71a')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('1626d219-92fe-4d75-9d5b-326258461dc4')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Gang Member', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, ability_scores=AbilityScores(name='ability_scores', description=None, uuid=UUID('1626d219-92fe-4d75-9d5b-326258461dc4'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, strength=Ability(name='strength', description=None, uuid=UUID('d92456a5-2de5-453a-920f-cdc22fd9142b'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, ability_score=ModifiableValue(name='strength Ability Score', uuid=UUID('26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('afa6709c-692f-41a5-9fd0-5b0c4e6daa70'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, normalized_value=2), UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'): NumericalModifier(name='level 4 talent', uuid=UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <Dam ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('24e03c3b-0cd0-4379-ba1a-f7a61d09e16f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('afa6709c-692f-41a5-9fd0-5b0c4e6daa70'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('24e03c3b-0cd0-4379-ba1a-f7a61d09e16f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, normalized_value=2), UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'): NumericalModifier(name='level 4 talent', uuid=UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('4338d23e-50b6-4139-ad86-0715849fcca8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('24e03c3b-0cd0-4379-ba1a-f7a61d09e16f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Unarmed Attack Bonus and uuid 7f4d33b1-0154-4185-8334-1bb2de27d6a2
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Melee Attack Bonus and uuid 3c8f9714-15f0-4c7a-9333-bf5a064f1623
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Ability Score and uuid 26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid 2ea174de-1787-4c4e-b157-4415a85523b4

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 20

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 15

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name strength Ability Score and uuid 26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid 2ea174de-1787-4c4e-b157-4415a85523b4
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Unarmed Damage Bonus and uuid 518b25e9-cec4-4fec-9344-6d0e9e1be2ae and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Damage Bonus and uuid bf5e9299-7142-4267-8575-98275c32b48b
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Unarmed Damage Bonus and uuid 518b25e9-cec4-4fec-9344-6d0e9e1be2ae and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Melee Damage Bonus and uuid 7d6ed602-8613-4856-8c40-d07c1db2acce
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Unarmed Damage Bonus and uuid 518b25e9-cec4-4fec-9344-6d0e9e1be2ae and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Ability Score_strength Modifier Bonus and uuid d5246dd8-0a9e-4bf9-ad4b-473c739c8b5c
# 0.0015153884887695312

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('afa6709c-692f-41a5-9fd0-5b0c4e6daa70'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, normalized_value=2), UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'): NumericalModifier(name='level 4 talent', uuid=UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('4338d23e-50b6-4139-ad86-0715849fcca8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Unarmed Attack Bonus and uuid 7f4d33b1-0154-4185-8334-1bb2de27d6a2
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Melee Attack Bonus and uuid 3c8f9714-15f0-4c7a-9333-bf5a064f1623
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Ability Score and uuid 26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid 2ea174de-1787-4c4e-b157-4415a85523b4
# 0.0014984607696533203

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name Armor Class Bonus and uuid bd04999f-9d01-4e91-9b6a-4c0f1b8c3021 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Unarmored Armor Class and uuid 66fcb06b-05fe-4ddd-bbe0-6f4752ef1d8c
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name Armor Class Bonus and uuid bd04999f-9d01-4e91-9b6a-4c0f1b8c3021 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Ability Score and uuid b86365af-8439-4470-976a-15d02ecf9fe7
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name Armor Class Bonus and uuid bd04999f-9d01-4e91-9b6a-4c0f1b8c3021 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid bb461b02-0894-41dc-b95a-59f02c30fc3e
# 0.0009999275207519531

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 7, Roll total: 12 vs target ac: 12 result: True
# 0.0004999637603759766

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name strength Ability Score and uuid 43f436bb-ae7d-49b2-98bb-87c82ea7e748 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid 8716b771-c906-472f-acba-4f53e0d45409
# Total Health before taking damage: 58
# Roll result: [1], Roll total: 7
# Total Health after taking damage: 52
# 0.0004999637603759766

# %%
damages
# Out:
# [Damage(name='Damage', description=None, uuid=UUID('ea6a0c9d-fa6f-4dff-99c2-297449e0421c'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('5804b91c-5824-4deb-989d-7802f59e572e'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000029893783BA0>, generated_from=[UUID('518b25e9-cec4-4fec-9344-6d0e9e1be2ae'), UUID('bf5e9299-7142-4267-8575-98275c32b48b'), UUID('7d6ed602-8613-4856-8c40-d07c1db2acce'), UUID('d5246dd8-0a9e-4bf9-ad4b-473c739c8b5c')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('d57abae7-160a-4758-8ac3-a2628f20165f'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000029893783BA0>, generated_from=[UUID('d583f852-d560-4881-b296-1aa86f59e617'), UUID('af1a0345-0daa-4047-8fa1-61d3722bb52a'), UUID('b03eccf3-ad9b-43b0-b97c-eb395c7dbd5f'), UUID('145dd043-4ac6-4200-9db1-2279bc5bae7e')], global_normalizer=False, value_modifiers={UUID('8592c8c1-cf09-4e67-9106-86b9d2d74f36'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('8592c8c1-cf09-4e67-9106-86b9d2d74f36'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000029893783BA0>, normalized_value=1), UUID('e227f81c-e663-45a0-a1e0-26f2d05bfcc8'): NumericalModifier(name='a past in the circus', uuid=UUID('e227f81c-e663-45a0-a1e0-26f2d05bfcc8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('983e912b-5669-4bdd-afd4-4672c5946655'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('983e912b-5669-4bdd-afd4-4672c5946655'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000298937832E0>, normalized_value=0), UUID('d9d09975-8857-4ef4-964e-0bb72a6c982a'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('d9d09975-8857-4ef4-964e-0bb72a6c982a'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000298937837E0>, normalized_value=0), UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, normalized_value=2), UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'): NumericalModifier(name='level 4 talent', uuid=UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_enti ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('24e03c3b-0cd0-4379-ba1a-f7a61d09e16f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('afa6709c-692f-41a5-9fd0-5b0c4e6daa70'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('24e03c3b-0cd0-4379-ba1a-f7a61d09e16f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('f93ba913-eb15-4a48-8252-4fdbe9315eab'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, normalized_value=2), UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'): NumericalModifier(name='level 4 talent', uuid=UUID('4ee89ecc-20c1-4975-8b56-630f88f0b8ca'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('4338d23e-50b6-4139-ad86-0715849fcca8'), source_entity_uuid=UUID('c1760451-d672-4909-a8b4-2c77ae96c71a'), source_entity_name=None, target_entity_uuid=UUID('24e03c3b-0cd0-4379-ba1a-f7a61d09e16f'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000029891FC1260>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Unarmed Attack Bonus and uuid 7f4d33b1-0154-4185-8334-1bb2de27d6a2
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Melee Attack Bonus and uuid 3c8f9714-15f0-4c7a-9333-bf5a064f1623
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Ability Score and uuid 26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Value and uuid 6967dfd3-5137-4d23-86e3-0c64bab88fdd and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid 2ea174de-1787-4c4e-b157-4415a85523b4
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name Armor Class Bonus and uuid bd04999f-9d01-4e91-9b6a-4c0f1b8c3021 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Unarmored Armor Class and uuid 66fcb06b-05fe-4ddd-bbe0-6f4752ef1d8c
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name Armor Class Bonus and uuid bd04999f-9d01-4e91-9b6a-4c0f1b8c3021 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Ability Score and uuid b86365af-8439-4470-976a-15d02ecf9fe7
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name Armor Class Bonus and uuid bd04999f-9d01-4e91-9b6a-4c0f1b8c3021 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid bb461b02-0894-41dc-b95a-59f02c30fc3e
# Target AC: 12
# Attack bonus: 5
# Roll result: 15, Roll total: 20 vs target ac: 12 result: True
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name strength Ability Score and uuid 26bfecc1-ecb9-4ce9-bb2c-ed9e842ccfe8 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid 2ea174de-1787-4c4e-b157-4415a85523b4
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Unarmed Damage Bonus and uuid 518b25e9-cec4-4fec-9344-6d0e9e1be2ae and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Damage Bonus and uuid bf5e9299-7142-4267-8575-98275c32b48b
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Unarmed Damage Bonus and uuid 518b25e9-cec4-4fec-9344-6d0e9e1be2ae and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name Melee Damage Bonus and uuid 7d6ed602-8613-4856-8c40-d07c1db2acce
# Validating others source id c1760451-d672-4909-a8b4-2c77ae96c71a against self source c1760451-d672-4909-a8b4-2c77ae96c71a for modifer  with name Unarmed Damage Bonus and uuid 518b25e9-cec4-4fec-9344-6d0e9e1be2ae and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Ability Score_strength Modifier Bonus and uuid 37366919-847c-4604-be99-f68d31f45544
# Validating others source id 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f against self source 24e03c3b-0cd0-4379-ba1a-f7a61d09e16f for modifer  with name strength Ability Score and uuid 43f436bb-ae7d-49b2-98bb-87c82ea7e748 and type <class 'dnd.core.values.ModifiableValue'> against <class 'dnd.core.values.ModifiableValue'> with name strength Modifier Bonus and uuid 8716b771-c906-472f-acba-4f53e0d45409
# Total Health before taking damage: 52
# Roll result: [1], Roll total: 7
# Total Health after taking damage: 46
# 0.11826086044311523
