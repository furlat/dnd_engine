# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior(name="Mona")

# %%
warrior.source_entity_uuid
# Out:
# UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('5b00c2cb-f93d-4192-9523-e40d84ad1fdf')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('5b00c2cb-f93d-4192-9523-e40d84ad1fdf'): AbilityScores(name='ability_scores', description=None, uuid=UUID('5b00c2cb-f93d-4192-9523-e40d84ad1fdf'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('0d493c15-ef9e-4dd7-b5fa-87265d71001a'): Ability(name='strength', description=None, uuid=UUID('0d493c15-ef9e-4dd7-b5fa-87265d71001a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('2d1a6d95-1587-45ca-8c05-d0a31bf9eb6a'): ModifiableValue(name='strength Ability Score', uuid=UUID('2d1a6d95-1587-45ca-8c05-d0a31bf9eb6a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d098e3c7-d3be-4ff6-adba-b8510038f8b0'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('876a5642-5f74-4e54-819b-ee13680652b7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('876a5642-5f74-4e54-819b-ee13680652b7'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'): NumericalModifier(name='level 4 talent', uuid=UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Damag ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('2d1a6d95-1587-45ca-8c05-d0a31bf9eb6a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d098e3c7-d3be-4ff6-adba-b8510038f8b0'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('876a5642-5f74-4e54-819b-ee13680652b7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('876a5642-5f74-4e54-819b-ee13680652b7'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'): NumericalModifier(name='level 4 talent', uuid=UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b617a348-3b8e-477f-b6c8-d6ae72c61b03'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 7

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 2

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.001001119613647461

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('2d1a6d95-1587-45ca-8c05-d0a31bf9eb6a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d098e3c7-d3be-4ff6-adba-b8510038f8b0'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('876a5642-5f74-4e54-819b-ee13680652b7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('876a5642-5f74-4e54-819b-ee13680652b7'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'): NumericalModifier(name='level 4 talent', uuid=UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b617a348-3b8e-477f-b6c8-d6ae72c61b03'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.0014998912811279297

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0010056495666503906

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 14, Roll total: 19 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 50
# 0.0005002021789550781

# %%
damages
# Out:
# [Damage(name='Damage', description=None, uuid=UUID('b5c5ee63-39de-45a3-bcd6-29a06f0838cc'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('497241a2-2289-40fb-8f88-0cf7876feef5'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('497241a2-2289-40fb-8f88-0cf7876feef5'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB9260>, generated_from=[UUID('7d187be1-5d29-42e3-bd8d-9d4b53499896'), UUID('44e8136e-f947-4251-a5f1-9849292de2a8'), UUID('15cf6db1-22e4-408e-b4ba-db438c3ecd97'), UUID('ac021ac7-0d31-4354-84da-c047195c082c')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('3ffdf30a-fa34-41d5-971c-9d24ee85a28a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB9260>, generated_from=[UUID('998d147a-1b74-4762-aa82-842fcef87f70'), UUID('4bff7cc8-6c0e-46fa-b074-1583dbe837f6'), UUID('4f41c265-b353-4401-aab7-73ed99ada7c5'), UUID('80701859-6970-463d-a9d7-007e64344d99')], global_normalizer=False, value_modifiers={UUID('788e447f-5dbf-40a5-ad41-59aeb9682138'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('788e447f-5dbf-40a5-ad41-59aeb9682138'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB9260>, normalized_value=1), UUID('ccb04c76-ed37-4222-b040-fd39f7d10b8a'): NumericalModifier(name='a past in the circus', uuid=UUID('ccb04c76-ed37-4222-b040-fd39f7d10b8a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('07e039ef-951b-4148-8dc5-d2f0cbfc18c9'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('07e039ef-951b-4148-8dc5-d2f0cbfc18c9'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB89A0>, normalized_value=0), UUID('1834af06-4756-47ba-8f50-c86a9ce403c1'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('1834af06-4756-47ba-8f50-c86a9ce403c1'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB8EA0>, normalized_value=0), UUID('876a5642-5f74-4e54-819b-ee13680652b7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('876a5642-5f74-4e54-819b-ee13680652b7'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'): NumericalModifier(name='level 4 talent', uuid=UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_n ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0015027523040771484

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0019996166229248047

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.001501321792602539

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('2d1a6d95-1587-45ca-8c05-d0a31bf9eb6a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d098e3c7-d3be-4ff6-adba-b8510038f8b0'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('876a5642-5f74-4e54-819b-ee13680652b7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('876a5642-5f74-4e54-819b-ee13680652b7'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'): NumericalModifier(name='level 4 talent', uuid=UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b617a348-3b8e-477f-b6c8-d6ae72c61b03'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 18, Roll total: 23 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 50
# Damage Roll result: [1], Roll total: 7
# Total Health after taking damage: 44
# 0.007498979568481445

# %%
from dnd.core.requests import SkillCheckRequest, SavingThrowRequest, SkillName

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request
# Out:
# SkillCheckRequest(dc=12, source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), context=None, skill_name='acrobatics')

# %%
strength_saving_throw_request
# Out:
# SavingThrowRequest(dc=12, source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), context=None, ability_name='strength')

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")
# Out:
# ModifiableValue(name='Value_acrobatics Skill Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('9e551ace-df06-4bcd-b672-1f388eb2c60e'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000024464F59800>, generated_from=[UUID('c59fe7ec-9c23-4ae2-bbd2-4cefb95fe6ff'), UUID('07019a5a-1633-43a3-aaae-9d3adc4d87b9'), UUID('e410a1a4-a87b-49ee-95e0-d2da64165da3'), UUID('98be38c3-26b9-4a84-8d8d-46a7e0703f53')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('372ad7c1-16e6-467e-8ead-a980e3695d23'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000024464F59800>, generated_from=[UUID('1f43ea8e-6eda-456c-b2b6-f624375a9ca4'), UUID('ee82a8d0-fe71-4633-91ec-e5ef31f11dde'), UUID('58d21a53-1a97-4b15-bbda-9ce3c76a7429'), UUID('55620356-12f3-4674-9c99-c6560c9006fe')], global_normalizer=False, value_modifiers={UUID('e1982ed7-84b0-4102-b203-d901341b0225'): NumericalModifier(name='Value_base_value', uuid=UUID('e1982ed7-84b0-4102-b203-d901341b0225'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=0, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000024464F59800>, normalized_value=0), UUID('9235857d-86e9-42b2-a751-3668f911e1a2'): NumericalModifier(name='a past in the circus', uuid=UUID('9235857d-86e9-42b2-a751-3668f911e1a2'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000024464F59800>, normalized_value=-2), UUID('ba03b489-f027-4723-9800-b63cf7eae00a'): NumericalModifier(name='acrobatics Skill Bonus_base_value', uuid=UUID('ba03b489-f027-4723-9800-b63cf7eae00a'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DBAAC0>, normalized_value=0), UUID('747ed227-bb78-49a2-bc76-9dbf2848812b'): NumericalModifier(name='a past in the circus', uuid=UUID('747ed227-bb78-49a2-bc76-9dbf2848812b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=7, score_normalizer=None, normalized_value=7), UUID('0a6eaed9-ebe9-42af-a9ee-d77f15e0fdd1'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('0a6eaed9-ebe9-42af-a9ee-d77f15e0fdd1'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=12, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=1), UUID('4f75cae0-bb7b-41cc-ae54-d4a7cea69f2a'): NumericalModifier(name='strength Modifier Bonus_base_value', uuid=UUID('4f75cae0-bb7b-41cc-ae54-d4a7cea69f2a'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB9E40>, normalized_value=0)}, min_constraints={}, max_co ...

# %%
warrior2.skill_check(acrobatics_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 6
# Roll result: 8, Roll total: 14 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('36feabc4-eb31-4583-9ace-44a175edf561'), dice_uuid=UUID('99eae787-f657-4434-b775-f504548b82da'), roll_type=<RollType.ATTACK: 'Attack'>, results=8, total=14, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  True)

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 17, Roll total: 17 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('7c972f93-f004-4703-9dc9-bb3bda02ca59'), dice_uuid=UUID('c2372cf4-80af-409d-9d9a-95d08efbbd26'), roll_type=<RollType.ATTACK: 'Attack'>, results=17, total=17, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  True)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")
# Out:
# ModifiableValue(name='Value_strength_saving_throw Saving Throw Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('3ab30246-f3a6-451a-b4c0-c2f721f9aa24'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000024464F598A0>, generated_from=[UUID('c59fe7ec-9c23-4ae2-bbd2-4cefb95fe6ff'), UUID('39aabb07-97cc-4a38-9491-70de6a6fcc56'), UUID('8e79a785-8c01-4215-ae0d-47b34e11cd6b'), UUID('83b80e02-12c8-4428-90ce-f5fb97fe4ed3')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('66eeb67a-4d34-493c-9de6-fde37fbc1a0e'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000024464F598A0>, generated_from=[UUID('1f43ea8e-6eda-456c-b2b6-f624375a9ca4'), UUID('afec204a-d130-4bff-96c5-e7b04a2fc206'), UUID('c8bce1e4-878e-494d-b7d9-1f147d866de9'), UUID('860bf416-e92a-4492-92f2-577ec76e8952')], global_normalizer=False, value_modifiers={UUID('e1982ed7-84b0-4102-b203-d901341b0225'): NumericalModifier(name='Value_base_value', uuid=UUID('e1982ed7-84b0-4102-b203-d901341b0225'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=0, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000024464F598A0>, normalized_value=0), UUID('9235857d-86e9-42b2-a751-3668f911e1a2'): NumericalModifier(name='a past in the circus', uuid=UUID('9235857d-86e9-42b2-a751-3668f911e1a2'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000024464F598A0>, normalized_value=-1), UUID('bc1f24c9-4a6b-49b9-8a55-2e19a6e7727f'): NumericalModifier(name='strength_saving_throw Saving Throw Bonus_base_value', uuid=UUID('bc1f24c9-4a6b-49b9-8a55-2e19a6e7727f'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464E38CC0>, normalized_value=0), UUID('bb592947-db31-46c7-a828-8482ee3c702b'): NumericalModifier(name='a past in the circus', uuid=UUID('bb592947-db31-46c7-a828-8482ee3c702b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'): NumericalModifier(name='level 4 talent', uuid=UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('b89b6f06-7713-4e47-96d4-91636825e440'): NumericalModifier(name='strength Modifier  ...

# %%
warrior2.saving_throw(strength_saving_throw_request)
# Out:
# Target AC: 12
# Attack bonus: 4
# Roll result: 19, Roll total: 23 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('752c0810-7067-406b-bb1f-2689472a63ce'), dice_uuid=UUID('e1c77081-71c8-487f-806d-e9028583627e'), roll_type=<RollType.ATTACK: 'Attack'>, results=19, total=23, bonus=4, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  True)

# %%
from dnd.conditions import Blinded

blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# True

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('8e79a785-8c01-4215-ae0d-47b34e11cd6b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('c8bce1e4-878e-494d-b7d9-1f147d866de9'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'): NumericalModifier(name='level 4 talent', uuid=UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('46eff969-39c2-409d-8d83-0513fc960201'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 7, Roll total: 10 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('cd09c2be-b76a-4c6e-95fa-ef336d575bd6'), dice_uuid=UUID('516f81c2-659a-47be-ae41-0a6b907c3449'), roll_type=<RollType.ATTACK: 'Attack'>, results=7, total=10, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  [])

# %%
warrior.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior.attack(warrior2.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('2d1a6d95-1587-45ca-8c05-d0a31bf9eb6a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d098e3c7-d3be-4ff6-adba-b8510038f8b0'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('876a5642-5f74-4e54-819b-ee13680652b7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('876a5642-5f74-4e54-819b-ee13680652b7'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'): NumericalModifier(name='level 4 talent', uuid=UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('b617a348-3b8e-477f-b6c8-d6ae72c61b03'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 18, Roll total: 23 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# Total Health before taking damage: 44
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 36
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('fbe91750-3704-4f4a-bbb0-f788ae5485bd'), dice_uuid=UUID('7af3da4f-bfb0-4f26-a769-db117b8e318c'), roll_type=<RollType.ATTACK: 'Attack'>, results=18, total=23, bonus=5, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('d7b5fcf3-7eb7-444c-8d17-4e92f114b162'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, blocks={}, values={UUID('0cd96df8-ca3a-40b3-86cd-cb6d3dbe5f26'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('0cd96df8-ca3a-40b3-86cd-cb6d3dbe5f26'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB9260>, generated_from=[UUID('7d187be1-5d29-42e3-bd8d-9d4b53499896'), UUID('44e8136e-f947-4251-a5f1-9849292de2a8'), UUID('15cf6db1-22e4-408e-b4ba-db438c3ecd97'), UUID('c7193ac6-f5e6-4927-99e8-1b54a497648b')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('be82cbf1-2da7-49a9-af08-1111b7122fd6'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB9260>, generated_from=[UUID('998d147a-1b74-4762-aa82-842fcef87f70'), UUID('4bff7cc8-6c0e-46fa-b074-1583dbe837f6'), UUID('4f41c265-b353-4401-aab7-73ed99ada7c5'), UUID('5be46115-f188-4d79-add4-b1006df4fdf7')], global_normalizer=False, value_modifiers={UUID('788e447f-5dbf-40a5-ad41-59aeb9682138'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('788e447f-5dbf-40a5-ad41-59aeb9682138'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB9260>, normalized_value=1), UUID('ccb04c76-ed37-4222-b040-fd39f7d10b8a'): NumericalModifier(name='a past in the circus', uuid=UUID('ccb04c76-ed37-4222-b040-fd39f7d10b8a'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('07e039ef-951b-4148-8dc5-d2f0cbfc18c9'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('07e039ef-951b-4148-8dc5-d2f0cbfc18c9'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB89A0>, normalized_value=0), UUID('1834af06-4756-47ba-8f50-c86a9ce403c1'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('1834af06-4756-47ba-8f50-c86a9ce403c1'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000024464DB8EA0>, normalized_value=0), UUID('876a5642-5f74-4e54-819b-ee13680652b7'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('876a5642-5f74-4e54-819b-ee13680652b7'), source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e7873b98-2c23-4800-a21a-d9f1f9d0fc85'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('f36259a0-f01e-40e4-a358-fbeed8acd7dc'), dice_uuid=UUID('ce6192c4-a66a-428d-972b-6c1816ac3da5'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[3], total=9, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
blinded.modifers_uuids
# Out:
# {UUID('7cc03791-3cd2-4b72-9f8a-658d3ab22dbd'): [UUID('655ea651-b25a-4be7-bd14-87c709f94288')],
#  UUID('bb87b2e2-7828-46d4-b1f6-1fb7333e7e56'): [UUID('7025bb87-77af-4f35-90c7-698b8420a949')],
#  UUID('7af28e2b-b312-4a4a-87bc-8d011a91b9ab'): [UUID('1c1d6991-3c39-4317-953b-774e4676e568')],
#  UUID('9f3484fb-163d-490d-b25f-be01280fc18b'): [UUID('4cae76a3-83be-4d82-b757-a4d5d47e5a6e')],
#  UUID('4f3424e2-2f16-453f-93fb-301ef6bd897d'): [UUID('d48af2fe-e820-4519-a932-6e7bc79015e5')],
#  UUID('c04bc004-b533-433a-83a2-231a89c699e0'): [UUID('f94574f4-6dc6-4cbd-b2dd-aa100b027c74')]}

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 14, Roll total: 14 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('b7d82247-bf4f-4451-bfe1-4e3e44440e88'), dice_uuid=UUID('3814c379-ed36-4465-baf4-51e01f5e388d'), roll_type=<RollType.ATTACK: 'Attack'>, results=14, total=14, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  False)

# %%
blinded.remove()
# Out:
# True

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 10, Roll total: 10 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('77da3091-3f77-44e5-b36f-d00a84fb3229'), dice_uuid=UUID('3ebd4650-410e-4ca5-89da-f253c7581936'), roll_type=<RollType.ATTACK: 'Attack'>, results=10, total=10, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  False)

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('8e79a785-8c01-4215-ae0d-47b34e11cd6b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('c8bce1e4-878e-494d-b7d9-1f147d866de9'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'): NumericalModifier(name='level 4 talent', uuid=UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('46eff969-39c2-409d-8d83-0513fc960201'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 2, Roll total: 5 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('fb839004-5ae2-4acf-a06a-747f110321fa'), dice_uuid=UUID('a8fe4a7e-9596-4e81-a625-21fc8f444d5e'), roll_type=<RollType.ATTACK: 'Attack'>, results=2, total=5, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  [])

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()
# Out:
# True

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('8e79a785-8c01-4215-ae0d-47b34e11cd6b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('c8bce1e4-878e-494d-b7d9-1f147d866de9'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('ace3b56e-ecf1-4ff7-8a20-adbb7b33d83b'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, normalized_value=2), UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'): NumericalModifier(name='level 4 talent', uuid=UUID('e15fdd96-d90c-4270-9738-9a50701f4c4d'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('46eff969-39c2-409d-8d83-0513fc960201'), source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), source_entity_name=None, target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000024462335C60>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# charmer_id: da1dd86e-d16a-4626-9f4e-42f57baaaef8, source_entity_uuid: 5b2055e7-79b5-4ed9-8a8e-6cc767f863bd, target_entity_uuid: da1dd86e-d16a-4626-9f4e-42f57baaaef8
# Roll result: 11, Roll total: 14 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('a2b50fcb-f206-4e42-9371-03263a50223b'), dice_uuid=UUID('a1a71426-96d3-4a30-bef6-0d002e02f8d8'), roll_type=<RollType.ATTACK: 'Attack'>, results=11, total=14, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), target_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), attack_outcome=None),
#  [])

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)
# Out:
# Target AC: 15
# Attack bonus: 0
# charmer_id: da1dd86e-d16a-4626-9f4e-42f57baaaef8,charmed_id: 5b2055e7-79b5-4ed9-8a8e-6cc767f863bd, source_entity_uuid: 5b2055e7-79b5-4ed9-8a8e-6cc767f863bd, target_entity_uuid: da1dd86e-d16a-4626-9f4e-42f57baaaef8
# charmer_id: da1dd86e-d16a-4626-9f4e-42f57baaaef8,charmed_id: 5b2055e7-79b5-4ed9-8a8e-6cc767f863bd, source_entity_uuid: 5b2055e7-79b5-4ed9-8a8e-6cc767f863bd, target_entity_uuid: da1dd86e-d16a-4626-9f4e-42f57baaaef8
# Roll result: 12, Roll total: 12 vs target ac: 15 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# charmer_id: da1dd86e-d16a-4626-9f4e-42f57baaaef8,charmed_id: 5b2055e7-79b5-4ed9-8a8e-6cc767f863bd, source_entity_uuid: 5b2055e7-79b5-4ed9-8a8e-6cc767f863bd, target_entity_uuid: da1dd86e-d16a-4626-9f4e-42f57baaaef8
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('0e0ff277-60d0-452e-89a7-51d35c5de2d6'), dice_uuid=UUID('1ef449ab-57e6-420c-81aa-98e009701582'), roll_type=<RollType.ATTACK: 'Attack'>, results=12, total=12, bonus=0, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('da1dd86e-d16a-4626-9f4e-42f57baaaef8'), target_entity_uuid=UUID('5b2055e7-79b5-4ed9-8a8e-6cc767f863bd'), attack_outcome=None),
#  False)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)
# Out:
# UUID('959875d7-af26-4d4e-b592-1c39d9d23697')

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score
# Out:
# 5

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score
# Out:
# 0

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()
# Out:
# True

# %%
warrior.action_economy.movement.normalized_score
# Out:
# 0

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score
# Out:
# 30
