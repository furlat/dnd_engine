# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4
from dnd.core.events import EventQueue

import time
from uuid import UUID

# %%
start_time = time.time()
source_id = uuid4()
proficiency_bonus = 2

# %%
q = EventQueue()

# %%
warrior = create_warrior(source_id,proficiency_bonus,position=(0,0))
q._all_events
# Out:
# [ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('7a5bf80f-6fa0-4352-99fa-85d3bf7663a3'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 240680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resista ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('e000b232-6872-4d8a-b047-56f13553461f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 240680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceSt ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('965cb175-3e7c-409b-8790-1311090b0fb6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 241187), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.N ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('ff318b23-1806-4088-b57f-2dee4bb6065f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 241187), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resistance ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('96a5af10-1383-4f6e-ae0c-1ed4b5dc7c97'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <R ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('d6fa98d6-98f7-44fd-83bf-aa3da2c6cf02'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resist ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('ddad7516-d760-4983-9d7d-84e4c1f37d9b'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceSt ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('0bea82b6-d8e6-470a-9955-e052427e68d5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resi ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('7f9354dc-c954-45da-a153-53fe8568fea4'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0ad591f0-41d8-4fed-8e5a-4eb0c1b2d0ee'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('384c0cf6-3cc8-4558-9ed9-82d28978d7d9'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'): ModifiableValue(name='Attack Bonus', uuid=UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('2bdb8c0b-c9a5-4797-bdf2-a49c4f311a12'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('c020171e-a656-4392-a689-9e45bff5fdca'): AdvantageModifier(name='Rusty Blade', uuid=UUID('c020171e-a656-4392-a689-9e45bff5fdca'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.N ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('8a469820-967d-4372-9f7c-cd2f8996380d'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0ad591f0-41d8-4fed-8e5a-4eb0c1b2d0ee'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('384c0cf6-3cc8-4558-9ed9-82d28978d7d9'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'): ModifiableValue(name='Attack Bonus', uuid=UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('2bdb8c0b-c9a5-4797-bdf2-a49c4f311a12'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('c020171e-a656-4392-a689-9e45bff5fdca'): AdvantageModifier(name='Rusty Blade', uuid=UUID('c020171e-a656-4392-a689-9e45bff5fdca'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE:  ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('dc8a4ca3-df25-4139-80c1-3b09380bb64f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0ad591f0-41d8-4fed-8e5a-4eb0c1b2d0ee'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('384c0cf6-3cc8-4558-9ed9-82d28978d7d9'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'): ModifiableValue(name='Attack Bonus', uuid=UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('2bdb8c0b-c9a5-4797-bdf2-a49c4f311a12'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('c020171e-a656-4392-a689-9e45bff5fdca'): AdvantageModifier(name='Rusty Blade', uuid=UUID('c020171e-a656-4392-a689-9e45bff5fdca'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None' ...
# ...
#  ConditionApplicationEvent(name='Elemental Weapon Mastery', uuid=UUID('5bb2ca04-ebaf-4231-bbdb-8e0b09e72f10'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, lineage_uuid=UUID('f8d6d5bc-5b33-496c-a37e-99d7f24f2d10'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 303786), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Weapon Mastery contextual advantage modifier condition to Ganger', lineage_children_events=[], children_events=[], condition=ElementalWeaponMastery(name='Elemental Weapon Mastery', uuid=UUID('4bbe9a3c-9187-4814-943c-7248cdbf4d0b'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('58ca1126-8208-4e2d-93b5-b9918b47b2fb'), source_entity_uuid=UUID('a45ce65e-9085-4801-8ee2-a0fb672c861f'), source_entity_name=None, target_entity_uuid=UUID('ba5e5822-0739-4836-b314-b59db0fff361'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('4bbe9a3c-9187-4814-943c-7248cdbf4d0b'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('ead2c659-02f5-48f2-8186-1416eefb63ea'): [UUID('b00d3278-f74d-4063-8c41-3118af5873c6')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='You have advantage on attack rolls made with weapons that deal acid, cold, fire, lightning, poison, or thunder damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('b03e48b8-a7fa-433d-a682-1fdbf12565ba'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, lineage_uuid=UUID('fcdb10fa-41a4-4924-867c-91e86628087a'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34,
857-f33be96fb1e4')], UUID('16596801-7477-46c4-b2eb-3dbe7d919e0b'): [UUID('a35dbd56-24da-4b39-af20-9d8c69277a2a')], UUID('81c9548c-cb48-4472-9154-997cba7425c0'): [UUID('a486dcc9-bf77-462c-8658-3e7b8afad2a0')], UUID('7792b32b-d31f-451f-8aa4-80c5b064ae84'): [UUID('2f5a4c38-7f23-4dcd-9f74-719fd7e34ba2')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('887dd2a0-5a56-40ef-8f64-67af2c96316c'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, lineage_uuid=UUID('0885d1f4-7a35-444f-aed2-1ed3a71310ff'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 304285), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Ganger', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('9f6b2b71-72dc-4038-8622-1b5aebe7f1b4'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('c1c114cd-d46e-4ea0-80dc-cbe0b3bee23b'), source_entity_uuid=UUID('351cba75-63d0-440b-8986-44c241d381c2'), source_entity_name=None, target_entity_uuid=UUID('a90289aa-b0e6-4ead-bac1-c45ee6cc2a32'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('9f6b2b71-72dc-4038-8622-1b5aebe7f1b4'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('ce89d67d-5f1c-47f2-80ba-34c1c0045a8d'): [UUID('fb272eef-1861-4958-82f0-491091d7bcd9')], UUID('e59a63b7-defe-491d-aa2f-7c265998a112'): [UUID('910740c7-72ad-4767-b5cd-72019d37e05a')], UUID('ca3ea128-68d0-4e75-a93e-51a714b0f45d'): [UUID('4b3e6fde-54c0-44c4-8c60-be9b988e5f4a')], UUID('014e8aa8-e68a-4f4e-a1bb-48c3743edd0b'): [UUID('d770bf5e-31f8-419b-82f4-a6d8b634e6ea')], UUID('c198875b-4f00-4d1b-81c3-6680c60a6b73'): [UUID('ce807b21-8543-4ec8-86db-7911304f5aa9')], UUID('85101967-33c5-484b-b513-793c22c18968'): [UUID('5551de16-2416-48de-9857-f33be96fb1e4')], UUID('16596801-7477-46c4-b2eb-3dbe7d919e0b'): [UUID('a35dbd56-24da-4b39-af20-9d8c69277a2a')], UUID('81c9548c-cb48-4472-9154-997cba7425c0'): [UUID('a486dcc9-bf77-462c-8658-3e7b8afad2a0')], UUID('7792b32b-d31f-451f-8aa4-80c5b064ae84'): [UUID('2f5a4c38-7f23-4dcd-9f74-719fd7e34ba2')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('6d2fad1b-b8b8-41ad-8936-26d8a36ee79c'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, lineage_uuid=UUID('0885d1f4-7a35-444f-aed2-1ed3a71310ff'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 304285), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Ganger', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('9f6b2b71-72dc-4038-8622-1b5aebe7f1b4'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('c1c114cd-d46e-4ea0-80dc-cbe0b3bee23b'), source_entity_uuid=UUID('351cba75-63d0-440b-8986-44c241d381c2'), source_entity_name=None, target_entity_uuid=UUID('a90289aa-b0e6-4ead-bac1-c45ee6cc2a32'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('9f6b2b71-72dc-4038-8622-1b5aebe7f1b4'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('ce89d67d-5f1c-47f2-80ba-34c1c0045a8d'): [UUID('fb272eef-1861-4958-82f0-491091d7bcd9')], UUID('e59a63b7-defe-491d-aa2f-7c265998a112'): [UUID('910740c7-72ad-4767-b5cd-72019d37e05a')], UUID('ca3ea128-68d0-4e75-a93e-51a714b0f45d'): [UUID('4b3e6fde-54c0-44c4-8c60-be9b988e5f4a')], UUID('014e8aa8-e68a-4f4e-a1bb-48c3743edd0b'): [UUID('d770bf5e-31f8-419b-82f4-a6d8b634e6ea')], UUID('c198875b-4f00-4d1b-81c3-6680c60a6b73'): [UUID('ce807b21-8543-4ec8-86db-7911304f5aa9')], UUID('85101967-33c5-484b-b513-793c22c18968'): [UUID('5551de16-2416-48de-9857-f33be96fb1e4')], UUID('16596801-7477-46c4-b2eb-3dbe7d919e0b'): [UUID('a35dbd56-24da-4b39-af20-9d8c69277a2a')], UUID('81c9548c-cb48-4472-9154-997cba7425c0'): [UUID('a486dcc9-bf77-462c-8658-3e7b8afad2a0')], UUID('7792b32b-d31f-451f-8aa4-80c5b064ae84'): [UUID('2f5a4c38-7f23-4dcd-9f74-719fd7e34ba2')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.'))]

# %%
warrior2 = create_warrior(name="Mona",position=(1,1))
q._all_events
# Out:
# [ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('7a5bf80f-6fa0-4352-99fa-85d3bf7663a3'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 240680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resista ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('e000b232-6872-4d8a-b047-56f13553461f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 240680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceSt ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('965cb175-3e7c-409b-8790-1311090b0fb6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 241187), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.N ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('ff318b23-1806-4088-b57f-2dee4bb6065f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('e052da6b-704b-4433-8310-051fd73f8477'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 241187), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('30abaa31-4ca8-4ee9-8534-b1bbd336f3dd'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'): ModifiableValue(name='Armor Class', uuid=UUID('6ec2c4f9-0121-4288-be1c-b14b041ef0ce'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a0895ce8-cc9f-46ea-8483-8a03d0fc50db'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('c2d56066-15e8-46ad-868a-41bbc084fc39'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210F40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resistance ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('96a5af10-1383-4f6e-ae0c-1ed4b5dc7c97'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <R ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('d6fa98d6-98f7-44fd-83bf-aa3da2c6cf02'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resist ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('ddad7516-d760-4983-9d7d-84e4c1f37d9b'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceSt ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('0bea82b6-d8e6-470a-9955-e052427e68d5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('d88e6790-f0fc-4e78-9313-62990f0da63d'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('c8adbbf3-c690-4203-ad00-a0c9c5ba177f'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'): ModifiableValue(name='Attack Bonus', uuid=UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, generated_from=[], global_normalizer=True, value_modifiers={UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resi ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('7f9354dc-c954-45da-a153-53fe8568fea4'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0ad591f0-41d8-4fed-8e5a-4eb0c1b2d0ee'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('384c0cf6-3cc8-4558-9ed9-82d28978d7d9'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'): ModifiableValue(name='Attack Bonus', uuid=UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('2bdb8c0b-c9a5-4797-bdf2-a49c4f311a12'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('c020171e-a656-4392-a689-9e45bff5fdca'): AdvantageModifier(name='Rusty Blade', uuid=UUID('c020171e-a656-4392-a689-9e45bff5fdca'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.N ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('8a469820-967d-4372-9f7c-cd2f8996380d'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0ad591f0-41d8-4fed-8e5a-4eb0c1b2d0ee'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 297264), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('384c0cf6-3cc8-4558-9ed9-82d28978d7d9'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'): ModifiableValue(name='Attack Bonus', uuid=UUID('c337e13e-d45c-48e1-b00d-c5418140d7f0'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('2bdb8c0b-c9a5-4797-bdf2-a49c4f311a12'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('0ab4fa67-660c-49fc-b23a-ecf5efafce24'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402109A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('c020171e-a656-4392-a689-9e45bff5fdca'): AdvantageModifier(name='Rusty Blade', uuid=UUID('c020171e-a656-4392-a689-9e45bff5fdca'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NON
d24a3d959')], UUID('f431b9e7-8214-4ca7-bd21-2f06fd2ea58d'): [UUID('7ce4636e-5a46-44ef-8c56-50e71131b467')], UUID('0d73c51f-10d3-4692-aff6-03706dc2d91c'): [UUID('046c8b4f-0c09-4750-b877-bcae63bd6252')], UUID('8faaf599-eef9-4010-aced-95d4aed7724c'): [UUID('022c696a-ada5-4c52-9685-19e0986c9052')], UUID('3b4278cc-3350-4f84-bbb1-2ecf62b71768'): [UUID('4f330957-103f-4878-ad4a-f191b6fce768')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('fdd15ca8-dfc7-4df8-9b81-17287a571791'), source_entity_uuid=UUID('5e8c8c3f-882b-4451-8291-8246cec451b0'), source_entity_name=None, target_entity_uuid=UUID('5e8c8c3f-882b-4451-8291-8246cec451b0'), target_entity_name=None, context=None, lineage_uuid=UUID('5155c946-ead6-4270-b0ce-f0457c80e9d9'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 365798), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Mona', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('6c1e7498-33c7-4e48-9b72-57cde985d058'), source_entity_uuid=UUID('5e8c8c3f-882b-4451-8291-8246cec451b0'), source_entity_name=None, target_entity_uuid=UUID('5e8c8c3f-882b-4451-8291-8246cec451b0'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('52e646b7-1de4-4bc8-8795-2a99d4b61c56'), source_entity_uuid=UUID('6f20903d-149e-44dd-844f-eb35c9bd19fc'), source_entity_name=None, target_entity_uuid=UUID('5276aada-e77a-417d-a7cc-358b369eaf7e'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('6c1e7498-33c7-4e48-9b72-57cde985d058'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('7c9be7b9-21d8-4134-abab-a13dd5a4a6aa'): [UUID('c6b3986d-2265-49a5-8a9c-f47a58a9d65c')], UUID('35772721-19bb-4b15-9fd4-645a5e95a7fa'): [UUID('4fd6cf8d-07c3-459b-8065-d067395cd781')], UUID('7a2d000e-0df7-47a1-b3d5-e0338105e539'): [UUID('39d782f6-5898-41de-925b-3cfbdbf99f0c')], UUID('17c7d534-0541-46db-80f1-d0f7b783b25c'): [UUID('1f903c27-5ff2-4c36-8bb1-2a4f7fc73677')], UUID('6f3a6bcf-059f-4f2a-aa6e-0d19fc8070ba'): [UUID('7a89a887-426b-4c53-83b9-bacd24a3d959')], UUID('f431b9e7-8214-4ca7-bd21-2f06fd2ea58d'): [UUID('7ce4636e-5a46-44ef-8c56-50e71131b467')], UUID('0d73c51f-10d3-4692-aff6-03706dc2d91c'): [UUID('046c8b4f-0c09-4750-b877-bcae63bd6252')], UUID('8faaf599-eef9-4010-aced-95d4aed7724c'): [UUID('022c696a-ada5-4c52-9685-19e0986c9052')], UUID('3b4278cc-3350-4f84-bbb1-2ecf62b71768'): [UUID('4f330957-103f-4878-ad4a-f191b6fce768')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.'))]

# %%
q._events_by_lineage[UUID("2447f19b-7dac-4743-bf95-aadf34a9b712")]
# Out:
# []

# %%
from dnd.actions import Attack
weapon_slot = WeaponSlot.MAIN_HAND

# %%
warrior.senses.add_entity(warrior2.uuid,warrior2.position)
warrior2.senses.add_entity(warrior.uuid,warrior.position)

# %%
attack = Attack(name="Warrior Main Hand attack",
                source_entity_uuid=warrior.uuid,
                target_entity_uuid=warrior2.uuid,
                weapon_slot= WeaponSlot.MAIN_HAND)

# %%
warrior2.get_hp()
# Out:
# 58

# %%
attack.apply()
# Out:
# cost actions 1 <function entity_action_economy_cost_evaluator at 0x0000023A413D3F60>
# actions cazzo minchia 1 1
# AttackEvent(name='Warrior Main Hand attack', uuid=UUID('066f6e3a-32a7-4801-bab9-447398837b56'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('5e8c8c3f-882b-4451-8291-8246cec451b0'), target_entity_name=None, context=None, lineage_uuid=UUID('2e502736-6020-4cb5-a3d4-b8792a684d00'), timestamp=datetime.datetime(2025, 5, 12, 1, 16, 34, 474086), event_type=<EventType.ATTACK: 'attack'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Attack completed', lineage_children_events=[], children_events=[], costs=[Cost(name='Attack Cost', cost_type='actions', cost=1, evaluator=<function entity_action_economy_cost_evaluator at 0x0000023A413D3F60>)], weapon_slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, range=Range(type=<RangeType.REACH: 'Reach'>, normal=5, long=None), attack_bonus=ModifiableValue(name='Value_Attack Bonus_Attack Bonus_Melee Attack Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('7e3825cb-2401-484e-aa62-c7f4add0fe21'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('5e8c8c3f-882b-4451-8291-8246cec451b0'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402107C0>, generated_from=[UUID('7792b32b-d31f-451f-8aa4-80c5b064ae84'), UUID('818a7d1f-3b73-4c7a-a9f5-54833e5ecef6'), UUID('ead2c659-02f5-48f2-8186-1416eefb63ea'), UUID('5ad76cf7-0091-495e-aa08-9d57e2a7b7a4'), UUID('c22c5172-35fa-4f08-9f9c-bc444020f547'), UUID('539826b7-2fc3-43da-aab5-f918d864924d')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value_A Value', uuid=UUID('0d0a7eef-6543-4e92-9470-af5a81a73a92'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('5e8c8c3f-882b-4451-8291-8246cec451b0'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402107C0>, generated_from=[UUID('94d384b0-651c-4eef-9546-2e433a06c0cc'), UUID('30fb1b13-4927-418a-a493-bcd769eaa0c2'), UUID('f278ed0b-8e0d-468a-baec-6a9328e61e05'), UUID('98f0b9eb-04ae-4e2c-9dcc-1f4bcd340849'), UUID('326d7d1a-7f3e-4bc9-b8a6-27ef7c64b1d8'), UUID('91d97c3e-9069-4f33-9ab2-4de65393af20')], global_normalizer=False, value_modifiers={UUID('a89b2a6a-c44f-4828-b439-d8f1ccf51828'): NumericalModifier(name='Value_base_value', uuid=UUID('a89b2a6a-c44f-4828-b439-d8f1ccf51828'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=2, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A402107C0>, normalized_value=2), UUID('2f5a4c38-7f23-4dcd-9f74-719fd7e34ba2'): NumericalModifier(name='Circus Training', uuid=UUID('2f5a4c38-7f23-4dcd-9f74-719fd7e34ba2'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=-1, score_normalizer=None, normalized_value=-1), UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('33397e0f-e176-4e0a-84b1-a2ef44f6c4b5'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000023A40210C20>, normalized_value=0), UUID('f0c13c6d-bca7-4e6d-adae-973ed170e5e9'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('f0c13c6d-bca7-4e6d-adae-973ed170e5e9'), source_entity_uuid=UUID('0dc54d5a-64c2-414d-8c8e-aa3ea68a4a0b'), source_entity_name=None, target_entity_uuid=UUID(' ...

# %%
attack.apply()
# Out:
# cost actions 1 <function entity_action_economy_cost_evaluator at 0x0000023A413D3F60>
# actions cazzo minchia 0 1

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
for event in q._all_events:
    print(event.name,event.status_message)
# Out:
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Dual Wielder None
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Ganger
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Ganger
# Elemental Weapon Mastery None
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Ganger
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Ganger
# Elemental Affinity None
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Ganger
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Ganger
# Circus Performer None
# Circus Performer Applied Circus Performer condition to Ganger
# Circus Performer Applied Circus Performer condition to Ganger
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Dual Wielder None
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Mona
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Mona
# Elemental Weapon Mastery None
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Mona
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Mona
# Elemental Affinity None
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Mona
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Mona
# Circus Performer None
# Circus Performer Applied Circus Performer condition to Mona
# Circus Performer Applied Circus Performer condition to Mona
# Warrior Main Hand attack None
# Warrior Main Hand attack Validated range for Warrior Main Hand attack - added range to event
# Warrior Main Hand attack Validated line of sight for Warrior Main Hand attack
# Warrior Main Hand attack Attack validated for Warrior Main Hand attack
# Warrior Main Hand attack Rolling attack
# Warrior Main Hand attack Attack rolled 23 and AttackOutcome.HIT
# Warrior Main Hand attack Dealing damage
# Warrior Main Hand attack Attack completed

# %%
warrior2.get_hp()
# Out:
# 54

# %%
warrior.action_economy.actions.normalized_score
# Out:
# 0

# %%
warrior.action_economy.actions.self_static.value_modifiers
# Out:
# {UUID('ae6a0176-d3df-4528-bcfd-d5ccf8c469e8'): NumericalModifier(name='Actions_base_value', uuid=UUID('ae6a0176-d3df-4528-bcfd-d5ccf8c469e8'), source_entity_uuid=UUID('af7d2079-0a4a-4228-8cc7-18554f5f86aa'), source_entity_name=None, target_entity_uuid=UUID('af7d2079-0a4a-4228-8cc7-18554f5f86aa'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000182A63300E0>, normalized_value=1),
#  UUID('07800008-c663-4e07-91fc-4b6af1bdc040'): NumericalModifier(name='cost', uuid=UUID('07800008-c663-4e07-91fc-4b6af1bdc040'), source_entity_uuid=UUID('af7d2079-0a4a-4228-8cc7-18554f5f86aa'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=None, normalized_value=-1)}

# %%
warrior.action_economy.reset_all_costs()

# %%
warrior.action_economy.actions.normalized_score
# Out:
# 1

# %%
warrior.source_entity_uuid
# Out:
# UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('4bf62a8d-f496-44e9-b0ed-ddb80abd6d21')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands.', uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('4bf62a8d-f496-44e9-b0ed-ddb80abd6d21'): AbilityScores(name='ability_scores', description=None, uuid=UUID('4bf62a8d-f496-44e9-b0ed-ddb80abd6d21'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('231cdc5b-de31-4f75-abae-dfd42987107f'): Ability(name='strength', description=None, uuid=UUID('231cdc5b-de31-4f75-abae-dfd42987107f'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('4acab144-14a4-44ce-9897-1e8de35c602b'): ModifiableValue(name='strength Ability Score', uuid=UUID('4acab144-14a4-44ce-9897-1e8de35c602b'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000180CF515440>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('6fe56204-56c1-4962-846e-cd0fbbfb06a0'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000180CF515440>, generated_from=[], global_normalizer=True, value_modifiers={UUID('56bca55e-32f3-4dfe-a9a8-f1ee594b2f96'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('56bca55e-32f3-4dfe-a9a8-f1ee594b2f96'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000180CF515440>, normalized_value=2), UUID('5567d081-a5b5-49fb-879c-e1d35d646382'): NumericalModifier(name='level 4 talent', uuid=UUID('5567d081-a5b5-49fb-879c-e1d35d646382'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Dama ...

# %%
from dnd.conditions import Paralyzed

# %%
paralyzed_condition = Paralyzed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
paralyzed_condition.apply()
# Out:
# ConditionApplicationEvent(name='Paralyzed', uuid=UUID('f786dab7-daa2-4c92-b3a5-799509eb8f03'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=UUID('72649558-23a3-4397-b5be-2abc1fa36c78'), target_entity_name=None, context=None, lineage_uuid=UUID('9b0e900e-a1c5-4cdf-95f2-ffacf0295769'), timestamp=datetime.datetime(2025, 5, 11, 19, 9, 3, 810441), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Paralyzed to target contextual critical modifier to Mona', lineage_children_events=[UUID('a9b3031e-e6e3-420f-a7ba-3e8fea24e13a'), UUID('219eb697-cc94-4117-82f8-90bc5bc98c68'), UUID('f8796037-ca17-4349-8eae-2bd721c08d58'), UUID('b1e88ea5-b149-4477-b1c0-6af5c568fc38'), UUID('d2cedcd6-df90-4d8a-8a5a-4190a8f53fd3'), UUID('ffece060-7512-45f7-b464-d44834654be9'), UUID('a9b3031e-e6e3-420f-a7ba-3e8fea24e13a'), UUID('219eb697-cc94-4117-82f8-90bc5bc98c68'), UUID('f8796037-ca17-4349-8eae-2bd721c08d58'), UUID('b1e88ea5-b149-4477-b1c0-6af5c568fc38'), UUID('d2cedcd6-df90-4d8a-8a5a-4190a8f53fd3'), UUID('ffece060-7512-45f7-b464-d44834654be9')], children_events=[], condition=Paralyzed(name='Paralyzed', uuid=UUID('7a4e583e-21ff-4716-b1a7-5e14aa41b846'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=UUID('72649558-23a3-4397-b5be-2abc1fa36c78'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('6ba6e2d0-cb90-42ee-aba0-0ba3e56e93e5'), source_entity_uuid=UUID('b8deddac-f07c-40a2-b1f9-8defc9ff835b'), source_entity_name=None, target_entity_uuid=UUID('e03e5fe7-0f47-4544-a726-0eec030e26d7'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('7a4e583e-21ff-4716-b1a7-5e14aa41b846'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('775cc1a7-1d26-4a23-b83e-603bfb92e67e'): [UUID('beef1be9-fff1-4eca-a8f3-e31c12c7383d')], UUID('1a2da1e1-88fe-46fa-a112-e9027c0b5030'): [UUID('06fec6d8-cc88-4ef8-81ec-d30564604d2e')], UUID('54306bc4-5b0c-4299-83e4-b3ef6a8eff0d'): [UUID('6b90ebde-9e4a-4000-87ee-eb7a2f0f032a')]}, parent_condition=None, sub_conditions=[UUID('e9b62af5-9963-4f81-949c-e173f646886b')], event_handlers_uuids=[], description='A paralyzed creature is incapacitated (see the condition) and can’t move or speak. The creature automatically fails Strength and Dexterity saving throws. Attack rolls against the creature have advantage. Any attack that hits the creature is a critical hit if the attacker is within 5 feet of the creature.'))

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score

# %%
warrior_bonus.normalized_score

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")

# %%
attack_roll.bonus

# %%
attack_roll.results

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()

# %%
damages

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request

# %%
strength_saving_throw_request

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")

# %%
warrior2.skill_check(acrobatics_skill_request)

# %%
warrior2.skill_check(perception_skill_request)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")

# %%
warrior2.saving_throw(strength_saving_throw_request)

# %%
from dnd.conditions import Blinded
from dnd.core.events import EventQueue


blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()

# %%
warrior2.equipment.attack_bonus.advantage

# %%
warrior.equipment.attack_bonus.advantage

# %%
blinded.modifers_uuids

# %%
warrior2.skill_check(perception_skill_request)

# %%
blinded.remove()

# %%
warrior2.skill_check(perception_skill_request)

# %%
warrior2.equipment.attack_bonus.advantage

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()

# %%
warrior.action_economy.movement.normalized_score

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score

# %%
print(f"total_time: {time.time()-start_time}")
