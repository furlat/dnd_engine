# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4
from dnd.core.events import EventQueue

import time
from uuid import UUID

# %%
start_time = time.time()
source_id = uuid4()
proficiency_bonus = 2

# %%
q = EventQueue()

# %%
warrior = create_warrior(source_id,proficiency_bonus)
q._all_events

# %%
warrior2 = create_warrior(name="Mona")
q._all_events
# Out:
# [ArmorEquipEvent(name='Armor Equip', uuid=UUID('9815b257-0638-426d-a276-464cc1b74d75'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0cb525c3-2f62-4cea-a732-39647196708c'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 781669), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('ebd6326b-13c5-4e85-82ec-dcf5f7301c56'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('296416f2-6bdb-454e-9758-07fc0c318019'): ModifiableValue(name='Armor Class', uuid=UUID('296416f2-6bdb-454e-9758-07fc0c318019'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9a8cdf88-fb54-491b-acf6-f72cfaf39f65'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE ...
#  ArmorEquipEvent(name='Armor Equip', uuid=UUID('15f656c6-3e17-4783-83b7-af751b51adfc'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0cb525c3-2f62-4cea-a732-39647196708c'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 781669), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('ebd6326b-13c5-4e85-82ec-dcf5f7301c56'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('296416f2-6bdb-454e-9758-07fc0c318019'): ModifiableValue(name='Armor Class', uuid=UUID('296416f2-6bdb-454e-9758-07fc0c318019'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9a8cdf88-fb54-491b-acf6-f72cfaf39f65'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'No ...
#  ArmorEquipEvent(name='Armor Equip', uuid=UUID('6bade669-03eb-4316-8525-518f52bdd2a5'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0cb525c3-2f62-4cea-a732-39647196708c'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 781669), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('ebd6326b-13c5-4e85-82ec-dcf5f7301c56'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('296416f2-6bdb-454e-9758-07fc0c318019'): ModifiableValue(name='Armor Class', uuid=UUID('296416f2-6bdb-454e-9758-07fc0c318019'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9a8cdf88-fb54-491b-acf6-f72cfaf39f65'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>,  ...
#  ArmorEquipEvent(name='Armor Equip', uuid=UUID('35973ce1-1e0e-40d4-a67d-f0e252e92d18'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('0cb525c3-2f62-4cea-a732-39647196708c'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 781669), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('ebd6326b-13c5-4e85-82ec-dcf5f7301c56'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('296416f2-6bdb-454e-9758-07fc0c318019'): ModifiableValue(name='Armor Class', uuid=UUID('296416f2-6bdb-454e-9758-07fc0c318019'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('9a8cdf88-fb54-491b-acf6-f72cfaf39f65'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, generated_from=[], global_normalizer=True, value_modifiers={UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('f3559c01-2309-4e5a-abe9-5a3201463b72'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505CA40>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: ' ...
#  WeaponEquipEvent(name='Weapon Equip', uuid=UUID('7840ae63-752a-4919-9d78-1fd853c7c13f'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('80f4e290-130c-4a1c-a6f9-e7e0dac11a1b'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 789667), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('b65e6c68-dafa-4f7d-8e13-7e8e2cd79057'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'): ModifiableValue(name='Attack Bonus', uuid=UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('1585e5d0-ee3a-445e-bcc0-31407b27ccdc'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, value_modifiers={UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resis ...
#  WeaponEquipEvent(name='Weapon Equip', uuid=UUID('ed7857d7-0c20-4f87-a3b5-bd4e7dac33a0'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('80f4e290-130c-4a1c-a6f9-e7e0dac11a1b'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 789667), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('b65e6c68-dafa-4f7d-8e13-7e8e2cd79057'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'): ModifiableValue(name='Attack Bonus', uuid=UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('1585e5d0-ee3a-445e-bcc0-31407b27ccdc'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, value_modifiers={UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resistance ...
#  WeaponEquipEvent(name='Weapon Equip', uuid=UUID('58bc530e-3881-43f1-8499-9fb09413bca3'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('80f4e290-130c-4a1c-a6f9-e7e0dac11a1b'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 789667), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('b65e6c68-dafa-4f7d-8e13-7e8e2cd79057'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'): ModifiableValue(name='Attack Bonus', uuid=UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('1585e5d0-ee3a-445e-bcc0-31407b27ccdc'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, value_modifiers={UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus ...
#  WeaponEquipEvent(name='Weapon Equip', uuid=UUID('9d407149-82ff-4e1f-8857-69ee875dafb0'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('80f4e290-130c-4a1c-a6f9-e7e0dac11a1b'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 789667), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('b65e6c68-dafa-4f7d-8e13-7e8e2cd79057'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'): ModifiableValue(name='Attack Bonus', uuid=UUID('2f12271d-db4c-4942-8f1c-f6ba25e8d004'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('1585e5d0-ee3a-445e-bcc0-31407b27ccdc'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, generated_from=[], global_normalizer=True, value_modifiers={UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('e1c4f33a-ed39-4df6-ba83-478fdee0c62a'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C720>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resistan ...
#  WeaponEquipEvent(name='Weapon Equip', uuid=UUID('fe5c8a6f-ef06-4949-8e13-7ac67e6f818b'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('3a2f2566-5c7b-4a1a-a576-f458dc5a4477'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 789667), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('9da74c78-5301-4799-986f-9f15acaa7b9c'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('8d4c07cf-e9f4-4a58-bab7-8585d516d1be'): ModifiableValue(name='Attack Bonus', uuid=UUID('8d4c07cf-e9f4-4a58-bab7-8585d516d1be'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('0319b477-25be-4003-b5c0-fc1f880a507e'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('fc739fa9-902e-445b-9bf8-cd1e22dee82a'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('fc739fa9-902e-445b-9bf8-cd1e22dee82a'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('6520736c-63e0-4418-b7cc-ecb292914b29'): AdvantageModifier(name='Rusty Blade', uuid=UUID('6520736c-63e0-4418-b7cc-ecb292914b29'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.N ...
#  WeaponEquipEvent(name='Weapon Equip', uuid=UUID('4d45f5dd-9e46-4150-9771-5ee8bba7cc95'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('3a2f2566-5c7b-4a1a-a576-f458dc5a4477'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 789667), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('9da74c78-5301-4799-986f-9f15acaa7b9c'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('8d4c07cf-e9f4-4a58-bab7-8585d516d1be'): ModifiableValue(name='Attack Bonus', uuid=UUID('8d4c07cf-e9f4-4a58-bab7-8585d516d1be'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('0319b477-25be-4003-b5c0-fc1f880a507e'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('fc739fa9-902e-445b-9bf8-cd1e22dee82a'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('fc739fa9-902e-445b-9bf8-cd1e22dee82a'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('6520736c-63e0-4418-b7cc-ecb292914b29'): AdvantageModifier(name='Rusty Blade', uuid=UUID('6520736c-63e0-4418-b7cc-ecb292914b29'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE:  ...
#  WeaponEquipEvent(name='Weapon Equip', uuid=UUID('7dbf0a91-9df3-459d-9846-5b7eb1e0e3ff'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('3a2f2566-5c7b-4a1a-a576-f458dc5a4477'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 15, 789667), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('9da74c78-5301-4799-986f-9f15acaa7b9c'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('8d4c07cf-e9f4-4a58-bab7-8585d516d1be'): ModifiableValue(name='Attack Bonus', uuid=UUID('8d4c07cf-e9f4-4a58-bab7-8585d516d1be'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('0319b477-25be-4003-b5c0-fc1f880a507e'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, generated_from=[], global_normalizer=True, value_modifiers={UUID('fc739fa9-902e-445b-9bf8-cd1e22dee82a'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('fc739fa9-902e-445b-9bf8-cd1e22dee82a'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002238505C4A0>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('6520736c-63e0-4418-b7cc-ecb292914b29'): AdvantageModifier(name='Rusty Blade', uuid=UUID('6520736c-63e0-4418-b7cc-ecb292914b29'), source_entity_uuid=UUID('d7ac85c5-53b6-4876-aadc-2282670230d9'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None' ...
# ...
#  ConditionApplicationEvent(name='Elemental Weapon Mastery', uuid=UUID('234014ee-20a2-4ddc-b611-29d19038746f'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, lineage_uuid=UUID('7a1df681-8263-4cc8-93b5-2f18aa905b4e'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 16, 624937), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Weapon Mastery contextual advantage modifier condition to Mona', lineage_children_events=[], children_events=[], condition=ElementalWeaponMastery(name='Elemental Weapon Mastery', uuid=UUID('3506dc1b-e254-412c-873d-bb653a5d67a7'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('280d3f5d-7621-498f-b889-6202b90a40c4'), source_entity_uuid=UUID('e2a7f1db-6c0d-4a37-a126-b46268fbe97e'), source_entity_name=None, target_entity_uuid=UUID('eb53affa-d474-4b92-9ac6-aeb0651b60f9'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('3506dc1b-e254-412c-873d-bb653a5d67a7'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('ca745c4c-2606-493b-8802-302c55afb6a8'): [UUID('2a4de36d-5af3-40e1-80a5-f9ecac0da1b0')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='You have advantage on attack rolls made with weapons that deal acid, cold, fire, lightning, poison, or thunder damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('a979fa59-f92f-4944-bc04-cf88df971710'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, lineage_uuid=UUID('46afac6e-3a32-420d-8000-0c4736c80a40'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 16, 624937), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('1c2619b6-7a41-4df3-a69f-867beea6450b'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('3c8db4c7-f6c2-4a44-8896-6683ac639d46'), source_entity_uuid=UUID('2399b449-d472-4a0e-869f-d0067fc1bcbd'), source_entity_name=None, target_entity_uuid=UUID('3ef36f69-815b-4f82-a574-2e8ece8be3c2'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('1c2619b6-7a41-4df3-a69f-867beea6450b'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('0bff50f7-4073-4821-9fce-0271b3025e04'), UUID('47f78689-8953-42d3-93fc-a908f8c3e57a')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('bb917611-4cfa-4bae-84cb-c28a0ab986cc'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, lineage_uuid=UUID('46afac6e-3a32-420d-8000-0c4736c80a40'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 16, 624937), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Affinity resistance modifier condition to Mona', lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('1c2619b6-7a41-4df3-a69f-867beea6450b'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('3c8db4c7-f6c2-4a44-8896-6683ac639d46'), source_entity_uuid=UUID('2399b449-d472-4a0e-869f-d0067fc1bcbd'), source_entity_name=None, target_entity_uuid=UUID('3ef36f69-815b-4f82-a574-2e8ece8be3c2'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('1c2619b6-7a41-4df3-a69f-867beea6450b'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('0bff50f7-4073-4821-9fce-0271b3025e04'), UUID('47f78689-8953-42d3-93fc-a908f8c3e57a')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('5265857c-02e6-4574-b90d-262ad5953288'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, lineage_uuid=UUID('46afac6e-3a32-420d-8000-0c4736c80a40'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 16, 624937), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Affinity resistance modifier condition to Mona', lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('1c2619b6-7a41-4df3-a69f-867beea6450b'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('3c8db4c7-f6c2-4a44-8896-6683ac639d46'), source_entity_uuid=UUID('2399b449-d472-4a0e-869f-d0067fc1bcbd'), source_entity_name=None, target_entity_uuid=UUID('3ef36f69-815b-4f82-a574-2e8ece8be3c2'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('1c2619b6-7a41-4df3-a69f-867beea6450b'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('0bff50f7-4073-4821-9fce-0271b3025e04'), UUID('47f78689-8953-42d3-93fc-a908f8c3e57a')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('dea91a33-92b6-4018-9bd3-2db2eb8f3cc8'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, lineage_uuid=UUID('ce3346d8-da58-4831-aae3-ea35526e331c'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 16, 624937), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('fc08f4f9-681f-488c-92d5-8312bda53459'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('1c2dadfb-247e-4859-90ca-e5668e08fc88'), source_entity_uuid=UUID('1642d454-eab3-4807-9b03-2c04ddc6b3cd'), source_entity_name=None, target_entity_uuid=UUID('d7c4abf4-c386-4b0a-8c74-383a480b5e60'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('fc08f4f9-681f-488c-92d5-8312bda53459'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('0470eb57-05e7-4d39-b8ff-c6175a4af48f'): [UUID('d340db25-ad6f-4115-8c38-1f6858cd5f95')], UUID('e55a7b03-435f-4edb-9b88-8aa5cb5f4091'): [UUID('fbdeb590-5abc-4baa-9eb4-4cfd10337df1')], UUID('2e9b0556-0e6d-47c7-b86d-9ab1c8397555'): [UUID('dae8a42a-f877-49a6-82e2-fd5d639c0dda')], UUID('3e76d23c-f2f4-4b15-abd8-c3e5815e3fad'): [UUID('83bcda55-8c15-4cfc-880e-7d2f02cb6be3')], UUID('394f0195-0b5d-4089-8b41-f189328a24d6'): [UUID('34533214-a673-4f74-a4e2-4a9e777acff2')], UUID('8fb12c58-2103-4293-aa2c-39573e280e09'): [UUID('ec69ebf9-b2a1-4d15-b558-e3ccb19901b3')], UUID('61f0c46b-61a9-4fff-82ea-c6f0b8942eb1'): [UUID('8713f913-fa8e-49f0-9c18-24f2d9e3cf89')], UUID('0335a8a1-c08a-4557-83e3-4f0d277a98f2'): [UUID('58f897b7-dfa6-4785-aafb-3f34293e8627')], UUID('9e2c9072-6dfb-48ad-863f-9862c9e662c7'): [UUID('6b863153-6b27-4c9c-b6a0-1b4c8aa69715')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('dab7d961-dbd2-47c4-b323-421e15631f02'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, lineage_uuid=UUID('ce3346d8-da58-4831-aae3-ea35526e331c'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 16, 625437), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Mona', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('fc08f4f9-681f-488c-92d5-8312bda53459'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('1c2dadfb-247e-4859-90ca-e5668e08fc88'), source_entity_uuid=UUID('1642d454-eab3-4807-9b03-2c04ddc6b3cd'), source_entity_name=None, target_entity_uuid=UUID('d7c4abf4-c386-4b0a-8c74-383a480b5e60'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('fc08f4f9-681f-488c-92d5-8312bda53459'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('0470eb57-05e7-4d39-b8ff-c6175a4af48f'): [UUID('d340db25-ad6f-4115-8c38-1f6858cd5f95')], UUID('e55a7b03-435f-4edb-9b88-8aa5cb5f4091'): [UUID('fbdeb590-5abc-4baa-9eb4-4cfd10337df1')], UUID('2e9b0556-0e6d-47c7-b86d-9ab1c8397555'): [UUID('dae8a42a-f877-49a6-82e2-fd5d639c0dda')], UUID('3e76d23c-f2f4-4b15-abd8-c3e5815e3fad'): [UUID('83bcda55-8c15-4cfc-880e-7d2f02cb6be3')], UUID('394f0195-0b5d-4089-8b41-f189328a24d6'): [UUID('34533214-a673-4f74-a4e2-4a9e777acff2')], UUID('8fb12c58-2103-4293-aa2c-39573e280e09'): [UUID('ec69ebf9-b2a1-4d15-b558-e3ccb19901b3')], UUID('61f0c46b-61a9-4fff-82ea-c6f0b8942eb1'): [UUID('8713f913-fa8e-49f0-9c18-24f2d9e3cf89')], UUID('0335a8a1-c08a-4557-83e3-4f0d277a98f2'): [UUID('58f897b7-dfa6-4785-aafb-3f34293e8627')], UUID('9e2c9072-6dfb-48ad-863f-9862c9e662c7'): [UUID('6b863153-6b27-4c9c-b6a0-1b4c8aa69715')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('81e7a007-13d1-4487-9197-5368edf8ff17'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, lineage_uuid=UUID('ce3346d8-da58-4831-aae3-ea35526e331c'), timestamp=datetime.datetime(2025, 5, 11, 0, 33, 16, 625437), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Mona', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('fc08f4f9-681f-488c-92d5-8312bda53459'), source_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), source_entity_name=None, target_entity_uuid=UUID('7f73ff4a-34b9-42ca-8786-4271fc5d8174'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('1c2dadfb-247e-4859-90ca-e5668e08fc88'), source_entity_uuid=UUID('1642d454-eab3-4807-9b03-2c04ddc6b3cd'), source_entity_name=None, target_entity_uuid=UUID('d7c4abf4-c386-4b0a-8c74-383a480b5e60'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('fc08f4f9-681f-488c-92d5-8312bda53459'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('0470eb57-05e7-4d39-b8ff-c6175a4af48f'): [UUID('d340db25-ad6f-4115-8c38-1f6858cd5f95')], UUID('e55a7b03-435f-4edb-9b88-8aa5cb5f4091'): [UUID('fbdeb590-5abc-4baa-9eb4-4cfd10337df1')], UUID('2e9b0556-0e6d-47c7-b86d-9ab1c8397555'): [UUID('dae8a42a-f877-49a6-82e2-fd5d639c0dda')], UUID('3e76d23c-f2f4-4b15-abd8-c3e5815e3fad'): [UUID('83bcda55-8c15-4cfc-880e-7d2f02cb6be3')], UUID('394f0195-0b5d-4089-8b41-f189328a24d6'): [UUID('34533214-a673-4f74-a4e2-4a9e777acff2')], UUID('8fb12c58-2103-4293-aa2c-39573e280e09'): [UUID('ec69ebf9-b2a1-4d15-b558-e3ccb19901b3')], UUID('61f0c46b-61a9-4fff-82ea-c6f0b8942eb1'): [UUID('8713f913-fa8e-49f0-9c18-24f2d9e3cf89')], UUID('0335a8a1-c08a-4557-83e3-4f0d277a98f2'): [UUID('58f897b7-dfa6-4785-aafb-3f34293e8627')], UUID('9e2c9072-6dfb-48ad-863f-9862c9e662c7'): [UUID('6b863153-6b27-4c9c-b6a0-1b4c8aa69715')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.'))]

# %%
q._events_by_lineage[UUID("2447f19b-7dac-4743-bf95-aadf34a9b712")]

# %%
warrior.source_entity_uuid

# %%
warrior.ability_scores.uuid

# %%
Entity.get(warrior.source_entity_uuid)

# %%
from dnd.conditions import Paralyzed

# %%
paralyzed_condition = Paralyzed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
paralyzed_condition.apply()

# %%
a

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score

# %%
warrior_bonus.normalized_score

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")

# %%
attack_roll.bonus

# %%
attack_roll.results

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)

# %%
damages

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request

# %%
strength_saving_throw_request

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")

# %%
warrior2.skill_check(acrobatics_skill_request)

# %%
warrior2.skill_check(perception_skill_request)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")

# %%
warrior2.saving_throw(strength_saving_throw_request)

# %%
from dnd.conditions import Blinded
from dnd.core.events import EventQueue


blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()

# %%
warrior2.equipment.attack_bonus.advantage

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
warrior.equipment.attack_bonus.advantage

# %%
warrior.attack(warrior2.uuid,weapon_slot)

# %%
blinded.modifers_uuids

# %%
warrior2.skill_check(perception_skill_request)

# %%
blinded.remove()

# %%
warrior2.skill_check(perception_skill_request)

# %%
warrior2.equipment.attack_bonus.advantage

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()

# %%
warrior.action_economy.movement.normalized_score

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score

# %%
print(f"total_time: {time.time()-start_time}")
