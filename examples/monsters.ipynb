# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior(name="Mona")

# %%
warrior.source_entity_uuid
# Out:
# UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('cd87f6dd-5d08-44d6-9bd7-b17a8c8e2702')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('cd87f6dd-5d08-44d6-9bd7-b17a8c8e2702'): AbilityScores(name='ability_scores', description=None, uuid=UUID('cd87f6dd-5d08-44d6-9bd7-b17a8c8e2702'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('05b664ae-dcec-482a-9abf-0aae8bb7962a'): Ability(name='strength', description=None, uuid=UUID('05b664ae-dcec-482a-9abf-0aae8bb7962a'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('6e5a1968-d54f-4c56-87e6-7013761779b4'): ModifiableValue(name='strength Ability Score', uuid=UUID('6e5a1968-d54f-4c56-87e6-7013761779b4'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('70e01a96-97bb-4caf-b12f-71d0cb1c3c33'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('3789476b-7fce-4381-8ca8-a3292351e807'): NumericalModifier(name='level 4 talent', uuid=UUID('3789476b-7fce-4381-8ca8-a3292351e807'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Damag ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('6e5a1968-d54f-4c56-87e6-7013761779b4'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('70e01a96-97bb-4caf-b12f-71d0cb1c3c33'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('3789476b-7fce-4381-8ca8-a3292351e807'): NumericalModifier(name='level 4 talent', uuid=UUID('3789476b-7fce-4381-8ca8-a3292351e807'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('f891da7e-3ad8-4776-b196-781a1e555e28'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 22

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 17

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.0005075931549072266

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('6e5a1968-d54f-4c56-87e6-7013761779b4'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('70e01a96-97bb-4caf-b12f-71d0cb1c3c33'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('3789476b-7fce-4381-8ca8-a3292351e807'): NumericalModifier(name='level 4 talent', uuid=UUID('3789476b-7fce-4381-8ca8-a3292351e807'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('f891da7e-3ad8-4776-b196-781a1e555e28'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.0014986991882324219

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 15, Roll total: 20 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Damage Roll result: [4], Roll total: 10
# Total Health after taking damage: 49
# 0.0004982948303222656

# %%
damages
# Out:
# [Damage(name='Damage', description=None, uuid=UUID('35d126e8-3bd9-4bfb-9127-75bd833767b5'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('c9620e58-d21e-484b-b0c9-9a3146fde375'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('c9620e58-d21e-484b-b0c9-9a3146fde375'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534E00>, generated_from=[UUID('d7360d57-55f3-4ee6-a103-becf21e3fa59'), UUID('6da9c3d2-44b9-4f36-812a-2f83fb90974f'), UUID('08372360-8bf4-486b-9dc6-3ca94aca288f'), UUID('de865624-16e4-4cfd-a91b-e7860426e7e7')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('e7e17f57-f63d-48b1-baea-dee55ef21b7a'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534E00>, generated_from=[UUID('1199f3a4-3c27-421e-a092-2f179444ab43'), UUID('44b02de4-6e48-4eb8-8200-7688d8776cd2'), UUID('3044190f-03f1-4f03-8a96-fec05019ca1f'), UUID('488924a6-a8b4-416d-bd28-867da998ee3c')], global_normalizer=False, value_modifiers={UUID('b402888d-0cac-4bbd-85d3-aeeaf5bdcbb0'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('b402888d-0cac-4bbd-85d3-aeeaf5bdcbb0'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534E00>, normalized_value=1), UUID('f32d6669-7e4b-48d3-82cd-c59de61f53cb'): NumericalModifier(name='a past in the circus', uuid=UUID('f32d6669-7e4b-48d3-82cd-c59de61f53cb'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('7379ad26-00a6-4ba3-aa83-5cdd7636080f'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('7379ad26-00a6-4ba3-aa83-5cdd7636080f'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534540>, normalized_value=0), UUID('1c2268f6-b396-406c-aacd-acf60173c39f'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('1c2268f6-b396-406c-aacd-acf60173c39f'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534A40>, normalized_value=0), UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('3789476b-7fce-4381-8ca8-a3292351e807'): NumericalModifier(name='level 4 talent', uuid=UUID('3789476b-7fce-4381-8ca8-a3292351e807'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_n ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0014982223510742188

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.001512765884399414

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0014977455139160156

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('6e5a1968-d54f-4c56-87e6-7013761779b4'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('70e01a96-97bb-4caf-b12f-71d0cb1c3c33'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('3789476b-7fce-4381-8ca8-a3292351e807'): NumericalModifier(name='level 4 talent', uuid=UUID('3789476b-7fce-4381-8ca8-a3292351e807'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('f891da7e-3ad8-4776-b196-781a1e555e28'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 17, Roll total: 22 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 49
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 41
# 0.008008003234863281

# %%
from dnd.core.requests import SkillCheckRequest, SavingThrowRequest, SkillName

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request
# Out:
# SkillCheckRequest(dc=12, source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), context=None, skill_name='acrobatics')

# %%
strength_saving_throw_request
# Out:
# SavingThrowRequest(dc=12, source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), context=None, ability_name='strength')

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")
# Out:
# ModifiableValue(name='Value_acrobatics Skill Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('2e82fa3a-9039-4153-901c-4130f6d562be'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001A99E6D5300>, generated_from=[UUID('7026e43d-eb3b-4f8d-8383-a0a1d88f1e65'), UUID('8df4c1a1-9dd3-46d5-852b-10ab3d41ea0e'), UUID('2cdee792-2da0-44f3-b23b-ef9eb3514221'), UUID('1030b295-bdf2-4a77-9dfc-1239342ec481')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('a751a8c5-ee12-425a-a602-60e716c01c94'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001A99E6D5300>, generated_from=[UUID('938165be-dac5-403e-a8f6-d37a7b11bb40'), UUID('956209bc-75ae-4a5c-ba12-7c5c138fd8cd'), UUID('398d493a-bbad-4596-ade7-08183088b10c'), UUID('7856e3d6-1e81-413c-9733-953d61afc93b')], global_normalizer=False, value_modifiers={UUID('46a6f827-5e39-4a9c-ac0f-0907ce49a4ac'): NumericalModifier(name='Value_base_value', uuid=UUID('46a6f827-5e39-4a9c-ac0f-0907ce49a4ac'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001A99E6D5300>, normalized_value=0), UUID('33882f0f-a43b-4c57-b8ac-8ea15a7cbbb1'): NumericalModifier(name='a past in the circus', uuid=UUID('33882f0f-a43b-4c57-b8ac-8ea15a7cbbb1'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001A99E6D5300>, normalized_value=-2), UUID('7a4fc03a-1697-4100-be78-79a7ec4075db'): NumericalModifier(name='acrobatics Skill Bonus_base_value', uuid=UUID('7a4fc03a-1697-4100-be78-79a7ec4075db'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E536660>, normalized_value=0), UUID('dba7c644-510c-495c-b073-9785e544d61e'): NumericalModifier(name='a past in the circus', uuid=UUID('dba7c644-510c-495c-b073-9785e544d61e'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=7, score_normalizer=None, normalized_value=7), UUID('88664061-f4bb-43ac-bc66-2e907a2dff09'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('88664061-f4bb-43ac-bc66-2e907a2dff09'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=12, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=1), UUID('a24cd44b-fd7e-4b36-bb52-383945ca68db'): NumericalModifier(name='strength Modifier Bonus_base_value', uuid=UUID('a24cd44b-fd7e-4b36-bb52-383945ca68db'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5359E0>, normalized_value=0)}, min_constraints={}, max_co ...

# %%
warrior2.skill_check(acrobatics_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 6
# Roll result: 10, Roll total: 16 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('029f99c4-ca61-4302-a815-665e6baa44ca'), dice_uuid=UUID('683253cb-f99d-4a63-a280-c79b81b416d9'), roll_type=<RollType.ATTACK: 'Attack'>, results=10, total=16, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  True)

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 9, Roll total: 9 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('e84514be-1f39-4b49-a345-c5e9ae331d46'), dice_uuid=UUID('2e77f2e6-965d-4264-8413-a074023a597b'), roll_type=<RollType.ATTACK: 'Attack'>, results=9, total=9, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  False)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")
# Out:
# ModifiableValue(name='Value_strength_saving_throw Saving Throw Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('c4fed082-ac5a-4fca-bf34-8be8b33c506b'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001A99E6D4720>, generated_from=[UUID('7026e43d-eb3b-4f8d-8383-a0a1d88f1e65'), UUID('978d3adf-f9d1-4db4-99e7-2da0e9b6fc46'), UUID('d4badc58-4021-4009-914c-fa05ffdb4a1b'), UUID('4ada26e5-a509-4836-9f49-d8559518341c')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('3b676bda-e6d9-4fbd-b937-7c096e21edcd'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001A99E6D4720>, generated_from=[UUID('938165be-dac5-403e-a8f6-d37a7b11bb40'), UUID('ea076a81-076c-46e5-b89b-ac5d9b23cb57'), UUID('a5484f1c-8812-4803-85b3-b87f76e244d4'), UUID('cfe9b426-6925-4687-a871-3fd50f083c3c')], global_normalizer=False, value_modifiers={UUID('46a6f827-5e39-4a9c-ac0f-0907ce49a4ac'): NumericalModifier(name='Value_base_value', uuid=UUID('46a6f827-5e39-4a9c-ac0f-0907ce49a4ac'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001A99E6D4720>, normalized_value=0), UUID('33882f0f-a43b-4c57-b8ac-8ea15a7cbbb1'): NumericalModifier(name='a past in the circus', uuid=UUID('33882f0f-a43b-4c57-b8ac-8ea15a7cbbb1'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001A99E6D4720>, normalized_value=-1), UUID('814d0f1e-ccea-44db-aeec-ae871aece195'): NumericalModifier(name='strength_saving_throw Saving Throw Bonus_base_value', uuid=UUID('814d0f1e-ccea-44db-aeec-ae871aece195'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AC860>, normalized_value=0), UUID('7056579c-aaa3-4d2d-a3cf-2756abcaddbc'): NumericalModifier(name='a past in the circus', uuid=UUID('7056579c-aaa3-4d2d-a3cf-2756abcaddbc'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'): NumericalModifier(name='level 4 talent', uuid=UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('9fede5fb-75bb-4f27-8689-d528aed6659c'): NumericalModifier(name='strength Modifier  ...

# %%
warrior2.saving_throw(strength_saving_throw_request)
# Out:
# Target AC: 12
# Attack bonus: 4
# Roll result: 16, Roll total: 20 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('bb4d350a-deee-405b-9c57-748a400bbbe1'), dice_uuid=UUID('7ca65698-0905-4893-b689-9ad008363cb0'), roll_type=<RollType.ATTACK: 'Attack'>, results=16, total=20, bonus=4, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  True)

# %%
from dnd.conditions import Blinded

blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# True

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('d4badc58-4021-4009-914c-fa05ffdb4a1b'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a5484f1c-8812-4803-85b3-b87f76e244d4'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'): NumericalModifier(name='level 4 talent', uuid=UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e86ee5a4-1884-40de-b183-addc64778664'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 15, Roll total: 18 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# Total Health before taking damage: 58
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 50
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('de48cc2d-26e9-44c6-b742-fa0235091bb9'), dice_uuid=UUID('649f4a36-f92d-40de-b1ef-8492847937f7'), roll_type=<RollType.ATTACK: 'Attack'>, results=15, total=18, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('d1e56314-6415-422f-b5ae-58e19589f949'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, blocks={}, values={UUID('fdd05fc6-d1e3-47b3-bcd5-9ed314d81623'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('fdd05fc6-d1e3-47b3-bcd5-9ed314d81623'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE980>, generated_from=[UUID('b8e85a7d-91b8-4db5-9732-12b4cfcd14b2'), UUID('66f7c1bc-3e5f-43e1-82cd-8083dc2d6def'), UUID('db4bd071-a7d2-4c1f-89a5-2507c9ec50b8'), UUID('65c0a1a5-572e-4e72-8fdd-ac5cd8a80ac5')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('9b759d6b-95f7-4d41-91ad-f2b6b0fcbc78'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE980>, generated_from=[UUID('063192e1-de2f-4113-aae3-a727d7daf65a'), UUID('2848c7b3-de5e-4076-8a93-081a0a19cea1'), UUID('9324b302-4201-4c5b-b695-c7194cd7cc9e'), UUID('6c393fa1-f96f-479a-8d65-f997adbd6d86')], global_normalizer=False, value_modifiers={UUID('c9f72fb4-2569-47f9-9819-f53e5e72a9ae'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('c9f72fb4-2569-47f9-9819-f53e5e72a9ae'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE980>, normalized_value=1), UUID('42531e5c-4fa4-40e8-bb23-5313a480f7a5'): NumericalModifier(name='a past in the circus', uuid=UUID('42531e5c-4fa4-40e8-bb23-5313a480f7a5'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('bde41a38-fc3f-44c8-a844-5bfff66b086f'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('bde41a38-fc3f-44c8-a844-5bfff66b086f'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE0C0>, normalized_value=0), UUID('9f08f696-4032-4f6e-8d26-28f8fc6cb271'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('9f08f696-4032-4f6e-8d26-28f8fc6cb271'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE5C0>, normalized_value=0), UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('135d504d-2a57-4489-b492-0d02d9370165'), dice_uuid=UUID('febafcf6-0598-4f42-aaf7-ecf4f56a923e'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[3], total=9, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
warrior.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior.attack(warrior2.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('6e5a1968-d54f-4c56-87e6-7013761779b4'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('70e01a96-97bb-4caf-b12f-71d0cb1c3c33'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('3789476b-7fce-4381-8ca8-a3292351e807'): NumericalModifier(name='level 4 talent', uuid=UUID('3789476b-7fce-4381-8ca8-a3292351e807'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('f891da7e-3ad8-4776-b196-781a1e555e28'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 18, Roll total: 23 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# Total Health before taking damage: 41
# Damage Roll result: [2], Roll total: 8
# Total Health after taking damage: 34
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('6d4bb2d3-9dec-4c8f-ad1b-2ed3edf2c3ec'), dice_uuid=UUID('28c9efda-1410-46f4-a813-f723c5732abf'), roll_type=<RollType.ATTACK: 'Attack'>, results=18, total=23, bonus=5, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('9ac811f2-32d3-4509-a75b-29dc9ca9ed14'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, blocks={}, values={UUID('181e63be-6a15-4851-9c75-55efb5e23004'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('181e63be-6a15-4851-9c75-55efb5e23004'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534E00>, generated_from=[UUID('d7360d57-55f3-4ee6-a103-becf21e3fa59'), UUID('6da9c3d2-44b9-4f36-812a-2f83fb90974f'), UUID('08372360-8bf4-486b-9dc6-3ca94aca288f'), UUID('098cecd0-3841-402a-93c5-0aa10333302a')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('ee50a6b6-6d65-4d09-b826-2f3e14867acf'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534E00>, generated_from=[UUID('1199f3a4-3c27-421e-a092-2f179444ab43'), UUID('44b02de4-6e48-4eb8-8200-7688d8776cd2'), UUID('3044190f-03f1-4f03-8a96-fec05019ca1f'), UUID('ae6c2f06-1bbe-45c7-84d0-18a91c683adc')], global_normalizer=False, value_modifiers={UUID('b402888d-0cac-4bbd-85d3-aeeaf5bdcbb0'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('b402888d-0cac-4bbd-85d3-aeeaf5bdcbb0'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534E00>, normalized_value=1), UUID('f32d6669-7e4b-48d3-82cd-c59de61f53cb'): NumericalModifier(name='a past in the circus', uuid=UUID('f32d6669-7e4b-48d3-82cd-c59de61f53cb'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('7379ad26-00a6-4ba3-aa83-5cdd7636080f'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('7379ad26-00a6-4ba3-aa83-5cdd7636080f'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534540>, normalized_value=0), UUID('1c2268f6-b396-406c-aacd-acf60173c39f'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('1c2268f6-b396-406c-aacd-acf60173c39f'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E534A40>, normalized_value=0), UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aa0b0a9d-da05-4767-8465-5c37e8c523cc'), source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('3789476b-7fce-4381-8ca8-a3292351e807'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('4d1e911c-6922-4034-98e5-94cd73fa61c8'), dice_uuid=UUID('d0269cf2-690d-40f1-a7aa-b916c4df0019'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[2], total=8, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
blinded.modifers_uuids
# Out:
# {UUID('a3868cf9-9c5b-4308-908f-c9893ec6619a'): [UUID('940a0ac1-45f4-4471-93db-f16269fb7c4a')],
#  UUID('15324053-c4f8-4858-a503-fa4ecc325b39'): [UUID('89dcc2a6-f47b-41eb-af86-2d21c56e6b99')],
#  UUID('3ad52524-0513-4c1b-8299-08bc2a214a77'): [UUID('c643d4cc-470c-49af-8d3c-b9c745399989')],
#  UUID('8e578a13-f649-4ce5-8088-451152f00d18'): [UUID('d1934ae7-9293-41fb-ad5c-3bb0087b84ef')],
#  UUID('9161504a-9d3c-4c3f-b44d-15d08c8ef9a7'): [UUID('2a603ff2-8ba5-4438-96b6-65e4e5c57066')],
#  UUID('dbf1ec5c-fba0-40e2-abbb-248e0bac3c04'): [UUID('706e9e1a-4975-4ca7-84f4-859dafa7dcf6')]}

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 15, Roll total: 15 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('4369f0b0-da0c-4405-8929-d125b9e3c090'), dice_uuid=UUID('f8cfa83b-e221-44f5-994b-dd08c88d3ef2'), roll_type=<RollType.ATTACK: 'Attack'>, results=15, total=15, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  False)

# %%
blinded.remove()
# Out:
# True

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 3, Roll total: 3 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('3c5fb439-8260-465e-98fb-3129160c05f7'), dice_uuid=UUID('19aaf5ea-7321-420d-aaac-960d1289da1d'), roll_type=<RollType.ATTACK: 'Attack'>, results=3, total=3, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  False)

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('d4badc58-4021-4009-914c-fa05ffdb4a1b'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a5484f1c-8812-4803-85b3-b87f76e244d4'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'): NumericalModifier(name='level 4 talent', uuid=UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e86ee5a4-1884-40de-b183-addc64778664'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 15, Roll total: 18 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 50
# Damage Roll result: [4], Roll total: 10
# Total Health after taking damage: 41
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('9cd54b97-f5e6-4373-b9b3-3cb4ac5c67aa'), dice_uuid=UUID('d19f2170-50fc-4c2d-84c9-ebcc9e407bde'), roll_type=<RollType.ATTACK: 'Attack'>, results=15, total=18, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('29c2a559-6b19-46b9-88db-2fb4424e0637'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, blocks={}, values={UUID('7e9c0e49-d2fe-4e3b-a513-420f3f01906c'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('7e9c0e49-d2fe-4e3b-a513-420f3f01906c'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE980>, generated_from=[UUID('b8e85a7d-91b8-4db5-9732-12b4cfcd14b2'), UUID('66f7c1bc-3e5f-43e1-82cd-8083dc2d6def'), UUID('db4bd071-a7d2-4c1f-89a5-2507c9ec50b8'), UUID('c89f4213-4dd6-4d87-9439-5336cef9aa36')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('ac39a4a1-0798-4759-a7c2-696db20c8d8c'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE980>, generated_from=[UUID('063192e1-de2f-4113-aae3-a727d7daf65a'), UUID('2848c7b3-de5e-4076-8a93-081a0a19cea1'), UUID('9324b302-4201-4c5b-b695-c7194cd7cc9e'), UUID('cae3ca62-ff4a-4f02-97f8-2d6d6a29f320')], global_normalizer=False, value_modifiers={UUID('c9f72fb4-2569-47f9-9819-f53e5e72a9ae'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('c9f72fb4-2569-47f9-9819-f53e5e72a9ae'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE980>, normalized_value=1), UUID('42531e5c-4fa4-40e8-bb23-5313a480f7a5'): NumericalModifier(name='a past in the circus', uuid=UUID('42531e5c-4fa4-40e8-bb23-5313a480f7a5'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('bde41a38-fc3f-44c8-a844-5bfff66b086f'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('bde41a38-fc3f-44c8-a844-5bfff66b086f'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE0C0>, normalized_value=0), UUID('9f08f696-4032-4f6e-8d26-28f8fc6cb271'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('9f08f696-4032-4f6e-8d26-28f8fc6cb271'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001A99E5AE5C0>, normalized_value=0), UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('3c04c57b-8f2f-4bb3-97cc-dbd229edcba5'), dice_uuid=UUID('837d0641-8609-476b-9808-e957585f3d8a'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[4], total=10, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()
# Out:
# True

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('d4badc58-4021-4009-914c-fa05ffdb4a1b'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('a5484f1c-8812-4803-85b3-b87f76e244d4'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d2453b2b-98c2-4908-9aac-0e19337212c9'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, normalized_value=2), UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'): NumericalModifier(name='level 4 talent', uuid=UUID('b8d1adbd-d280-48a5-8db4-04a8256b3696'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e86ee5a4-1884-40de-b183-addc64778664'), source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), source_entity_name=None, target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001A99BA09800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# charmer_id: 1d9039e3-077f-4199-ae77-8a2b1f33ae90, source_entity_uuid: 4d809d91-4e96-4ad6-945a-3af2862e01fe, target_entity_uuid: 1d9039e3-077f-4199-ae77-8a2b1f33ae90
# Roll result: 18, Roll total: 21 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('a65d44b0-1ac2-4599-b53b-44fc31e810a9'), dice_uuid=UUID('28be8c3d-c88a-47e6-8771-24a469640223'), roll_type=<RollType.ATTACK: 'Attack'>, results=18, total=21, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), target_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), attack_outcome=None),
#  [])

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)
# Out:
# Target AC: 15
# Attack bonus: 0
# charmer_id: 1d9039e3-077f-4199-ae77-8a2b1f33ae90,charmed_id: 4d809d91-4e96-4ad6-945a-3af2862e01fe, source_entity_uuid: 4d809d91-4e96-4ad6-945a-3af2862e01fe, target_entity_uuid: 1d9039e3-077f-4199-ae77-8a2b1f33ae90
# charmer_id: 1d9039e3-077f-4199-ae77-8a2b1f33ae90,charmed_id: 4d809d91-4e96-4ad6-945a-3af2862e01fe, source_entity_uuid: 4d809d91-4e96-4ad6-945a-3af2862e01fe, target_entity_uuid: 1d9039e3-077f-4199-ae77-8a2b1f33ae90
# Roll result: 12, Roll total: 12 vs target ac: 15 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# charmer_id: 1d9039e3-077f-4199-ae77-8a2b1f33ae90,charmed_id: 4d809d91-4e96-4ad6-945a-3af2862e01fe, source_entity_uuid: 4d809d91-4e96-4ad6-945a-3af2862e01fe, target_entity_uuid: 1d9039e3-077f-4199-ae77-8a2b1f33ae90
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('1dd05b2d-1b1b-4200-8d60-0d89c39102fb'), dice_uuid=UUID('60176079-afa9-4841-8d6e-cd19736c4ce6'), roll_type=<RollType.ATTACK: 'Attack'>, results=12, total=12, bonus=0, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('1d9039e3-077f-4199-ae77-8a2b1f33ae90'), target_entity_uuid=UUID('4d809d91-4e96-4ad6-945a-3af2862e01fe'), attack_outcome=None),
#  False)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)
# Out:
# UUID('03ce9d01-6b0c-4c7e-8b9c-b914f1136967')

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score
# Out:
# 5

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score
# Out:
# 0

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()
# Out:
# True

# %%
warrior.action_economy.movement.normalized_score
# Out:
# 0

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score
