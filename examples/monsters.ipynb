# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior(name="Mona")

# %%
warrior.source_entity_uuid
# Out:
# UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('beb77181-41e1-4cb6-9224-38cf4544472b')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('beb77181-41e1-4cb6-9224-38cf4544472b'): AbilityScores(name='ability_scores', description=None, uuid=UUID('beb77181-41e1-4cb6-9224-38cf4544472b'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('d4e1715b-783d-4e74-99df-cea5e8d3aecc'): Ability(name='strength', description=None, uuid=UUID('d4e1715b-783d-4e74-99df-cea5e8d3aecc'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('59d2cb23-db1d-43e7-9942-2fbdd3526aab'): ModifiableValue(name='strength Ability Score', uuid=UUID('59d2cb23-db1d-43e7-9942-2fbdd3526aab'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8a718508-7812-4531-a55c-222257292034'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('040fe152-2725-49f6-a421-5594cdf5f69f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('040fe152-2725-49f6-a421-5594cdf5f69f'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'): NumericalModifier(name='level 4 talent', uuid=UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Damag ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('59d2cb23-db1d-43e7-9942-2fbdd3526aab'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8a718508-7812-4531-a55c-222257292034'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('040fe152-2725-49f6-a421-5594cdf5f69f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('040fe152-2725-49f6-a421-5594cdf5f69f'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'): NumericalModifier(name='level 4 talent', uuid=UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e16ca177-7777-4402-9777-367404f0fcac'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 20

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 15

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.0004973411560058594

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('59d2cb23-db1d-43e7-9942-2fbdd3526aab'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8a718508-7812-4531-a55c-222257292034'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('040fe152-2725-49f6-a421-5594cdf5f69f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('040fe152-2725-49f6-a421-5594cdf5f69f'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'): NumericalModifier(name='level 4 talent', uuid=UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e16ca177-7777-4402-9777-367404f0fcac'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.0020160675048828125

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0005013942718505859

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 2, Roll total: 7 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0005047321319580078

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Damage Roll result: [1], Roll total: 7
# Total Health after taking damage: 52
# 0.0010018348693847656

# %%
damages
# Out:
# [Damage(name='Damage', description=None, uuid=UUID('c8576365-1a37-4587-ad09-a0c9a57209e5'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('42eb1b82-85a5-4492-a05c-0ee62e7cb90d'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('42eb1b82-85a5-4492-a05c-0ee62e7cb90d'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020793719080>, generated_from=[UUID('43ab8e6a-b492-4561-bde6-d98f00e0e1b2'), UUID('0267d1de-f904-4560-8be3-e23adaac7e42'), UUID('46e37793-aa4b-429c-ae0e-c14b4a6ec1db'), UUID('4b2ded91-98ea-4274-899b-f2f3a18064ea')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('5a682201-d4e6-47a6-bde2-5e0c53af9cad'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020793719080>, generated_from=[UUID('3407466c-a162-4687-9fb6-da5603e3faae'), UUID('a642715c-8a56-471a-802b-3b46865a4cde'), UUID('06c0b323-a042-4aa9-8222-d114b44e83e7'), UUID('b4fcd3f8-01cb-4222-baa5-ad16c1138c2f')], global_normalizer=False, value_modifiers={UUID('34fea9aa-6fa7-4a3a-9691-5299fbace647'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('34fea9aa-6fa7-4a3a-9691-5299fbace647'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020793719080>, normalized_value=1), UUID('96d10c4a-a0f2-4a53-95ec-78215a8fdabf'): NumericalModifier(name='a past in the circus', uuid=UUID('96d10c4a-a0f2-4a53-95ec-78215a8fdabf'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('c69e21bc-0ee2-472e-906b-d070b00d3b6e'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('c69e21bc-0ee2-472e-906b-d070b00d3b6e'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x00000207937187C0>, normalized_value=0), UUID('43344124-e5a3-4d56-8756-8e7661786055'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('43344124-e5a3-4d56-8756-8e7661786055'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020793718CC0>, normalized_value=0), UUID('040fe152-2725-49f6-a421-5594cdf5f69f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('040fe152-2725-49f6-a421-5594cdf5f69f'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'): NumericalModifier(name='level 4 talent', uuid=UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_n ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0014998912811279297

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.001004934310913086

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0024993419647216797

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.00201416015625

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('59d2cb23-db1d-43e7-9942-2fbdd3526aab'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8a718508-7812-4531-a55c-222257292034'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('040fe152-2725-49f6-a421-5594cdf5f69f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('040fe152-2725-49f6-a421-5594cdf5f69f'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'): NumericalModifier(name='level 4 talent', uuid=UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e16ca177-7777-4402-9777-367404f0fcac'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 10, Roll total: 15 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 52
# Damage Roll result: [4], Roll total: 10
# Total Health after taking damage: 43
# 0.00850677490234375

# %%
from dnd.core.requests import SkillCheckRequest, SavingThrowRequest, SkillName

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request
# Out:
# SkillCheckRequest(dc=12, source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), context=None, skill_name='acrobatics')

# %%
strength_saving_throw_request
# Out:
# SavingThrowRequest(dc=12, source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), context=None, ability_name='strength')

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")
# Out:
# ModifiableValue(name='Value_acrobatics Skill Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('e78989c0-06c1-4ad4-a244-929bd5adbd2f'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020793965580>, generated_from=[UUID('873bdc0e-c620-45e6-83c0-9554450e2737'), UUID('6ded4421-e2c9-4d7b-93cd-6266ff773965'), UUID('912d168e-dfcb-48af-b488-85a2d228f757'), UUID('199f8d3e-dbaa-4e18-9821-72460ee00474')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('3cc5e8df-9fb8-4b1d-a4e5-7297f788c41b'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020793965580>, generated_from=[UUID('0a24107a-75d8-490f-862b-5320be7e5b0d'), UUID('fae24c5b-f146-4c49-9811-faf05bae155e'), UUID('169d4eb5-b112-40b6-be4a-40f575270219'), UUID('1be45a28-eb76-4eb9-acb3-390c203b3ad6')], global_normalizer=False, value_modifiers={UUID('77aadeec-d728-4fa8-8f78-510cdcecbbfc'): NumericalModifier(name='Value_base_value', uuid=UUID('77aadeec-d728-4fa8-8f78-510cdcecbbfc'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=0, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020793965580>, normalized_value=0), UUID('698c5cc4-c8f8-4ca7-a08e-7a3cac1a91f8'): NumericalModifier(name='a past in the circus', uuid=UUID('698c5cc4-c8f8-4ca7-a08e-7a3cac1a91f8'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x0000020793965580>, normalized_value=-2), UUID('9c7d53ff-9b38-4a7a-99b0-3e83b514274d'): NumericalModifier(name='acrobatics Skill Bonus_base_value', uuid=UUID('9c7d53ff-9b38-4a7a-99b0-3e83b514274d'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002079371A8E0>, normalized_value=0), UUID('2d3bbac5-9bc2-45c6-aad5-856a8f3c7128'): NumericalModifier(name='a past in the circus', uuid=UUID('2d3bbac5-9bc2-45c6-aad5-856a8f3c7128'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=7, score_normalizer=None, normalized_value=7), UUID('901267ed-3792-4c10-9a96-b8ae89e3755b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('901267ed-3792-4c10-9a96-b8ae89e3755b'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=12, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=1), UUID('579a4144-3482-456c-9d10-0baaa32e6697'): NumericalModifier(name='strength Modifier Bonus_base_value', uuid=UUID('579a4144-3482-456c-9d10-0baaa32e6697'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x0000020793719C60>, normalized_value=0)}, min_constraints={}, max_co ...

# %%
warrior2.skill_check(acrobatics_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 6
# Roll result: 5, Roll total: 11 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('b2fac51c-8d7c-4d2d-9413-d306cfc6318f'), dice_uuid=UUID('ca37a321-d9d0-4e57-ade2-825ce064b93f'), roll_type=<RollType.ATTACK: 'Attack'>, results=5, total=11, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  False)

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 20, Roll total: 20 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.CRIT: 'Crit'>,
#  DiceRoll(roll_uuid=UUID('b66a1130-9666-422d-8e19-35947ee4194c'), dice_uuid=UUID('1bf60d16-23c7-4719-ab61-14c759cffb8c'), roll_type=<RollType.ATTACK: 'Attack'>, results=20, total=20, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  True)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")
# Out:
# ModifiableValue(name='Value_strength_saving_throw Saving Throw Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('8fe0386e-2d6a-44a3-a5cb-592664bd671d'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020793965080>, generated_from=[UUID('873bdc0e-c620-45e6-83c0-9554450e2737'), UUID('924c4533-fe50-4355-b44c-bd0d4eb5a289'), UUID('6972fef1-91f0-43ba-963b-0311565a6353'), UUID('f8d02a4d-fb67-464a-a9a2-9aa741676282')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('fb1541ca-be87-48ff-92ab-7184bc5a5475'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020793965080>, generated_from=[UUID('0a24107a-75d8-490f-862b-5320be7e5b0d'), UUID('e38c1ef0-134c-41ed-9619-b82d5eb224f2'), UUID('e204e7a4-cf69-43f2-9000-5be71c60e48d'), UUID('676905a7-2c4f-47c6-bcbf-8bff5d001416')], global_normalizer=False, value_modifiers={UUID('77aadeec-d728-4fa8-8f78-510cdcecbbfc'): NumericalModifier(name='Value_base_value', uuid=UUID('77aadeec-d728-4fa8-8f78-510cdcecbbfc'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=0, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020793965080>, normalized_value=0), UUID('698c5cc4-c8f8-4ca7-a08e-7a3cac1a91f8'): NumericalModifier(name='a past in the circus', uuid=UUID('698c5cc4-c8f8-4ca7-a08e-7a3cac1a91f8'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x0000020793965080>, normalized_value=-1), UUID('a0fdcc33-78ad-4afa-9e31-6efc29aadc17'): NumericalModifier(name='strength_saving_throw Saving Throw Bonus_base_value', uuid=UUID('a0fdcc33-78ad-4afa-9e31-6efc29aadc17'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002079383CAE0>, normalized_value=0), UUID('2b81ef03-97ac-4eae-9e35-cbfd444655ad'): NumericalModifier(name='a past in the circus', uuid=UUID('2b81ef03-97ac-4eae-9e35-cbfd444655ad'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('aae47572-b873-440a-9539-c12f716af591'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aae47572-b873-440a-9539-c12f716af591'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'): NumericalModifier(name='level 4 talent', uuid=UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('f5152b2d-da5e-4fc5-a20e-9327c413364a'): NumericalModifier(name='strength Modifier  ...

# %%
warrior2.saving_throw(strength_saving_throw_request)
# Out:
# Target AC: 12
# Attack bonus: 4
# Roll result: 3, Roll total: 7 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('281a9835-77f1-4743-8be8-a2e9546dbe07'), dice_uuid=UUID('3b29bc00-313e-45d8-8b64-95e64c5d9c91'), roll_type=<RollType.ATTACK: 'Attack'>, results=3, total=7, bonus=4, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  False)

# %%
from dnd.conditions import Blinded

blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# True

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.DISADVANTAGE: 'Disadvantage'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('6972fef1-91f0-43ba-963b-0311565a6353'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e204e7a4-cf69-43f2-9000-5be71c60e48d'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aae47572-b873-440a-9539-c12f716af591'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aae47572-b873-440a-9539-c12f716af591'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'): NumericalModifier(name='level 4 talent', uuid=UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e832ad90-1fa9-4c98-9568-c1d34acceefb'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 7, Roll total: 10 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.DISADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.DISADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('6cf17f1a-015e-4a3a-91ce-fa9c72ffb26a'), dice_uuid=UUID('f2d8444e-eb9e-4a8e-a045-cc9877292805'), roll_type=<RollType.ATTACK: 'Attack'>, results=7, total=10, bonus=3, advantage_status=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  [])

# %%
warrior.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior.attack(warrior2.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('59d2cb23-db1d-43e7-9942-2fbdd3526aab'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('8a718508-7812-4531-a55c-222257292034'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('040fe152-2725-49f6-a421-5594cdf5f69f'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('040fe152-2725-49f6-a421-5594cdf5f69f'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'): NumericalModifier(name='level 4 talent', uuid=UUID('58248ed2-7cbe-4e34-9fe1-b7b17e56f062'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e16ca177-7777-4402-9777-367404f0fcac'), source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 2, Roll total: 7 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('0208e5df-77eb-4216-b130-c8ca3c680779'), dice_uuid=UUID('d7e9859c-d451-4c4b-a04d-9f996bdda7c2'), roll_type=<RollType.ATTACK: 'Attack'>, results=2, total=7, bonus=5, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), attack_outcome=None),
#  [])

# %%
blinded.modifers_uuids
# Out:
# {UUID('4619ace6-e623-4879-9d49-1cd83924ab4b'): [UUID('44422c35-07a6-4e25-a962-512d55441b86')],
#  UUID('0c0f29a0-fb04-421b-8401-7540bd980164'): [UUID('e59cff1a-bc27-4762-b73f-a19cf2fd5a75')],
#  UUID('bfda379f-a447-41e9-9721-f36a5207de96'): [UUID('60a53ac6-6571-47a8-bb4a-72b2665c051e')],
#  UUID('1ae92ac0-b2ff-44bf-b45a-ab8dc01ee0a9'): [UUID('ddae1cc7-4cd8-41a7-8b0c-fda3b9b7c8d7')],
#  UUID('049374b0-4c10-474e-8276-e5e483bf53d8'): [UUID('21dec3cc-bfd5-4c5d-9a04-ab10e7c2c5b2')],
#  UUID('cd931911-a148-4939-aaae-be82001b83da'): [UUID('171edbe5-93a8-46d3-8c11-f1981fd29184')]}

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 19, Roll total: 19 vs target ac: 12 result: True auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('08c88073-079d-45ac-8cd6-39ce9b29e59e'), dice_uuid=UUID('01aff4e8-b971-45a6-abc6-3ae578235a81'), roll_type=<RollType.ATTACK: 'Attack'>, results=19, total=19, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  False)

# %%
blinded.remove()
# Out:
# True

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 19, Roll total: 19 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('81e8dbe6-a933-4aab-9a53-bfeb6745b751'), dice_uuid=UUID('a5eeb63e-914c-49ad-8c0f-d996d5da2045'), roll_type=<RollType.ATTACK: 'Attack'>, results=19, total=19, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  True)

# %%
warrior2.equipment.attack_bonus.advantage
# Out:
# <AdvantageStatus.NONE: 'None'>

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('6972fef1-91f0-43ba-963b-0311565a6353'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e204e7a4-cf69-43f2-9000-5be71c60e48d'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aae47572-b873-440a-9539-c12f716af591'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aae47572-b873-440a-9539-c12f716af591'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'): NumericalModifier(name='level 4 talent', uuid=UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e832ad90-1fa9-4c98-9568-c1d34acceefb'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# Roll result: 12, Roll total: 15 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 58
# Damage Roll result: [2], Roll total: 8
# Total Health after taking damage: 51
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('d8fcf7a9-8b68-4da3-b9ca-5ccb49c2416c'), dice_uuid=UUID('5e111022-8e2f-4fd5-9c75-0817b1ded639'), roll_type=<RollType.ATTACK: 'Attack'>, results=12, total=15, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  [(Damage(name='Damage', description=None, uuid=UUID('e4a122e4-8edd-4126-88f7-f3cb00d3ac27'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, blocks={}, values={UUID('f9f27cc9-3cbd-4724-8b1f-7a0b9d66c2a7'): ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('f9f27cc9-3cbd-4724-8b1f-7a0b9d66c2a7'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002079383EC00>, generated_from=[UUID('af4dc685-d515-49f4-a383-00cff43276a0'), UUID('d6a31695-b382-433d-bb24-9fff5e552101'), UUID('5c265e54-0e72-4b2c-a0a2-4f4cc3887084'), UUID('8a0435f3-23f4-47cf-84ae-f06c45aecb54')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('6a40130b-ed20-408c-a15b-1cc7440aeaee'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002079383EC00>, generated_from=[UUID('1a48b85f-ac97-43b3-8294-f9b8d66e7ba2'), UUID('8993e1db-44fd-4065-83e6-31d451af82a2'), UUID('f3af82bc-5c62-40be-b3ce-78be73ab65c3'), UUID('f00fbe91-211a-4fdb-a81a-e575d37a4553')], global_normalizer=False, value_modifiers={UUID('52cf30e1-b8aa-4276-aa3e-cabb26898285'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('52cf30e1-b8aa-4276-aa3e-cabb26898285'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002079383EC00>, normalized_value=1), UUID('b6e0682d-c309-4adf-9ab6-c2ba8a0d5555'): NumericalModifier(name='a past in the circus', uuid=UUID('b6e0682d-c309-4adf-9ab6-c2ba8a0d5555'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('cd31fbe6-7f00-40aa-acad-43322f1603f0'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('cd31fbe6-7f00-40aa-acad-43322f1603f0'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002079383E340>, normalized_value=0), UUID('e0b7acba-e0a9-4bcb-91c2-ed6015754c12'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('e0b7acba-e0a9-4bcb-91c2-ed6015754c12'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000002079383E840>, normalized_value=0), UUID('aae47572-b873-440a-9539-c12f716af591'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aae47572-b873-440a-9539-c12f716af591'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'): NumericalModifier(name='level 4 talent', uuid=UUID ...
#    DiceRoll(roll_uuid=UUID('ce2604d1-4ae6-4a15-9ff6-f63bddca13ca'), dice_uuid=UUID('2fb446ae-1e17-4f90-b914-e51533a0ef83'), roll_type=<RollType.DAMAGE: 'Damage'>, results=[2], total=8, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=<AttackOutcome.HIT: 'Hit'>))])

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()
# Out:
# True

# %%
warrior2.attack(warrior.uuid,weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('6972fef1-91f0-43ba-963b-0311565a6353'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e204e7a4-cf69-43f2-9000-5be71c60e48d'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('aae47572-b873-440a-9539-c12f716af591'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('aae47572-b873-440a-9539-c12f716af591'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, normalized_value=2), UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'): NumericalModifier(name='level 4 talent', uuid=UUID('4b27c53c-0b6a-40fd-b8cf-278f8fad1cb3'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e832ad90-1fa9-4c98-9568-c1d34acceefb'), source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), source_entity_name=None, target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x0000020790C95800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 3
# charmer_id: f54bd469-d0c9-43f7-b74d-a27c9031a2fb, source_entity_uuid: c4592d01-021a-4d2d-b755-e815c840b2db, target_entity_uuid: f54bd469-d0c9-43f7-b74d-a27c9031a2fb
# Roll result: 5, Roll total: 8 vs target ac: 12 result: False auto hit status: AutoHitStatus.AUTOMISS critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.AUTOMISS
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('116b3d96-e70a-4fa7-acb8-bf17f9e04d20'), dice_uuid=UUID('4f905f4c-5dee-479b-9a71-85f302106af8'), roll_type=<RollType.ATTACK: 'Attack'>, results=5, total=8, bonus=3, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.AUTOMISS: 'Automiss'>, source_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), target_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), attack_outcome=None),
#  [])

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)
# Out:
# Target AC: 15
# Attack bonus: 0
# charmer_id: f54bd469-d0c9-43f7-b74d-a27c9031a2fb,charmed_id: c4592d01-021a-4d2d-b755-e815c840b2db, source_entity_uuid: c4592d01-021a-4d2d-b755-e815c840b2db, target_entity_uuid: f54bd469-d0c9-43f7-b74d-a27c9031a2fb
# charmer_id: f54bd469-d0c9-43f7-b74d-a27c9031a2fb,charmed_id: c4592d01-021a-4d2d-b755-e815c840b2db, source_entity_uuid: c4592d01-021a-4d2d-b755-e815c840b2db, target_entity_uuid: f54bd469-d0c9-43f7-b74d-a27c9031a2fb
# Roll result: 8, Roll total: 8 vs target ac: 15 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# charmer_id: f54bd469-d0c9-43f7-b74d-a27c9031a2fb,charmed_id: c4592d01-021a-4d2d-b755-e815c840b2db, source_entity_uuid: c4592d01-021a-4d2d-b755-e815c840b2db, target_entity_uuid: f54bd469-d0c9-43f7-b74d-a27c9031a2fb
# Attack bonus advantage modifiers: AdvantageStatus.ADVANTAGE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.ADVANTAGE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('877278d1-ebda-4236-b404-212919568699'), dice_uuid=UUID('5dd96673-81b4-4ae1-83fd-6622090654a3'), roll_type=<RollType.ATTACK: 'Attack'>, results=8, total=8, bonus=0, advantage_status=<AdvantageStatus.ADVANTAGE: 'Advantage'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('f54bd469-d0c9-43f7-b74d-a27c9031a2fb'), target_entity_uuid=UUID('c4592d01-021a-4d2d-b755-e815c840b2db'), attack_outcome=None),
#  False)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)
# Out:
# UUID('63c1f357-e33b-4596-85e8-84d0e178f14d')

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score
# Out:
# 5

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score
# Out:
# 0

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()
# Out:
# True

# %%
warrior.action_economy.movement.normalized_score
# Out:
# 0

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score
# Out:
# 30
