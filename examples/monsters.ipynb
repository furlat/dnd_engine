# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4
from dnd.core.events import EventQueue

import time
from uuid import UUID

# %%
start_time = time.time()
source_id = uuid4()
proficiency_bonus = 2

# %%
q = EventQueue()

# %%
warrior = create_warrior(source_id,proficiency_bonus,position=(0,0))
q._all_events
# Out:
# [ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('e10f61f0-7af7-4239-a1ca-0d6961a003e8'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resist ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('b6e52c3b-654b-49a5-ab35-a87d87da96ed'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceS ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('1d460e47-506f-4651-9729-de9d58272cd7'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus. ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('b48510ef-4763-4714-9cc9-3bfa5aa08f6d'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resistanc ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('72c39c4b-6d9d-4459-bf91-7771edfb8f18'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: < ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('d4a467c2-28e2-42fe-8b19-4a89d8acc3f7'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resis ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('df142f27-a64b-4b91-bc0f-24928ee4a735'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceS ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('df850648-26a3-4723-90e6-5f49f60d9d36'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Res ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('ecdbecdc-0253-428b-a18f-acd73ef750b8'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('40ab94a8-8ade-42c1-b572-50e7a5161272'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('c91cdd78-b377-4c73-8192-bb6da4b4a819'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'): ModifiableValue(name='Attack Bonus', uuid=UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e2c5bdad-bb14-471a-8719-6041776f5778'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, value_modifiers={UUID('307985f4-725d-45f8-8796-0665d78ecd41'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('307985f4-725d-45f8-8796-0665d78ecd41'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('a135046a-2779-44f0-b413-830a6e349aa3'): AdvantageModifier(name='Rusty Blade', uuid=UUID('a135046a-2779-44f0-b413-830a6e349aa3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus. ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('cd54f96e-e039-4aab-8173-78dbc7924f1a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('40ab94a8-8ade-42c1-b572-50e7a5161272'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('c91cdd78-b377-4c73-8192-bb6da4b4a819'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'): ModifiableValue(name='Attack Bonus', uuid=UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e2c5bdad-bb14-471a-8719-6041776f5778'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, value_modifiers={UUID('307985f4-725d-45f8-8796-0665d78ecd41'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('307985f4-725d-45f8-8796-0665d78ecd41'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('a135046a-2779-44f0-b413-830a6e349aa3'): AdvantageModifier(name='Rusty Blade', uuid=UUID('a135046a-2779-44f0-b413-830a6e349aa3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('600c6d72-1c87-42fe-94d8-f493a1c8d9a9'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('40ab94a8-8ade-42c1-b572-50e7a5161272'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('c91cdd78-b377-4c73-8192-bb6da4b4a819'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'): ModifiableValue(name='Attack Bonus', uuid=UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e2c5bdad-bb14-471a-8719-6041776f5778'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, value_modifiers={UUID('307985f4-725d-45f8-8796-0665d78ecd41'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('307985f4-725d-45f8-8796-0665d78ecd41'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('a135046a-2779-44f0-b413-830a6e349aa3'): AdvantageModifier(name='Rusty Blade', uuid=UUID('a135046a-2779-44f0-b413-830a6e349aa3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None ...
# ...
#  ConditionApplicationEvent(name='Elemental Weapon Mastery', uuid=UUID('6089b172-5857-48eb-a432-02ae57bd7e71'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, lineage_uuid=UUID('b6f3dbf9-a71f-4b27-92bb-bcd7d11b7782'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 465255), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Weapon Mastery contextual advantage modifier condition to Ganger', lineage_children_events=[], children_events=[], condition=ElementalWeaponMastery(name='Elemental Weapon Mastery', uuid=UUID('fa8cf6a8-8121-49e8-852f-6e9250d5031c'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('37952da2-76c9-47be-b839-25678eb7f509'), source_entity_uuid=UUID('2a0e4243-1347-4a75-82bb-266ef48309e4'), source_entity_name=None, target_entity_uuid=UUID('914f1a7d-64c4-49aa-bbc4-04e62d7452e7'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('fa8cf6a8-8121-49e8-852f-6e9250d5031c'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('272dbf92-9fcf-4a95-8140-b312bc04770a'): [UUID('ef4f9f76-a259-46fa-b461-9e6118a18f45')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='You have advantage on attack rolls made with weapons that deal acid, cold, fire, lightning, poison, or thunder damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('489e8add-c1af-445e-8b0f-62a665567daf'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, lineage_uuid=UUID('1fc70364-7319-467e-ac32-314d3ee3417b'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 465255), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('18ac8180-fe0f-455b-9a5c-d173370b5509'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('f8b2c834-6a66-4111-820a-3d616e201f3f'), source_entity_uuid=UUID('a8339914-d884-4b2b-a103-222cf71b7bb4'), source_entity_name=None, target_entity_uuid=UUID('0aac1804-8990-40b4-8df8-bcf9279abffe'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('18ac8180-fe0f-455b-9a5c-d173370b5509'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('299ad774-0922-4d96-9700-a1b1d10e7328'), UUID('1ce3ee5e-9f25-4756-b15c-161c2ade1ab5')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('1dc9e9cb-ae14-4dec-9162-d585f40fb0f3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, lineage_uuid=UUID('1fc70364-7319-467e-ac32-314d3ee3417b'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 465255), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Affinity resistance modifier condition to Ganger', lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('18ac8180-fe0f-455b-9a5c-d173370b5509'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('f8b2c834-6a66-4111-820a-3d616e201f3f'), source_entity_uuid=UUID('a8339914-d884-4b2b-a103-222cf71b7bb4'), source_entity_name=None, target_entity_uuid=UUID('0aac1804-8990-40b4-8df8-bcf9279abffe'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('18ac8180-fe0f-455b-9a5c-d173370b5509'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('299ad774-0922-4d96-9700-a1b1d10e7328'), UUID('1ce3ee5e-9f25-4756-b15c-161c2ade1ab5')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('f1a8eab3-c7d5-4972-8bb7-67080f4d63e3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, lineage_uuid=UUID('1fc70364-7319-467e-ac32-314d3ee3417b'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 465255), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Affinity resistance modifier condition to Ganger', lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('18ac8180-fe0f-455b-9a5c-d173370b5509'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('f8b2c834-6a66-4111-820a-3d616e201f3f'), source_entity_uuid=UUID('a8339914-d884-4b2b-a103-222cf71b7bb4'), source_entity_name=None, target_entity_uuid=UUID('0aac1804-8990-40b4-8df8-bcf9279abffe'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('18ac8180-fe0f-455b-9a5c-d173370b5509'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('299ad774-0922-4d96-9700-a1b1d10e7328'), UUID('1ce3ee5e-9f25-4756-b15c-161c2ade1ab5')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('e1e380a6-cb31-4d44-83b2-2ff9a751360d'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, lineage_uuid=UUID('cb02cdfa-8f99-4594-b5bc-adf8ef49de8d'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 465255), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('df11ae02-58d0-4ecc-8a40-d3dc2472939e'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('56d0fdf7-53cf-4b0e-b9de-c30c6de4d1e6'), source_entity_uuid=UUID('708b241e-4d72-4f3f-9a20-26bbfadb1295'), source_entity_name=None, target_entity_uuid=UUID('72dbc926-4d13-4a05-80c1-cfc309e87e35'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('df11ae02-58d0-4ecc-8a40-d3dc2472939e'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('63e5d5dd-9838-4ed6-988c-2b1531157315'): [UUID('e73c1c4a-7e21-4bc2-9981-45a940c99c67')], UUID('77b3d29e-5de4-42db-8ac5-6d0cc1f07c40'): [UUID('1b7194e2-ada3-4809-970c-c0faa4d509ac')], UUID('8dcf01fe-758f-4945-9e9c-ed8c493ff982'): [UUID('98f44596-2090-42f4-b73e-c084920be532')], UUID('a03d260f-27dd-4c4e-9226-98f9523e3203'): [UUID('7d26a95a-07f2-4ca9-b904-76f810e199ff')], UUID('ceb73bd4-ab37-4a43-98c3-9acb796da93b'): [UUID('f7b937ab-6195-4c83-994b-a0f2dce70cc3')], UUID('1e072dde-a9c3-4c9f-8bc4-127f3fc9c3ad'): [UUID('7debec59-a6bb-4928-bab1-53023f6bad93')], UUID('f4a60534-ecd8-4d68-9fbd-83bc662c0411'): [UUID('3e3c7e56-e317-443f-879c-5da9824f5ade')], UUID('b2bd67f6-a044-4c27-b28e-36040d9d0c5c'): [UUID('102ffd4e-03ad-4d82-afb8-7209a221de04')], UUID('0d92c5ed-394a-4e0e-8d6e-8761fa946736'): [UUID('390bb358-47b3-48a6-8cc7-9f173358fc35')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('5c28c321-c44e-4380-87a6-9d744acd813f'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, lineage_uuid=UUID('cb02cdfa-8f99-4594-b5bc-adf8ef49de8d'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 465765), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Ganger', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('df11ae02-58d0-4ecc-8a40-d3dc2472939e'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('56d0fdf7-53cf-4b0e-b9de-c30c6de4d1e6'), source_entity_uuid=UUID('708b241e-4d72-4f3f-9a20-26bbfadb1295'), source_entity_name=None, target_entity_uuid=UUID('72dbc926-4d13-4a05-80c1-cfc309e87e35'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('df11ae02-58d0-4ecc-8a40-d3dc2472939e'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('63e5d5dd-9838-4ed6-988c-2b1531157315'): [UUID('e73c1c4a-7e21-4bc2-9981-45a940c99c67')], UUID('77b3d29e-5de4-42db-8ac5-6d0cc1f07c40'): [UUID('1b7194e2-ada3-4809-970c-c0faa4d509ac')], UUID('8dcf01fe-758f-4945-9e9c-ed8c493ff982'): [UUID('98f44596-2090-42f4-b73e-c084920be532')], UUID('a03d260f-27dd-4c4e-9226-98f9523e3203'): [UUID('7d26a95a-07f2-4ca9-b904-76f810e199ff')], UUID('ceb73bd4-ab37-4a43-98c3-9acb796da93b'): [UUID('f7b937ab-6195-4c83-994b-a0f2dce70cc3')], UUID('1e072dde-a9c3-4c9f-8bc4-127f3fc9c3ad'): [UUID('7debec59-a6bb-4928-bab1-53023f6bad93')], UUID('f4a60534-ecd8-4d68-9fbd-83bc662c0411'): [UUID('3e3c7e56-e317-443f-879c-5da9824f5ade')], UUID('b2bd67f6-a044-4c27-b28e-36040d9d0c5c'): [UUID('102ffd4e-03ad-4d82-afb8-7209a221de04')], UUID('0d92c5ed-394a-4e0e-8d6e-8761fa946736'): [UUID('390bb358-47b3-48a6-8cc7-9f173358fc35')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('960e1141-0786-4c95-9e84-c9b94fc25850'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, lineage_uuid=UUID('cb02cdfa-8f99-4594-b5bc-adf8ef49de8d'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 465765), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Ganger', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('df11ae02-58d0-4ecc-8a40-d3dc2472939e'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('56d0fdf7-53cf-4b0e-b9de-c30c6de4d1e6'), source_entity_uuid=UUID('708b241e-4d72-4f3f-9a20-26bbfadb1295'), source_entity_name=None, target_entity_uuid=UUID('72dbc926-4d13-4a05-80c1-cfc309e87e35'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('df11ae02-58d0-4ecc-8a40-d3dc2472939e'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('63e5d5dd-9838-4ed6-988c-2b1531157315'): [UUID('e73c1c4a-7e21-4bc2-9981-45a940c99c67')], UUID('77b3d29e-5de4-42db-8ac5-6d0cc1f07c40'): [UUID('1b7194e2-ada3-4809-970c-c0faa4d509ac')], UUID('8dcf01fe-758f-4945-9e9c-ed8c493ff982'): [UUID('98f44596-2090-42f4-b73e-c084920be532')], UUID('a03d260f-27dd-4c4e-9226-98f9523e3203'): [UUID('7d26a95a-07f2-4ca9-b904-76f810e199ff')], UUID('ceb73bd4-ab37-4a43-98c3-9acb796da93b'): [UUID('f7b937ab-6195-4c83-994b-a0f2dce70cc3')], UUID('1e072dde-a9c3-4c9f-8bc4-127f3fc9c3ad'): [UUID('7debec59-a6bb-4928-bab1-53023f6bad93')], UUID('f4a60534-ecd8-4d68-9fbd-83bc662c0411'): [UUID('3e3c7e56-e317-443f-879c-5da9824f5ade')], UUID('b2bd67f6-a044-4c27-b28e-36040d9d0c5c'): [UUID('102ffd4e-03ad-4d82-afb8-7209a221de04')], UUID('0d92c5ed-394a-4e0e-8d6e-8761fa946736'): [UUID('390bb358-47b3-48a6-8cc7-9f173358fc35')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.'))]

# %%
warrior2 = create_warrior(name="Mona",position=(1,1))
q._all_events
# Out:
# [ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('e10f61f0-7af7-4239-a1ca-0d6961a003e8'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resist ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('b6e52c3b-654b-49a5-ab35-a87d87da96ed'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceS ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('1d460e47-506f-4651-9729-de9d58272cd7'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus. ...
#  ArmorEquipEvent(name="Performer's Leather Armor", uuid=UUID('b48510ef-4763-4714-9cc9-3bfa5aa08f6d'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('5511a341-b419-4cea-9685-f236bbb7c2be'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 400680), event_type=<EventType.ARMOR_EQUIP: 'armor_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<BodyPart.BODY: 'Body'>, armor=BodyArmor(name="Performer's Leather Armor", description='A masterfully crafted set of leather armor adorned with intricate circus motifs. The armor is specially designed to allow maximum flexibility for acrobatic performances while providing protection. Gold and silver thread accents catch the light during movement.', uuid=UUID('9fe66e84-b1b2-4b67-bf1b-9db3a264030a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'): ModifiableValue(name='Armor Class', uuid=UUID('d17baa1d-5a0b-4bd8-b94a-54e42ae1124b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('abeb365c-f26b-4ff1-a119-a786593ebb62'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, generated_from=[], global_normalizer=True, value_modifiers={UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'): NumericalModifier(name='Armor Class_base_value', uuid=UUID('a94b032b-f5f6-4413-aeda-8319e8bfb659'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=11, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440D60>, normalized_value=11)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=11, normalized_score=11, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <Resistanc ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('72c39c4b-6d9d-4459-bf91-7771edfb8f18'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: < ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('d4a467c2-28e2-42fe-8b19-4a89d8acc3f7'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Resis ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('df142f27-a64b-4b91-bc0f-24928ee4a735'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceS ...
#  WeaponEquipEvent(name='Flaming Scimitar', uuid=UUID('df850648-26a3-4723-90e6-5f49f60d9d36'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('41b3391a-77e9-459f-875a-a8d5a6c0bf5e'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, weapon=Weapon(name='Flaming Scimitar', description='An elegant curved blade enchanted with magical flames. The blade dances with fire during performances, leaving trails of light in its wake. The flames intensify when the wielder performs acrobatic maneuvers.', uuid=UUID('a029a341-ad99-4b95-be93-0c99c00bc40b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'): ModifiableValue(name='Attack Bonus', uuid=UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, generated_from=[], global_normalizer=True, value_modifiers={UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <Res ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('ecdbecdc-0253-428b-a18f-acd73ef750b8'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('40ab94a8-8ade-42c1-b572-50e7a5161272'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('c91cdd78-b377-4c73-8192-bb6da4b4a819'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'): ModifiableValue(name='Attack Bonus', uuid=UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e2c5bdad-bb14-471a-8719-6041776f5778'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, value_modifiers={UUID('307985f4-725d-45f8-8796-0665d78ecd41'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('307985f4-725d-45f8-8796-0665d78ecd41'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('a135046a-2779-44f0-b413-830a6e349aa3'): AdvantageModifier(name='Rusty Blade', uuid=UUID('a135046a-2779-44f0-b413-830a6e349aa3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus. ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('cd54f96e-e039-4aab-8173-78dbc7924f1a'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('40ab94a8-8ade-42c1-b572-50e7a5161272'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EXECUTION: 'execution'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('c91cdd78-b377-4c73-8192-bb6da4b4a819'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'): ModifiableValue(name='Attack Bonus', uuid=UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e2c5bdad-bb14-471a-8719-6041776f5778'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, value_modifiers={UUID('307985f4-725d-45f8-8796-0665d78ecd41'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('307985f4-725d-45f8-8796-0665d78ecd41'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('a135046a-2779-44f0-b413-830a6e349aa3'): AdvantageModifier(name='Rusty Blade', uuid=UUID('a135046a-2779-44f0-b413-830a6e349aa3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: ...
#  WeaponEquipEvent(name='Rusty Dagger', uuid=UUID('600c6d72-1c87-42fe-94d8-f493a1c8d9a9'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, lineage_uuid=UUID('40ab94a8-8ade-42c1-b572-50e7a5161272'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 458754), event_type=<EventType.WEAPON_EQUIP: 'weapon_equip'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], slot=<WeaponSlot.OFF_HAND: 'OFF_HAND'>, weapon=Weapon(name='Rusty Dagger', description='A poorly maintained dagger with a rusty blade. The ornate hilt is still beautiful, but the blade has seen better days, making it harder to strike accurately.', uuid=UUID('c91cdd78-b377-4c73-8192-bb6da4b4a819'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'): ModifiableValue(name='Attack Bonus', uuid=UUID('b5a502b6-b9c0-4090-a97a-02672bc63aab'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('e2c5bdad-bb14-471a-8719-6041776f5778'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, generated_from=[], global_normalizer=True, value_modifiers={UUID('307985f4-725d-45f8-8796-0665d78ecd41'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('307985f4-725d-45f8-8796-0665d78ecd41'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440900>, normalized_value=0)}, min_constraints={}, max_constraints={}, advantage_modifiers={UUID('a135046a-2779-44f0-b413-830a6e349aa3'): AdvantageModifier(name='Rusty Blade', uuid=UUID('a135046a-2779-44f0-b413-830a6e349aa3'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, numerical_value=-1)}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=0, normalized_score=0, advantage_sum=-1, advantage=<AdvantageStatus.DISADVANTAGE: 'Disadvantage'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None ...
# ...
#  ConditionApplicationEvent(name='Elemental Weapon Mastery', uuid=UUID('49a09b52-263a-4387-a670-eb7993ca5ade'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('01c45fe1-1a40-43ae-a11a-54624116fc98'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 510041), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Weapon Mastery contextual advantage modifier condition to Mona', lineage_children_events=[], children_events=[], condition=ElementalWeaponMastery(name='Elemental Weapon Mastery', uuid=UUID('76f0b4ad-ddac-4eed-b5d8-01284bb14cf1'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('3bc1788d-98c5-440a-b836-d8ba7ef33d40'), source_entity_uuid=UUID('51438049-4132-400f-893f-2576856c46c6'), source_entity_name=None, target_entity_uuid=UUID('cb8b569c-576f-424a-a694-bc864ccac9ff'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('76f0b4ad-ddac-4eed-b5d8-01284bb14cf1'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('15fb3482-b811-4ace-9153-d3920a897722'): [UUID('08e716b3-4f27-49f5-80c9-d844b69222b0')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='You have advantage on attack rolls made with weapons that deal acid, cold, fire, lightning, poison, or thunder damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('e41522bb-d34a-4bf6-bbf5-84ccf8f0c09f'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('4f931efc-0b56-43e1-aa28-8bf01b3b7399'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 510041), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('d51bde89-1f8c-4c32-a49f-559d242d5445'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('a96444d2-f546-4fcb-8b1c-e7eb5daa82ed'), source_entity_uuid=UUID('774c61a3-3e5d-466f-b9ff-646ba8475785'), source_entity_name=None, target_entity_uuid=UUID('51e0cae0-c4a9-4c58-959e-2b3b9c42a88f'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('d51bde89-1f8c-4c32-a49f-559d242d5445'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('4a85bede-1f24-47e1-8aa6-e4d8181a92ea'), UUID('79f7db8b-c1c2-4bfa-9596-e662358cc9e2')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('9df8d645-6014-4e73-ae38-aa270bc7d08d'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('4f931efc-0b56-43e1-aa28-8bf01b3b7399'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 510041), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Affinity resistance modifier condition to Mona', lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('d51bde89-1f8c-4c32-a49f-559d242d5445'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('a96444d2-f546-4fcb-8b1c-e7eb5daa82ed'), source_entity_uuid=UUID('774c61a3-3e5d-466f-b9ff-646ba8475785'), source_entity_name=None, target_entity_uuid=UUID('51e0cae0-c4a9-4c58-959e-2b3b9c42a88f'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('d51bde89-1f8c-4c32-a49f-559d242d5445'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('4a85bede-1f24-47e1-8aa6-e4d8181a92ea'), UUID('79f7db8b-c1c2-4bfa-9596-e662358cc9e2')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Elemental Affinity', uuid=UUID('62c9015f-a4c8-4b12-a7b0-afda8086ad40'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('4f931efc-0b56-43e1-aa28-8bf01b3b7399'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 510041), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Elemental Affinity resistance modifier condition to Mona', lineage_children_events=[], children_events=[], condition=ElementalAffinity(name='Elemental Affinity', uuid=UUID('d51bde89-1f8c-4c32-a49f-559d242d5445'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('a96444d2-f546-4fcb-8b1c-e7eb5daa82ed'), source_entity_uuid=UUID('774c61a3-3e5d-466f-b9ff-646ba8475785'), source_entity_name=None, target_entity_uuid=UUID('51e0cae0-c4a9-4c58-959e-2b3b9c42a88f'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('d51bde89-1f8c-4c32-a49f-559d242d5445'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[UUID('4a85bede-1f24-47e1-8aa6-e4d8181a92ea'), UUID('79f7db8b-c1c2-4bfa-9596-e662358cc9e2')], description='Years of performing with enchanted weapons have attuned you to fire, but left you vulnerable to cold. You have resistance to fire damage but vulnerability to cold damage.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('4827aa14-b0fa-42d1-8221-d25cc38fea05'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('1434dd3a-f6de-4f8b-80c4-b036931db6a6'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 510041), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.DECLARATION: 'declaration'>, modified=False, canceled=False, parent_event=None, status_message=None, lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('786c258b-a3e5-4321-a20d-a45dc674a8d2'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('765cbf76-498c-4c62-aae1-b7752aa63e92'), source_entity_uuid=UUID('4da1a555-a50f-4a4c-a79d-a40ba4f6ce90'), source_entity_name=None, target_entity_uuid=UUID('44d2c9b3-a53c-46aa-9699-5830a9ffbf55'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('786c258b-a3e5-4321-a20d-a45dc674a8d2'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('3d7bbf77-ae65-45ac-8cbb-581bf5974df1'): [UUID('b79a61e9-04c3-48ca-9184-e1ead10b2605')], UUID('03f32901-407b-4341-8e8d-624bb2f5b8d8'): [UUID('81caba07-7a1e-4d8b-900c-0aef3bbd4428')], UUID('5ab06269-8693-4efd-844e-82eaeddd421a'): [UUID('8e4e01a2-be3b-4610-be69-afe9ec4bb272')], UUID('e3a8c753-8556-4bd7-9d7d-5c147ec4b923'): [UUID('cf3af813-9779-4a30-92a8-258a00c43767')], UUID('080602c7-dab9-4472-a7e9-6a49cdf15a22'): [UUID('3a72d9d8-7fde-4426-89d8-c19dc25b4750')], UUID('17f0424a-0c96-40af-8e53-bbf92cec1678'): [UUID('d63d178e-6fe0-4a83-b34f-2393552acb56')], UUID('5e4c5107-5e48-4d82-949a-aab32f2441f0'): [UUID('b763f2b7-2bf1-4145-b0a7-d4d504d89a4b')], UUID('8f551ea5-9128-4689-bb4a-ac8896a60229'): [UUID('e757cd9a-e75b-4cc4-a16a-d994292ab735')], UUID('a680671c-e9d6-44bc-ab70-4eb2f22446c3'): [UUID('8a60c0ff-fa83-47d6-96fb-f09f1dda87b2')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('a1aa2458-7b44-45eb-bc3a-d121c2cd5dbf'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('1434dd3a-f6de-4f8b-80c4-b036931db6a6'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 510041), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.EFFECT: 'effect'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Mona', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('786c258b-a3e5-4321-a20d-a45dc674a8d2'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('765cbf76-498c-4c62-aae1-b7752aa63e92'), source_entity_uuid=UUID('4da1a555-a50f-4a4c-a79d-a40ba4f6ce90'), source_entity_name=None, target_entity_uuid=UUID('44d2c9b3-a53c-46aa-9699-5830a9ffbf55'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('786c258b-a3e5-4321-a20d-a45dc674a8d2'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('3d7bbf77-ae65-45ac-8cbb-581bf5974df1'): [UUID('b79a61e9-04c3-48ca-9184-e1ead10b2605')], UUID('03f32901-407b-4341-8e8d-624bb2f5b8d8'): [UUID('81caba07-7a1e-4d8b-900c-0aef3bbd4428')], UUID('5ab06269-8693-4efd-844e-82eaeddd421a'): [UUID('8e4e01a2-be3b-4610-be69-afe9ec4bb272')], UUID('e3a8c753-8556-4bd7-9d7d-5c147ec4b923'): [UUID('cf3af813-9779-4a30-92a8-258a00c43767')], UUID('080602c7-dab9-4472-a7e9-6a49cdf15a22'): [UUID('3a72d9d8-7fde-4426-89d8-c19dc25b4750')], UUID('17f0424a-0c96-40af-8e53-bbf92cec1678'): [UUID('d63d178e-6fe0-4a83-b34f-2393552acb56')], UUID('5e4c5107-5e48-4d82-949a-aab32f2441f0'): [UUID('b763f2b7-2bf1-4145-b0a7-d4d504d89a4b')], UUID('8f551ea5-9128-4689-bb4a-ac8896a60229'): [UUID('e757cd9a-e75b-4cc4-a16a-d994292ab735')], UUID('a680671c-e9d6-44bc-ab70-4eb2f22446c3'): [UUID('8a60c0ff-fa83-47d6-96fb-f09f1dda87b2')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.')),
#  ConditionApplicationEvent(name='Circus Performer', uuid=UUID('a715a244-3582-46f0-a49c-cfaba0d90c54'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('1434dd3a-f6de-4f8b-80c4-b036931db6a6'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 510041), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Circus Performer condition to Mona', lineage_children_events=[], children_events=[], condition=CircusPerformer(name='Circus Performer', uuid=UUID('786c258b-a3e5-4321-a20d-a45dc674a8d2'), source_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('765cbf76-498c-4c62-aae1-b7752aa63e92'), source_entity_uuid=UUID('4da1a555-a50f-4a4c-a79d-a40ba4f6ce90'), source_entity_name=None, target_entity_uuid=UUID('44d2c9b3-a53c-46aa-9699-5830a9ffbf55'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('786c258b-a3e5-4321-a20d-a45dc674a8d2'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('3d7bbf77-ae65-45ac-8cbb-581bf5974df1'): [UUID('b79a61e9-04c3-48ca-9184-e1ead10b2605')], UUID('03f32901-407b-4341-8e8d-624bb2f5b8d8'): [UUID('81caba07-7a1e-4d8b-900c-0aef3bbd4428')], UUID('5ab06269-8693-4efd-844e-82eaeddd421a'): [UUID('8e4e01a2-be3b-4610-be69-afe9ec4bb272')], UUID('e3a8c753-8556-4bd7-9d7d-5c147ec4b923'): [UUID('cf3af813-9779-4a30-92a8-258a00c43767')], UUID('080602c7-dab9-4472-a7e9-6a49cdf15a22'): [UUID('3a72d9d8-7fde-4426-89d8-c19dc25b4750')], UUID('17f0424a-0c96-40af-8e53-bbf92cec1678'): [UUID('d63d178e-6fe0-4a83-b34f-2393552acb56')], UUID('5e4c5107-5e48-4d82-949a-aab32f2441f0'): [UUID('b763f2b7-2bf1-4145-b0a7-d4d504d89a4b')], UUID('8f551ea5-9128-4689-bb4a-ac8896a60229'): [UUID('e757cd9a-e75b-4cc4-a16a-d994292ab735')], UUID('a680671c-e9d6-44bc-ab70-4eb2f22446c3'): [UUID('8a60c0ff-fa83-47d6-96fb-f09f1dda87b2')]}, parent_condition=None, sub_conditions=[], event_handlers_uuids=[], description='Your past in the circus has granted you exceptional acrobatic abilities and combat training.'))]

# %%
q._events_by_lineage[UUID("2447f19b-7dac-4743-bf95-aadf34a9b712")]
# Out:
# []

# %%
from dnd.actions import Attack
weapon_slot = WeaponSlot.MAIN_HAND

# %%
warrior.senses.add_entity(warrior2.uuid,warrior2.position)
warrior2.senses.add_entity(warrior.uuid,warrior.position)

# %%
attack = Attack(name="Warrior Main Hand attack",
                source_entity_uuid=warrior.uuid,
                target_entity_uuid=warrior2.uuid,
                weapon_slot= WeaponSlot.MAIN_HAND)

# %%
warrior2.get_hp()
# Out:
# 58

# %%
attack.apply()
# Out:
# AttackEvent(name='Warrior Main Hand attack', uuid=UUID('361ccc7b-3d71-47dd-8a92-303afcbbde8b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, lineage_uuid=UUID('fc7b90d7-87ac-4e3e-aea9-5b7a95e5ff0b'), timestamp=datetime.datetime(2025, 5, 11, 19, 20, 18, 625398), event_type=<EventType.ATTACK: 'attack'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Attack completed', lineage_children_events=[], children_events=[], costs=[Cost(name='Attack Cost', cost_type='actions', cost=1, evaluator=<function entity_action_economy_cost_evaluator at 0x000001EE0F561260>)], weapon_slot=<WeaponSlot.MAIN_HAND: 'MAIN_HAND'>, range=Range(type=<RangeType.REACH: 'Reach'>, normal=5, long=None), attack_bonus=ModifiableValue(name='Value_Attack Bonus_Attack Bonus_Melee Attack Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('d0f1878f-2788-45bc-9cbc-94aa2c63778b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440720>, generated_from=[UUID('0d92c5ed-394a-4e0e-8d6e-8761fa946736'), UUID('749df5d9-935d-4041-a6d9-c26c4ee96959'), UUID('272dbf92-9fcf-4a95-8140-b312bc04770a'), UUID('8d8a845f-a211-43f0-80ab-4a748d5ed8e1'), UUID('93f1c7cf-ec84-4149-bc5e-bbf29b79889d'), UUID('38d294f6-fcaa-4576-aa8b-dfbf910562e7')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value_A Value', uuid=UUID('dec251ab-cd7d-4896-9f27-6ac69e580633'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('9a46584f-3a9a-4972-83e4-5681ff68a142'), target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440720>, generated_from=[UUID('22403f62-915e-40b6-a44b-890774bf68fd'), UUID('873d313f-1f8f-46d5-8a8d-958037b6784b'), UUID('2ff4dd20-b925-4e7d-aa02-1cd2a5c324cb'), UUID('c7a52f65-d909-4cd0-9239-1d70d9afb640'), UUID('439e44de-fa58-4ef3-af12-a529f77633f9'), UUID('ba803b7c-9328-443e-9109-ad8ebdc1f7c4')], global_normalizer=False, value_modifiers={UUID('730fd3c6-b86f-4848-a910-d236fd7b5477'): NumericalModifier(name='Value_base_value', uuid=UUID('730fd3c6-b86f-4848-a910-d236fd7b5477'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=2, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440720>, normalized_value=2), UUID('390bb358-47b3-48a6-8cc7-9f173358fc35'): NumericalModifier(name='Circus Training', uuid=UUID('390bb358-47b3-48a6-8cc7-9f173358fc35'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=-1, score_normalizer=None, normalized_value=-1), UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('49453ba5-8236-4e03-be17-14e92b50ba4b'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001EE0E440B80>, normalized_value=0), UUID('7775f479-310f-4097-99c5-68d77dd3b1e5'): NumericalModifier(name='Attack Bonus_base_value', uuid=UUID('7775f479-310f-4097-99c5-68d77dd3b1e5'), source_entity_uuid=UUID('09e5eeca-9b9f-46e0-a3e4-b3dbb8cfe21f'), source_entity_name=None, target_entity_uuid=UUID( ...

# %%
for event in q._all_events:
    print(event.name,event.status_message)
# Out:
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Dual Wielder None
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Ganger
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Ganger
# Elemental Weapon Mastery None
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Ganger
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Ganger
# Elemental Affinity None
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Ganger
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Ganger
# Circus Performer None
# Circus Performer Applied Circus Performer condition to Ganger
# Circus Performer Applied Circus Performer condition to Ganger
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Performer's Leather Armor None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Flaming Scimitar None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Rusty Dagger None
# Dual Wielder None
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Mona
# Dual Wielder Applied Dual Wielder contextual ac modifer condition to Mona
# Elemental Weapon Mastery None
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Mona
# Elemental Weapon Mastery Applied Elemental Weapon Mastery contextual advantage modifier condition to Mona
# Elemental Affinity None
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Mona
# Elemental Affinity Applied Elemental Affinity resistance modifier condition to Mona
# Circus Performer None
# Circus Performer Applied Circus Performer condition to Mona
# Circus Performer Applied Circus Performer condition to Mona
# Warrior Main Hand attack None
# Warrior Main Hand attack Validated range for Warrior Main Hand attack - added range to event
# Warrior Main Hand attack Validated line of sight for Warrior Main Hand attack
# Warrior Main Hand attack Attack validated for Warrior Main Hand attack
# Warrior Main Hand attack Rolling attack
# Warrior Main Hand attack Attack rolled 21 and AttackOutcome.HIT
# Warrior Main Hand attack Dealing damage
# Warrior Main Hand attack Attack completed

# %%
warrior2.get_hp()
# Out:
# 53

# %%
warrior.source_entity_uuid
# Out:
# UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('4bf62a8d-f496-44e9-b0ed-ddb80abd6d21')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands.', uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('4bf62a8d-f496-44e9-b0ed-ddb80abd6d21'): AbilityScores(name='ability_scores', description=None, uuid=UUID('4bf62a8d-f496-44e9-b0ed-ddb80abd6d21'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('231cdc5b-de31-4f75-abae-dfd42987107f'): Ability(name='strength', description=None, uuid=UUID('231cdc5b-de31-4f75-abae-dfd42987107f'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('4acab144-14a4-44ce-9897-1e8de35c602b'): ModifiableValue(name='strength Ability Score', uuid=UUID('4acab144-14a4-44ce-9897-1e8de35c602b'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000180CF515440>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('6fe56204-56c1-4962-846e-cd0fbbfb06a0'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x00000180CF515440>, generated_from=[], global_normalizer=True, value_modifiers={UUID('56bca55e-32f3-4dfe-a9a8-f1ee594b2f96'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('56bca55e-32f3-4dfe-a9a8-f1ee594b2f96'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x00000180CF515440>, normalized_value=2), UUID('5567d081-a5b5-49fb-879c-e1d35d646382'): NumericalModifier(name='level 4 talent', uuid=UUID('5567d081-a5b5-49fb-879c-e1d35d646382'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Dama ...

# %%
from dnd.conditions import Paralyzed

# %%
paralyzed_condition = Paralyzed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
paralyzed_condition.apply()
# Out:
# ConditionApplicationEvent(name='Paralyzed', uuid=UUID('f786dab7-daa2-4c92-b3a5-799509eb8f03'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=UUID('72649558-23a3-4397-b5be-2abc1fa36c78'), target_entity_name=None, context=None, lineage_uuid=UUID('9b0e900e-a1c5-4cdf-95f2-ffacf0295769'), timestamp=datetime.datetime(2025, 5, 11, 19, 9, 3, 810441), event_type=<EventType.CONDITION_APPLICATION: 'condition_application'>, phase=<EventPhase.COMPLETION: 'completion'>, modified=True, canceled=False, parent_event=None, status_message='Applied Paralyzed to target contextual critical modifier to Mona', lineage_children_events=[UUID('a9b3031e-e6e3-420f-a7ba-3e8fea24e13a'), UUID('219eb697-cc94-4117-82f8-90bc5bc98c68'), UUID('f8796037-ca17-4349-8eae-2bd721c08d58'), UUID('b1e88ea5-b149-4477-b1c0-6af5c568fc38'), UUID('d2cedcd6-df90-4d8a-8a5a-4190a8f53fd3'), UUID('ffece060-7512-45f7-b464-d44834654be9'), UUID('a9b3031e-e6e3-420f-a7ba-3e8fea24e13a'), UUID('219eb697-cc94-4117-82f8-90bc5bc98c68'), UUID('f8796037-ca17-4349-8eae-2bd721c08d58'), UUID('b1e88ea5-b149-4477-b1c0-6af5c568fc38'), UUID('d2cedcd6-df90-4d8a-8a5a-4190a8f53fd3'), UUID('ffece060-7512-45f7-b464-d44834654be9')], children_events=[], condition=Paralyzed(name='Paralyzed', uuid=UUID('7a4e583e-21ff-4716-b1a7-5e14aa41b846'), source_entity_uuid=UUID('26ced8d6-9c02-4212-9670-1e5bbb096e83'), source_entity_name=None, target_entity_uuid=UUID('72649558-23a3-4397-b5be-2abc1fa36c78'), target_entity_name=None, context=None, duration=Duration(name=None, uuid=UUID('6ba6e2d0-cb90-42ee-aba0-0ba3e56e93e5'), source_entity_uuid=UUID('b8deddac-f07c-40a2-b1f9-8defc9ff835b'), source_entity_name=None, target_entity_uuid=UUID('e03e5fe7-0f47-4544-a726-0eec030e26d7'), target_entity_name=None, context=None, duration=None, duration_type=<DurationType.PERMANENT: 'permanent'>, long_rested=False, owned_by_condition=UUID('7a4e583e-21ff-4716-b1a7-5e14aa41b846'), is_expired=False), application_saving_throw=None, removal_saving_throw=None, applied=True, modifers_uuids={UUID('775cc1a7-1d26-4a23-b83e-603bfb92e67e'): [UUID('beef1be9-fff1-4eca-a8f3-e31c12c7383d')], UUID('1a2da1e1-88fe-46fa-a112-e9027c0b5030'): [UUID('06fec6d8-cc88-4ef8-81ec-d30564604d2e')], UUID('54306bc4-5b0c-4299-83e4-b3ef6a8eff0d'): [UUID('6b90ebde-9e4a-4000-87ee-eb7a2f0f032a')]}, parent_condition=None, sub_conditions=[UUID('e9b62af5-9963-4f81-949c-e173f646886b')], event_handlers_uuids=[], description='A paralyzed creature is incapacitated (see the condition) and can’t move or speak. The creature automatically fails Strength and Dexterity saving throws. Attack rolls against the creature have advantage. Any attack that hits the creature is a critical hit if the attacker is within 5 feet of the creature.'))

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score

# %%
warrior_bonus.normalized_score

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")

# %%
attack_roll.bonus

# %%
attack_roll.results

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)

# %%
damages

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request

# %%
strength_saving_throw_request

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")

# %%
warrior2.skill_check(acrobatics_skill_request)

# %%
warrior2.skill_check(perception_skill_request)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")

# %%
warrior2.saving_throw(strength_saving_throw_request)

# %%
from dnd.conditions import Blinded
from dnd.core.events import EventQueue


blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()

# %%
warrior2.equipment.attack_bonus.advantage

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
warrior.equipment.attack_bonus.advantage

# %%
warrior.attack(warrior2.uuid,weapon_slot)

# %%
blinded.modifers_uuids

# %%
warrior2.skill_check(perception_skill_request)

# %%
blinded.remove()

# %%
warrior2.skill_check(perception_skill_request)

# %%
warrior2.equipment.attack_bonus.advantage

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()

# %%
warrior.action_economy.movement.normalized_score

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score

# %%
print(f"total_time: {time.time()-start_time}")
