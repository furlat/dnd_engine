# %%
from dnd.monsters.circus_fighter import create_warrior
from dnd.entity import Entity
from dnd.blocks.equipment import WeaponSlot
from dnd.core.dice import Dice, RollType, AttackOutcome
from uuid import uuid4

source_id = uuid4()
proficiency_bonus = 2

# %%
warrior = create_warrior(source_id,proficiency_bonus)
warrior2 = create_warrior(name="Mona")

# %%
warrior.source_entity_uuid
# Out:
# UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36')

# %%
warrior.ability_scores.uuid
# Out:
# UUID('cc529077-0427-41bd-9adb-fbb88c1f46c2')

# %%
Entity.get(warrior.source_entity_uuid)
# Out:
# Entity(name='Ganger', description='A level 4 fighter character with a past in the circus and spiked claws for hands', uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('cc529077-0427-41bd-9adb-fbb88c1f46c2'): AbilityScores(name='ability_scores', description=None, uuid=UUID('cc529077-0427-41bd-9adb-fbb88c1f46c2'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={UUID('11e7db16-6a88-42c4-8fc5-e054ad9de62f'): Ability(name='strength', description=None, uuid=UUID('11e7db16-6a88-42c4-8fc5-e054ad9de62f'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, blocks={}, values={UUID('4fc856c3-57e2-422b-afeb-93d7502813d1'): ModifiableValue(name='strength Ability Score', uuid=UUID('4fc856c3-57e2-422b-afeb-93d7502813d1'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d729a7c9-a720-4d75-9536-a5d9436e5a05'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, normalized_value=2), UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'): NumericalModifier(name='level 4 talent', uuid=UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <Damag ...

# %%
weapon_slot = WeaponSlot.MAIN_HAND

warrior_bonus = warrior.attack_bonus(target_entity_uuid=warrior2.source_entity_uuid,weapon_slot=weapon_slot)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('4fc856c3-57e2-422b-afeb-93d7502813d1'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d729a7c9-a720-4d75-9536-a5d9436e5a05'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, normalized_value=2), UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'): NumericalModifier(name='level 4 talent', uuid=UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e72cb5e0-820f-4c78-884c-10547f63f530'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...

# %%
warrior.ability_scores.get_ability("strength").ability_score.normalized_score+warrior.ability_scores.get_ability("strength").modifier_bonus.normalized_score
# Out:
# 4

# %%
warrior_bonus.normalized_score
# Out:
# 5

# %%
attack_dice = Dice(count=1,value=20,bonus=warrior_bonus, roll_type=RollType.ATTACK)
attack_roll = attack_dice.roll
print(f"Attack roll result: {attack_roll.total}")
# Out:
# Attack roll result: 6

# %%
attack_roll.bonus
# Out:
# 5

# %%
attack_roll.results
# Out:
# 1

# %%
import time

# %%
start_time = time.time()
damages = warrior.get_damages(weapon_slot)
print(time.time()-start_time)
# Out:
# 0.001005411148071289

# %%
start_time = time.time()
attack_bonus = warrior.attack_bonus(weapon_slot= weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('4fc856c3-57e2-422b-afeb-93d7502813d1'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d729a7c9-a720-4d75-9536-a5d9436e5a05'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, normalized_value=2), UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'): NumericalModifier(name='level 4 talent', uuid=UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e72cb5e0-820f-4c78-884c-10547f63f530'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=True, size_modifiers={}, damage_type_modifiers={}, resistance_mod ...
# 0.002514362335205078

# %%
start_time = time.time()
ac = warrior2.ac_bonus()
print(time.time()-start_time)
start_time = time.time()
# Out:
# 0.0004999637603759766

# %%
start_time = time.time()
dice_roll, attack_outcome = warrior.get_attack_outcome(attack_bonus, ac)
print(time.time()-start_time)
# Out:
# Target AC: 12
# Attack bonus: 5
# Roll result: 4, Roll total: 9 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# 0.0005004405975341797

# %%
start_time = time.time()
damage_rolls = warrior2.take_damage(damages, attack_outcome)
print(time.time()-start_time)
# Out:
# Total Health before taking damage: 58
# Damage Roll result: [3], Roll total: 9
# Total Health after taking damage: 50
# 0.0009980201721191406

# %%
damages
# Out:
# [Damage(name='Damage', uuid=UUID('4ea4a713-2c0a-429f-a0b1-b118894e50ad'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, damage_dice=4, dice_numbers=1, damage_bonus=ModifiableValue(name='Unarmed Damage Bonus_Damage Bonus_Melee Damage Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('caa1eaf5-4c85-45c9-8140-94d3851543e6'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745927240>, generated_from=[UUID('f3a31f12-a28b-408f-993c-9d8929d93a1f'), UUID('c9f07833-1ab1-47b3-9d74-46322e694a3d'), UUID('3129f351-3765-466e-95b8-51ebe379fad6'), UUID('52dff4bc-df70-4258-9392-237d0fbd1bd4')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value_A Value', uuid=UUID('bf20be72-a3f8-4f72-8d75-5697d7dd8052'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745927240>, generated_from=[UUID('c512f143-988e-46d7-9bc9-211230b7e979'), UUID('d06a43f9-5028-4c37-a94a-0dde07b4968a'), UUID('5359f693-ad62-41ec-b072-d6534e660eaf'), UUID('55cb2652-bd64-4f10-a637-b1c55bae36b4')], global_normalizer=False, value_modifiers={UUID('96c098ee-6ccf-4859-9019-d8471ecdc2dc'): NumericalModifier(name='Unarmed Damage Bonus_base_value', uuid=UUID('96c098ee-6ccf-4859-9019-d8471ecdc2dc'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=1, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745927240>, normalized_value=1), UUID('8e1ab180-678c-4fa6-af7d-806ab791e72c'): NumericalModifier(name='a past in the circus', uuid=UUID('8e1ab180-678c-4fa6-af7d-806ab791e72c'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('8a76d6b8-deac-4390-9189-110ac1fa65d9'): NumericalModifier(name='Damage Bonus_base_value', uuid=UUID('8a76d6b8-deac-4390-9189-110ac1fa65d9'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745926980>, normalized_value=0), UUID('7aa08b77-0c66-4906-ab1e-2f6b084ae829'): NumericalModifier(name='Melee Damage Bonus_base_value', uuid=UUID('7aa08b77-0c66-4906-ab1e-2f6b084ae829'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745926E80>, normalized_value=0), UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, normalized_value=2), UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'): NumericalModifier(name='level 4 talent', uuid=UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, targ ...

# %%
start_time = time.time()
warrior.set_target_entity(warrior2.uuid)
print(time.time()-start_time)
# Out:
# 0.0015003681182861328

# %%
warrior.target_entity_uuid=warrior2.uuid

# %%
a = warrior.uuid

# %%
start_time = time.time()
warrior2.target_entity_name="warrior.uuid"
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.target_entity_uuid=warrior.uuid
print(time.time()-start_time)
# Out:
# 0.0

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.001499176025390625

# %%
start_time = time.time()
warrior2.set_target_entity(warrior.uuid)
print(time.time()-start_time)
# Out:
# 0.0019998550415039062

# %%
start_time = time.time()
warrior.attack(warrior2.uuid,weapon_slot)
print(time.time()-start_time)
# Out:
# current ability bonuses [ModifiableValue(name='strength Ability Score', uuid=UUID('4fc856c3-57e2-422b-afeb-93d7502813d1'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, self_static=StaticValue(name='A Value', uuid=UUID('d729a7c9-a720-4d75-9536-a5d9436e5a05'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, value_modifiers={UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('c00e56a9-5d01-4f7a-9d42-7897dda276e2'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, normalized_value=2), UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'): NumericalModifier(name='level 4 talent', uuid=UUID('feed5714-1d36-4dec-8cc3-82fe02b82018'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1)}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_modifiers={}, auto_hit_modifiers={}, is_outgoing_modifier=False, size_modifiers={}, damage_type_modifiers={}, resistance_modifiers={}, largest_size_priority=True, min=None, max=None, score=16, normalized_score=3, advantage_sum=0, advantage=<AdvantageStatus.NONE: 'None'>, critical=<CriticalStatus.NONE: 'None'>, auto_hit=<AutoHitStatus.NONE: 'None'>, size=<Size.MEDIUM: 'Medium'>, damage_types=[], damage_type=None, resistance_sum={<DamageType.ACID: 'Acid'>: 0, <DamageType.BLUDGEONING: 'Bludgeoning'>: 0, <DamageType.COLD: 'Cold'>: 0, <DamageType.FIRE: 'Fire'>: 0, <DamageType.FORCE: 'Force'>: 0, <DamageType.LIGHTNING: 'Lightning'>: 0, <DamageType.NECROTIC: 'Necrotic'>: 0, <DamageType.PIERCING: 'Piercing'>: 0, <DamageType.POISON: 'Poison'>: 0, <DamageType.PSYCHIC: 'Psychic'>: 0, <DamageType.RADIANT: 'Radiant'>: 0, <DamageType.SLASHING: 'Slashing'>: 0, <DamageType.THUNDER: 'Thunder'>: 0}, resistance={<DamageType.ACID: 'Acid'>: <ResistanceStatus.NONE: 'None'>, <DamageType.BLUDGEONING: 'Bludgeoning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.COLD: 'Cold'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FIRE: 'Fire'>: <ResistanceStatus.NONE: 'None'>, <DamageType.FORCE: 'Force'>: <ResistanceStatus.NONE: 'None'>, <DamageType.LIGHTNING: 'Lightning'>: <ResistanceStatus.NONE: 'None'>, <DamageType.NECROTIC: 'Necrotic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PIERCING: 'Piercing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.POISON: 'Poison'>: <ResistanceStatus.NONE: 'None'>, <DamageType.PSYCHIC: 'Psychic'>: <ResistanceStatus.NONE: 'None'>, <DamageType.RADIANT: 'Radiant'>: <ResistanceStatus.NONE: 'None'>, <DamageType.SLASHING: 'Slashing'>: <ResistanceStatus.NONE: 'None'>, <DamageType.THUNDER: 'Thunder'>: <ResistanceStatus.NONE: 'None'>}), to_target_static=StaticValue(name='A Value', uuid=UUID('e72cb5e0-820f-4c78-884c-10547f63f530'), source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, generated_from=[], global_normalizer=True, value_modifiers={}, min_constraints={}, max_constraints={}, advantage_modifiers={}, critical_mod ...
# Target AC: 12
# Attack bonus: 5
# Roll result: 13, Roll total: 18 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# Ac advantage modifiers: AdvantageStatus.NONE
# Roll Advantage status: AdvantageStatus.NONE
# Total Health before taking damage: 50
# Damage Roll result: [1], Roll total: 7
# Total Health after taking damage: 44
# 0.008003711700439453

# %%
from dnd.core.requests import SkillCheckRequest, SavingThrowRequest, SkillName

# %%
warrior_strenght_modifer = warrior.ability_scores.get_ability("strength").get_combined_values()
warrior_ac = warrior.ac_bonus()

# %%
acrobatics_skill_request = warrior.create_skill_check_request(warrior2.uuid, "acrobatics",warrior_ac.uuid)
perception_skill_request = warrior.create_skill_check_request(warrior2.uuid, "perception",warrior_ac.uuid)
strength_saving_throw_request = warrior.create_saving_throw_request(warrior2.uuid, "strength",warrior_ac.uuid)

# %%
acrobatics_skill_request
# Out:
# SkillCheckRequest(dc=12, source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), context=None, skill_name='acrobatics')

# %%
strength_saving_throw_request
# Out:
# SavingThrowRequest(dc=12, source_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), context=None, ability_name='strength')

# %%
warrior2.skill_bonus(warrior.uuid,skill_name="acrobatics")
# Out:
# ModifiableValue(name='Value_acrobatics Skill Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('f2ca1bd8-7865-476b-9c0b-d89daf86b70a'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001E745B53740>, generated_from=[UUID('d5637cc2-7488-4306-a7aa-304f9928a2ba'), UUID('cbd386fc-488f-416d-bfce-0ac0a3d4da1f'), UUID('213d2875-8095-4c0e-a0f4-6a238e1244b9'), UUID('b76ba698-bc60-4b86-bc19-9019f7d34185')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('105c86d7-459d-4a93-8ecc-211d7e292da6'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001E745B53740>, generated_from=[UUID('92b70b88-4ebe-40de-90cc-4e176a220869'), UUID('873a3824-18d3-4138-b832-c775f4c30da1'), UUID('586ce844-d149-4ea5-8b10-95597bb3d62c'), UUID('4dda0f1d-d943-4ed0-93f7-549c47d252e5')], global_normalizer=False, value_modifiers={UUID('0fffdafb-84c9-4f10-8f62-f9e692c41ef7'): NumericalModifier(name='Value_base_value', uuid=UUID('0fffdafb-84c9-4f10-8f62-f9e692c41ef7'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, value=0, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001E745B53740>, normalized_value=0), UUID('aa713cbf-8747-402c-9a41-1cd2eb3b8165'): NumericalModifier(name='a past in the circus', uuid=UUID('aa713cbf-8747-402c-9a41-1cd2eb3b8165'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function Skill._get_proficiency_converter.<locals>.expert at 0x000001E745B53740>, normalized_value=-2), UUID('f7540f66-3ef2-4410-b0b9-33864507e493'): NumericalModifier(name='acrobatics Skill Bonus_base_value', uuid=UUID('f7540f66-3ef2-4410-b0b9-33864507e493'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745A5CAE0>, normalized_value=0), UUID('ad32766e-6a5c-4a19-a1be-9df1f98851b1'): NumericalModifier(name='a past in the circus', uuid=UUID('ad32766e-6a5c-4a19-a1be-9df1f98851b1'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=7, score_normalizer=None, normalized_value=7), UUID('d4202492-9eb6-4ef1-b5c3-98f91df6f3ac'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('d4202492-9eb6-4ef1-b5c3-98f91df6f3ac'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, value=12, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, normalized_value=1), UUID('009af05b-87d0-4734-b798-f5e0c14cbcba'): NumericalModifier(name='strength Modifier Bonus_base_value', uuid=UUID('009af05b-87d0-4734-b798-f5e0c14cbcba'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745927E20>, normalized_value=0)}, min_constraints={}, max_co ...

# %%
warrior2.skill_check(acrobatics_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 6
# Roll result: 5, Roll total: 11 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('3924ea00-db8a-4145-ae0b-e937c8e8a106'), dice_uuid=UUID('61f0930d-7d8a-49e4-bd66-93120d36d203'), roll_type=<RollType.ATTACK: 'Attack'>, results=5, total=11, bonus=6, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), attack_outcome=None),
#  False)

# %%
warrior2.skill_check(perception_skill_request)
# Out:
# Target AC: 12
# Attack bonus: 0
# Roll result: 5, Roll total: 5 vs target ac: 12 result: False auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.MISS: 'Miss'>,
#  DiceRoll(roll_uuid=UUID('58aa17c6-3f36-4fd3-8e89-42dc7f16777f'), dice_uuid=UUID('06db4f5e-304d-4262-99aa-6d60659c93b9'), roll_type=<RollType.ATTACK: 'Attack'>, results=5, total=5, bonus=0, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), attack_outcome=None),
#  False)

# %%
warrior2.saving_throw_bonus(warrior.uuid, "strength")
# Out:
# ModifiableValue(name='Value_strength_saving_throw Saving Throw Bonus_strength Ability Score_strength Modifier Bonus', uuid=UUID('75ec93b9-e74b-42e3-9f51-dc0106157e20'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001E745B53880>, generated_from=[UUID('d5637cc2-7488-4306-a7aa-304f9928a2ba'), UUID('bd7f1e14-4c73-411a-958c-1039e0bf5ce8'), UUID('b16b3050-ef1b-4f8d-aca4-a85b6f3ba9c6'), UUID('95bd4a9d-5aca-4b66-afa6-93ea927b0da4')], global_normalizer=False, self_static=StaticValue(name='A Value_A Value_A Value_A Value', uuid=UUID('030e13c1-23ac-486f-8301-bc29744046d9'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), target_entity_name=None, context=None, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001E745B53880>, generated_from=[UUID('92b70b88-4ebe-40de-90cc-4e176a220869'), UUID('6991bf3e-f0ea-4b5f-acce-35a69686922f'), UUID('ae884b0f-e006-4587-889f-15d5cabb9eaa'), UUID('abf38a05-9cea-457b-9243-fc413ac189e0')], global_normalizer=False, value_modifiers={UUID('0fffdafb-84c9-4f10-8f62-f9e692c41ef7'): NumericalModifier(name='Value_base_value', uuid=UUID('0fffdafb-84c9-4f10-8f62-f9e692c41ef7'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, value=0, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001E745B53880>, normalized_value=0), UUID('aa713cbf-8747-402c-9a41-1cd2eb3b8165'): NumericalModifier(name='a past in the circus', uuid=UUID('aa713cbf-8747-402c-9a41-1cd2eb3b8165'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=-1, score_normalizer=<function SavingThrow._get_proficiency_converter.<locals>.<lambda> at 0x000001E745B53880>, normalized_value=-1), UUID('2d9d7c0b-5287-4f62-92d1-c67401a85e4b'): NumericalModifier(name='strength_saving_throw Saving Throw Bonus_base_value', uuid=UUID('2d9d7c0b-5287-4f62-92d1-c67401a85e4b'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, value=0, score_normalizer=<function ModifiableValue.create.<locals>.<lambda> at 0x000001E745A5ECA0>, normalized_value=0), UUID('4aa5d7e2-1ddf-46f9-885b-d852a75e2868'): NumericalModifier(name='a past in the circus', uuid=UUID('4aa5d7e2-1ddf-46f9-885b-d852a75e2868'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('e48919b2-ed38-4d14-8da2-6a365d882d9b'): NumericalModifier(name='strength Ability Score_base_value', uuid=UUID('e48919b2-ed38-4d14-8da2-6a365d882d9b'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_name=None, context=None, value=15, score_normalizer=<function ability_score_normalizer at 0x000001E742D9D800>, normalized_value=2), UUID('46fcd855-0aa4-4ff2-853b-3039761b6352'): NumericalModifier(name='level 4 talent', uuid=UUID('46fcd855-0aa4-4ff2-853b-3039761b6352'), source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), source_entity_name=None, target_entity_uuid=None, target_entity_name=None, context=None, value=1, score_normalizer=None, normalized_value=1), UUID('cda1492d-6d6c-4102-8b78-942206bcdc6d'): NumericalModifier(name='strength Modifier  ...

# %%
warrior2.saving_throw(strength_saving_throw_request)
# Out:
# Target AC: 12
# Attack bonus: 4
# Roll result: 18, Roll total: 22 vs target ac: 12 result: True auto hit status: AutoHitStatus.NONE critical status: CriticalStatus.NONE
# Roll auto hit status: AutoHitStatus.NONE
# Roll critical status: CriticalStatus.NONE
# Attack bonus advantage modifiers: AdvantageStatus.NONE
# No advantage modifiers
# Roll Advantage status: AdvantageStatus.NONE
# (<AttackOutcome.HIT: 'Hit'>,
#  DiceRoll(roll_uuid=UUID('21acd3b8-3fad-4db0-843a-e745c9fab50a'), dice_uuid=UUID('27d40c05-740e-4765-ba76-50c34606b467'), roll_type=<RollType.ATTACK: 'Attack'>, results=18, total=22, bonus=4, advantage_status=<AdvantageStatus.NONE: 'None'>, critical_status=<CriticalStatus.NONE: 'None'>, auto_hit_status=<AutoHitStatus.NONE: 'None'>, source_entity_uuid=UUID('80d30934-a6b3-4d9b-86fa-bc1f2466b829'), target_entity_uuid=UUID('f5bac420-654f-4d1d-a4f1-a66f5116ac36'), attack_outcome=None),
#  True)

# %%
from dnd.conditions import Blinded
from dnd.core.events import EventQueue


blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
blinded.apply()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 6
#       2 from dnd.core.events import EventQueue
#       5 blinded = Blinded(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)
# ----> 6 blinded.apply()
#
# File ~\Documents\Dev\dnd_engine\dnd\core\base_conditions.py:151, in BaseCondition.apply(self, parent_event)
#     149     return None
#     150 #then apply the condition
# --> 151 modifers_uuids, event_handlers_uuids, sub_conditions_uuids, applied_event = self._apply(event)
#     152 if not applied_event or (len(modifers_uuids) == 0 and len(event_handlers_uuids) == 0 and len(sub_conditions_uuids) == 0):
#     153     return event.cancel(status_message=f"Condition {self.name} was not applied for some unknown reason, check the implementaiton of _apply method")
#
# ValueError: too many values to unpack (expected 4)

# %%
warrior2.equipment.attack_bonus.advantage

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
warrior.equipment.attack_bonus.advantage

# %%
warrior.attack(warrior2.uuid,weapon_slot)

# %%
blinded.modifers_uuids

# %%
warrior2.skill_check(perception_skill_request)

# %%
blinded.remove()

# %%
warrior2.skill_check(perception_skill_request)

# %%
warrior2.equipment.attack_bonus.advantage

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
from dnd.core.modifiers import ContextualNumericalModifier, NumericalModifier, ContextAwareNumerical
from typing import Optional, Dict, Any
from uuid import UUID

# %%
from dnd.conditions import Charmed

charmed = Charmed(source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid)

# %%
charmed.apply()

# %%
warrior2.attack(warrior.uuid,weapon_slot)

# %%
deception_skill_request = warrior2.create_skill_check_request(warrior.uuid, "deception",15)

warrior.skill_check(deception_skill_request)

# %%
def hate_mona(source_entity_uuid: UUID, target_entity_uuid: Optional[UUID]=None, context: Optional[Dict[str, Any]]=None) -> NumericalModifier:
    """ function that cheks if the target name is Mona, in that case it gives a +5 modifier"""
    if target_entity_uuid is not None:
        target_entity = Entity.get(target_entity_uuid)
    else:
        target_entity = None
    if isinstance(target_entity, Entity) and target_entity.name == "Mona":
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=5)
    else:
        return NumericalModifier(source_entity_uuid=source_entity_uuid, target_entity_uuid=target_entity_uuid, value=0)

hate_mona_modifier = ContextualNumericalModifier(name="Hate Mona",source_entity_uuid=warrior.uuid, target_entity_uuid=warrior2.uuid, callable=hate_mona)

# %%
warrior.equipment.attack_bonus.self_contextual.add_value_modifier(hate_mona_modifier)

# %%
warrior.set_target_entity(warrior2.uuid)
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.clear_target_entity()
warrior.equipment.attack_bonus.normalized_score

# %%
warrior.senses.entities[warrior2.uuid]=(1,0)

# %%
from dnd.conditions import Frightened
frightened = Frightened(source_entity_uuid=warrior2.uuid, target_entity_uuid=warrior.uuid)
frightened.apply()

# %%
warrior.action_economy.movement.normalized_score

# %%
warrior.senses.entities = {}
warrior.action_economy.movement.normalized_score
